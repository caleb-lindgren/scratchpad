# %%
import cptac

# %%
res = cptac.file_download_pdc.pdc_download("all", version="1.0", redownload=False)

# %%
cptac.file_download_pdc._check_ids_match(res)
# Out:
# PDC000239 == PDC000239
# Prospective Breast BI Acetylome == Prospective Breast BI Acetylome
#
# PDC000121 == PDC000121
# Prospective BRCA Phosphoproteome S039-2 == Prospective BRCA Phosphoproteome S039-2
#
# PDC000120 == PDC000120
# Prospective BRCA Proteome S039-1 == Prospective BRCA Proteome S039-1
#
# PDC000128 == PDC000128
# CPTAC CCRCC Discovery Study - Phosphoproteme S044-2 == CPTAC CCRCC Discovery Study - Phosphoproteme S044-2
#
# PDC000127 == PDC000127
# CPTAC CCRCC Discovery Study - Proteome S044-1 == CPTAC CCRCC Discovery Study - Proteome S044-1
#
# PDC000117 == PDC000117
# Prospective COAD Phosphoproteome S037-3 == Prospective COAD Phosphoproteome S037-3
#
# PDC000116 == PDC000116
# Prospective COAD Proteome S037-2 == Prospective COAD Proteome S037-2
#
# PDC000245 == PDC000245
# CPTAC GBM Discovery Study - Acetylome == CPTAC GBM Discovery Study - Acetylome
#
# PDC000205 == PDC000205
# ...
