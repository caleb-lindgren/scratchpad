# %%
import cptac
import cptac.utils as ut
import json

# %%
resp = ut.search_reactome_pathways("PTEN", resource="UniProt")

# %%
resp.json()
# Out:
# [{'dbId': 1660499,
#   'displayName': 'Synthesis of PIPs at the plasma membrane',
#   'stId': 'R-HSA-1660499',
#   'stIdVersion': 'R-HSA-1660499.6',
#   'isInDisease': False,
#   'isInferred': False,
#   'name': ['Synthesis of PIPs at the plasma membrane'],
#   'releaseDate': '2012-06-12',
#   'speciesName': 'Homo sapiens',
#   'doi': '10.3180/R-HSA-1660499.5',
#   'hasDiagram': False,
#   'hasEHLD': False,
#   'schemaClass': 'Pathway',
#   'className': 'Pathway'},
#  {'dbId': 1855204,
#   'displayName': 'Synthesis of IP3 and IP4 in the cytosol',
#   'stId': 'R-HSA-1855204',
#   'stIdVersion': 'R-HSA-1855204.3',
#   'isInDisease': False,
#   'isInferred': False,
#   'name': ['Synthesis of IP3 and IP4 in the cytosol'],
#   'releaseDate': '2012-12-04',
#   'speciesName': 'Homo sapiens',
#   'hasDiagram': False,
#   'hasEHLD': False,
#   'schemaClass': 'Pathway',
#   'className': 'Pathway'},
#  {'dbId': 199418,
#   'displayName': 'Negative regulation of the PI3K/AKT network',
# ...
