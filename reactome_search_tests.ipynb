# %%
import cptac
import cptac.utils as ut
import json

# %%
ut.search_reactome_pathways(["SMURF2", "PTEN", "asdf"])
# Out:
# cptac warning: The query for 'asdf' returned HTTP 404 (not found). You may have mistyped the gene/protein ID or the resource name. The server gave the following message: ['No pathways found for UniProt:asdf'] (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 1)
#         id                                            pathway     pathway_id
# 0   SMURF2                                   Signaling by BMP   R-HSA-201451
# 1   SMURF2      Downregulation of TGF-beta receptor signaling  R-HSA-2173788
# 2   SMURF2  Downregulation of SMAD2/3:SMAD4 transcriptiona...  R-HSA-2173795
# 3   SMURF2            Asymmetric localization of PCP proteins  R-HSA-4608870
# 4   SMURF2                                Degradation of AXIN  R-HSA-4641257
# 5   SMURF2                                Hedgehog 'on' state  R-HSA-5632684
# 6   SMURF2                   Ub-specific processing proteases  R-HSA-5689880
# ...
