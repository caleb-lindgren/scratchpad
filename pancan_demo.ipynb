# %% [markdown]
# # Pancan data access demo
#
# First, import the package.

# %%
import cptac.pancan as pc

# %% [markdown]
# Authentication through your Box account is required when you download files.

# %%
pc.pancan_download("pancanbrca")
# Out:
# Please login to Box on the webpage that was just opened and grant access for cptac to download files through your account. If you accidentally closed the browser window, press Ctrl+C and call the download function again.

# %%
pc.pancan_download("pancangbm")
# Out:
# Please login to Box on the webpage that was just opened and grant access for cptac to download files through your account. If you accidentally closed the browser window, press Ctrl+C and call the download function again.

# %% [markdown]
# ## Load the BRCA dataset

# %%
br = pc.PancanBrca()

# %%
br.get_clinical(source="mssm")
# Out:
#            tumor_code discovery_study  \
# Patient_ID
# 01BR001            BR             NaN
# 01BR015            BR             NaN
# 01BR017            BR             NaN
# 01BR018            BR             NaN
# 01BR025            BR             NaN
# 01BR026            BR             NaN
# 01BR027            BR             NaN
# 01BR028            BR             NaN
# 01BR030            BR             NaN
# 01BR031            BR             NaN
# 01BR032            BR             NaN
# 01BR033            BR             NaN
# 01BR040            BR             NaN
# 01BR042            BR             NaN
# 01BR043            BR             NaN
# 03BR002            BR             NaN
# 03BR004            BR             NaN
# 03BR005            BR             NaN
# 03BR006            BR             NaN
# 03BR009            BR             NaN
# 03BR010            BR             NaN
# 03BR011            BR             NaN
# 03BR012            BR             NaN
# ...

# %%
br.get_somatic_mutation(source="washu")
# Out:
#                Gene           Mutation        Location      Database_ID
# Patient_ID
# 01BR001      PIK3CD  Missense_Mutation         p.R785W  ENST00000377346
# 01BR001        CA14             Silent         p.E336E  ENST00000369111
# 01BR001      ADAM15             Silent         p.T105T  ENST00000356955
# 01BR001       DCAF6             Silent         p.R222R  ENST00000367840
# 01BR001     CACNA1E  Missense_Mutation         p.R924C  ENST00000367573
# 01BR001       HECW2  Missense_Mutation         p.E615K  ENST00000260983
# 01BR001        FZD7             Silent         p.L486L  ENST00000286201
# 01BR001      PHLDB2  Missense_Mutation         p.R449H  ENST00000431670
# 01BR001        BCHE  Missense_Mutation         p.Q379H  ENST00000264381
# 01BR001     TBC1D19             Silent         p.R442R  ENST00000264866
# 01BR001        AREG  Missense_Mutation          p.L15F  ENST00000395748
# 01BR001       SCLT1  Missense_Mutation          p.N48S  ENST00000281142
# ...

# %%
br.get_proteomics(source="umich")
# Out:
# Proteins              ARF5-201          M6PR-201          ESRRA-201  \
# Database_ID ENSG00000004059.11 ENSG00000003056.8 ENSG00000173153.16
# Patient_ID
# 01BR001               0.012367         -0.945999                NaN
# 01BR008              -0.514386          0.462307           0.230124
# 01BR009              -0.210782         -0.085055           0.380296
# 01BR010               0.105457          0.351335          -0.322798
# 01BR015              -0.509298         -0.874164                NaN
# 01BR017              -0.456085         -0.422949                NaN
# 01BR018              -0.164307         -0.264419           1.121425
# 01BR020              -0.078153         -0.388728          -0.268090
# 01BR023              -0.303983         -0.114765          -0.765492
# 01BR025               0.514449         -0.181170          -0.273682
# 01BR026              -0.254687         -0.433818          -0.288629
# 01BR027               0.001688         -0.678567                NaN
# ...

# %% [markdown]
# ### PDC data
#
# We can also access data from the PDC.

# %%
br.get_proteomics(source="pdc")
# Out:
#               A1BG     A2M   A2ML1    AAAS    AACS   AADAT   AAED1   AAGAB  \
# Patient_ID
# 01BR001     0.9205  0.6200 -1.5461  0.2554 -0.3552  0.6674 -0.0670 -0.6254
# 01BR008    -0.3536  0.0777  0.6186  0.1901 -1.1722     NaN -0.0570 -0.3568
# 01BR009     0.2883  1.0262  1.0538 -0.0663 -0.5431     NaN -0.0249 -0.2518
# 01BR010    -0.3184 -0.4881 -2.1017  0.1253  1.1133  2.9714  0.4628 -0.4796
# 01BR015     0.3141 -0.2018 -1.7129  0.4972  0.1122 -0.3622  0.0160 -0.1703
# 01BR017     0.5332  0.9145  0.1794  0.2714 -0.0139     NaN     NaN  0.0743
# 01BR018     0.7488  0.9163  0.6128  0.0266 -1.2230  0.9211     NaN -0.1070
# 01BR020    -0.1689 -0.4631 -1.8397  0.2066 -0.5330  0.1530  0.0291 -0.0143
# 01BR023    -0.3675 -0.7980 -2.7244  0.3550 -0.9243 -1.2035 -0.4903  0.2965
# 01BR025    -0.1107 -0.5642 -1.1304  0.5184  0.4934     NaN  0.5896  0.6201
# 01BR026     0.7218  1.1547  1.8365  0.1381 -0.9313     NaN  1.1202  0.1238
# ...

# %%
br.get_clinical(source="pdc")
# Out:
#                                     age_at_diagnosis ajcc_clinical_m  \
# case_submitter_id
# 01BR001                                      20074.0    Not Reported
# 01BR008                                          NaN    Not Reported
# 01BR009                                          NaN    Not Reported
# 01BR010                                          NaN    Not Reported
# 01BR015                                      12774.0    Not Reported
# 01BR017                                      16424.0    Not Reported
# 01BR018                                      24089.0    Not Reported
# 01BR020                                          NaN    Not Reported
# 01BR023                                          NaN    Not Reported
# 01BR025                                      22629.0    Not Reported
# 01BR026                                          0.0    Not Reported
# 01BR027                                      29199.0    Not Reported
# ...

# %% [markdown]
# ## Load the GBM dataset

# %%
gb = pc.PancanGbm()

# %%
gb.get_clinical(source="mssm")
# Out:
#            tumor_code discovery_study  \
# Patient_ID
# C3L-00016         GBM              No
# C3L-00019         GBM              No
# C3L-00104         GBM             Yes
# C3L-00265         GBM              No
# C3L-00278         GBM              No
# C3L-00349         GBM              No
# C3L-00365         GBM             Yes
# C3L-00424         GBM              No
# C3L-00429         GBM              No
# C3L-00506         GBM              No
# C3L-00528         GBM              No
# C3L-00591         GBM              No
# C3L-00631         GBM              No
# C3L-00671         GBM              No
# C3L-00674         GBM             Yes
# C3L-00677         GBM             Yes
# C3L-01040         GBM             Yes
# C3L-01043         GBM             Yes
# C3L-01045         GBM             Yes
# C3L-01046         GBM             Yes
# C3L-01048         GBM             Yes
# C3L-01049         GBM             Yes
# C3L-01061         GBM             Yes
# ...

# %%
gb.get_somatic_mutation(source="washu")
# Out:
#                 Gene           Mutation      Location      Database_ID
# Patient_ID
# C3L-00104       GJB4             Silent        p.R98R  ENST00000339480
# C3L-00104     CYP4B1  Missense_Mutation        p.T64M  ENST00000371923
# C3L-00104       HFM1  Missense_Mutation       p.L531F  ENST00000370425
# C3L-00104      INTS3  Missense_Mutation        p.H86Y  ENST00000318967
# C3L-00104     CFAP45  Missense_Mutation       p.R393H  ENST00000368099
# C3L-00104      IGFN1  Missense_Mutation      p.A1536T  ENST00000335211
# C3L-00104    ZC3H11A  Missense_Mutation        p.D91H  ENST00000545588
# C3L-00104       MYCN  Missense_Mutation        p.P44L  ENST00000281043
# C3L-00104    C2orf16  Missense_Mutation      p.P1187R  ENST00000408964
# C3L-00104    TMEM247  Missense_Mutation       p.Q153R  ENST00000434431
# C3L-00104        TTN  Missense_Mutation     p.R12289H  ENST00000589042
# C3L-00104      STAT4  Missense_Mutation       p.G618R  ENST00000392320
# ...

# %%
gb.get_proteomics(source="umich")
# Out:
# Proteins              ARF5-201          M6PR-201          ESRRA-201  \
# Database_ID ENSG00000004059.11 ENSG00000003056.8 ENSG00000173153.16
# Patient_ID
# C3L-00104            -0.254733         -0.138938           0.662227
# C3L-00365            -0.138512         -0.824520           0.494419
# C3L-00674            -0.351464         -0.120197          -0.084371
# C3L-00677            -0.062869          0.094198           0.391070
# C3L-01040            -0.365351          0.070523          -0.472543
# C3L-01043            -0.296915         -0.121120           0.349955
# C3L-01045             0.037365         -0.652065          -0.248141
# C3L-01046             0.075397          0.932390          -0.110516
# C3L-01048            -0.809921         -0.132927           0.403992
# C3L-01049            -0.073592          0.154447           0.385628
# C3L-01061             0.195500         -0.093353          -0.076683
# C3L-01142             0.039818          0.848821           0.376597
# ...

# %% [markdown]
# ### PDC data
#
# Again, we can also access data from the PDC.

# %%
gb.get_proteomics(source="pdc")
# Out:
#                                 A1BG     A2M    AAAS    AACS   AADAT   AAGAB  \
# Patient_ID
# C3L-00104                    -0.0412  0.2351  0.0018 -0.0782  0.6141 -0.5695
# C3L-00365                     0.1100  0.4324  0.2045 -0.6951     NaN  0.1336
# C3L-00674                     0.4574  0.7025  0.0951 -0.2422  0.0728  0.1744
# C3L-00677                     0.0359 -0.0541  0.1592 -0.1692 -0.0839  0.1231
# C3L-01040                    -0.4924 -0.7171  0.0256 -0.4839  0.3248 -0.1811
# C3L-01043                     0.5746  0.4742  0.0008 -0.2919 -0.5499 -0.0724
# C3L-01045                    -0.1602 -0.7021  0.1348 -0.4426 -0.4586  0.3336
# C3L-01046                    -0.2839 -0.2529  0.2834 -0.0450 -0.7014 -0.0970
# C3L-01048                    -0.4551 -0.5562  0.1733  0.0855 -0.3963 -0.1499
# C3L-01049                    -0.1281 -0.3739  0.1697 -0.2256     NaN  0.1728
# C3L-01061                    -0.1379 -0.0096  0.2052 -0.1722 -0.1227 -0.1052
# ...

# %%
gb.get_clinical(source="pdc")
# Out:
#                               age_at_diagnosis  ajcc_clinical_m  \
# case_submitter_id
# C3L-00104                              21170.0              NaN
# C3L-00365                              21535.0              NaN
# C3L-00674                              16425.0              NaN
# C3L-00677                              25185.0              NaN
# C3L-01040                              28105.0              NaN
# C3L-01043                              21535.0              NaN
# C3L-01045                              26645.0              NaN
# C3L-01046                              18250.0              NaN
# C3L-01048                              21900.0              NaN
# C3L-01049                              16790.0              NaN
# C3L-01061                              24090.0              NaN
# C3L-01142                              15330.0              NaN
# C3L-01146                              21535.0              NaN
# ...
