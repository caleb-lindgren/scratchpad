# %% [markdown]
# # Pancancer enrichment analysis step 7: Make figures from GSEApy data

# %% [markdown]
# ## Setup

# %%
import os
import datetime
import altair as alt
import numpy as np
import pandas as pd
import operator
import IPython.display

# %%
TIME_START = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

# Step 1 output
STEP01_DIR = "step01_outputs"
STEP01_FILE = "tumor_change_20200529_195104_10000_perm.tsv"
STEP01_FILE_PATH = os.path.join(STEP01_DIR, STEP01_FILE)

# Step 5 outputs
STEP05_DIR = "step05_outputs"

STEP05_abs_signal_to_noise = os.path.join(STEP05_DIR, "enrichment_gseapy_reactome_20200617_192305_10000_perms_abs_signal_to_noise.tsv")
STEP05_diff_of_classes = os.path.join(STEP05_DIR, "enrichment_gseapy_reactome_20200617_192305_10000_perms_diff_of_classes.tsv")
STEP05_log2_ratio_of_classes = os.path.join(STEP05_DIR, "enrichment_gseapy_reactome_20200617_192305_10000_perms_log2_ratio_of_classes.tsv")
STEP05_ratio_of_classes = os.path.join(STEP05_DIR, "enrichment_gseapy_reactome_20200617_192305_10000_perms_ratio_of_classes.tsv")
STEP05_signal_to_noise = os.path.join(STEP05_DIR, "enrichment_gseapy_reactome_20200617_192305_10000_perms_signal_to_noise.tsv")
STEP05_t_test = os.path.join(STEP05_DIR, "enrichment_gseapy_reactome_20200617_192305_10000_perms_t_test.tsv")

# Step 6 output
STEP06_DIR = "step06_outputs"

STEP06_S2N = "enrichment_gseapy_kegg_signal_to_noise_10000_perms_20200617_072701.tsv"
STEP06_S2N_PATH = os.path.join(STEP06_DIR, STEP06_S2N)

STEP06_ABS_S2N = "enrichment_gseapy_kegg_abs_signal_to_noise_10000_perms_20200617_103905.tsv"
STEP06_ABS_S2N_PATH = os.path.join(STEP06_DIR, STEP06_ABS_S2N)

MSV = 0.5 # Simplified expression value for marginally significant proteins

# %%
# Altair options
# alt.data_transformers.disable_max_rows()
# alt.data_transformers.enable('json')

# %% [markdown]
# ## Function to plot top pathways across cancer types

# %%
def plot_top_ten(enrich_file_path, expr_file_path, xtitle, fdr=0.3):
    
    # Read in the expression data
    all_expression_data = pd.read_csv(expr_file_path, sep="\t", index_col=0)

    # Make a column where all increases are +1 and all decreases 
    # are -1, because these are ratioed abundances, so we can't 
    # compare magnitudes between genes--we can only compare whether 
    # there was a change, and whether it was positive or negative
    all_expression_data = all_expression_data.assign(simplified_change=np.nan)

    # adj p < 0.05 and change > 1 => +1
    all_expression_data.loc[
        (all_expression_data["change"] > 0) & (all_expression_data["adj_p"] < 0.05), 
        "simplified_change"
    ] = 1

    # adj p >= 0.05 and change > 1 => +0.5
    all_expression_data.loc[(all_expression_data["change"] > 0) & (all_expression_data["adj_p"] >= 0.05),
        "simplified_change"
    ] = MSV

    # change == 0 => 0
    all_expression_data.loc[
        all_expression_data["change"] == 0,
        "simplified_change"
    ] = 0

    # adj p >= 0.05 and change < 1 => -0.5
    all_expression_data.loc[(all_expression_data["change"] < 0) & (all_expression_data["adj_p"] >= 0.05), 
        "simplified_change"
    ] = -MSV

    # adj p < 0.05 and change < 1 => -1
    all_expression_data.loc[
        (all_expression_data["change"] < 0) & (all_expression_data["adj_p"] < 0.05),
        "simplified_change"
    ] = -1

    # Select just the proteins where we chose to reject the null hypothesis of no change
    expression_data = all_expression_data[all_expression_data["reject_null"]]

    # Read in the enrichment data
    enrichment_data = pd.read_csv(enrich_file_path, sep="\t")
    
    # Select enrichment data below our FDR
    enrichment_data = enrichment_data.loc[enrichment_data["fdr"] <= fdr, :]
    
    # Make a column for abs_nes
    enrichment_data = enrichment_data.assign(abs_nes=enrichment_data["nes"].abs())

    # Assign pathway ranks within each cancer type based on absolute value of NES
    enrichment_data = enrichment_data.\
        assign(cancer_rank_abs_nes=enrichment_data.groupby("cancer_type")["abs_nes"].rank(ascending=False)).\
        sort_values(by=["cancer_type", "cancer_rank_abs_nes"]).\
        reset_index(drop=True)

    # Make a table with summary info for all pathways
    enrichment_summary = enrichment_data[["Term"]].drop_duplicates(keep="first")

    pathway_times_enriched = enrichment_summary["Term"].apply(
        lambda x: enrichment_data[enrichment_data["Term"] == x].shape[0])

    avg_rank = enrichment_summary["Term"].apply(
        lambda x: enrichment_data.loc[enrichment_data["Term"] == x, "cancer_rank_abs_nes"].mean())

    enrichment_summary = enrichment_summary.\
        assign(
            pathway_times_enriched=pathway_times_enriched,
            pathway_avg_rank=avg_rank).\
        sort_values(
            by=["pathway_times_enriched", "pathway_avg_rank"],
            ascending=[False, True]).\
        reset_index(drop=True)

    # Merge in the original enrichment data
    enrichment_data = enrichment_data.\
        merge(
            enrichment_summary,
            how="outer",
            left_on="Term",
            right_on="Term",
            validate="many_to_one"
        ).\
        sort_values(
            by=["pathway_times_enriched", "pathway_avg_rank", "cancer_type"],
            ascending=[False, True, True]
        )

    # Select top 10 for our plot
    
    in_all = enrichment_summary.loc[
        enrichment_summary["pathway_times_enriched"] == 8,
        "Term"
    ]
    
    if in_all.size <= 10:
        top_ten = in_all
    else:
        top_ten = in_all[:10]
    
    sel_enrich = enrichment_data[enrichment_data["Term"].isin(top_ten)]

    # Calculate the mean expression for each pathway in each cancer type
    mean_exprs = []

    for idx in sel_enrich.index:
        genes = sel_enrich.loc[idx, "genes"].split(";")
        cancer_type = sel_enrich.loc[idx, "cancer_type"]

        genes_expr = expression_data.loc[
            expression_data["protein_str"].isin(genes) &
            (expression_data["cancer_type"] == cancer_type),
            "simplified_change"
        ].mean()

        mean_exprs.append(genes_expr)

    sel_enrich = sel_enrich.assign(mean_expr=mean_exprs)

    sel_enrich = sel_enrich.assign(
        rank_size=1 / sel_enrich["cancer_rank_abs_nes"],
        avg_rank_size=1 / sel_enrich["pathway_avg_rank"],
        avg_rank_label=sel_enrich["pathway_avg_rank"].apply(round, 2).astype(str))
    
    # Take care of duplicates for the upper plot
    for i in range(10):
        sel_enrich["avg_rank_label"] = sel_enrich["avg_rank_label"].where(
            cond=~(sel_enrich.duplicated(subset=["cancer_type", "avg_rank_label"], keep="first")),
            other=" " + sel_enrich["avg_rank_label"])

    individual = alt.Chart(sel_enrich).mark_circle().encode(
        x=alt.X(
            "Term:N",
            sort=sel_enrich["Term"].values,
            axis=alt.Axis(
                labelAngle=-30,
                labelFontSize=12,
                labelLimit=500,
                title="",
                titleFontSize=16
            )
        ),
        y=alt.Y(
            "cancer_type:N",
            axis=alt.Axis(
                title="Cancer type",
                titleFontSize=12
            ),
        ),
        size=alt.Size(
            "rank_size:Q",
            legend=None
        ),
        color=alt.Color(
            "mean_expr:Q",
            scale=alt.Scale(
                scheme="blueorange",
                domain=[-1, 1]
            ),
            legend=alt.Legend(
                title="Pathway tumor expression"
            )
        )
    ).properties(
        width=400,
        height=300
    )

    aggregate = alt.Chart(sel_enrich).mark_circle().encode(
        x=alt.X(
            "avg_rank_label:N",
            sort=sel_enrich["avg_rank_label"].values,
            axis=alt.Axis(
                labelAngle=-30,
                labelFontSize=12,
                labelLimit=500,
                title="Overall rank of pathway",
                titleFontSize=12
            )
        ),
        size=alt.Size(
            "avg_rank_size:Q",
            legend=None
        ),
    ).properties(
        width=400
    )

    full_plot = alt.vconcat(
        aggregate, individual
    ).properties(
        title=xtitle
    )
    
    return full_plot, enrichment_data, all_expression_data, enrichment_summary

# %%
alt.vconcat(
    plot_top_ten(STEP05_abs_signal_to_noise, STEP01_FILE_PATH, "Reactome data - proteins ranked by abs_signal_to_noise")[0],
    plot_top_ten(STEP05_diff_of_classes, STEP01_FILE_PATH, "Reactome data - proteins ranked by diff_of_classes")[0],
    plot_top_ten(STEP05_log2_ratio_of_classes, STEP01_FILE_PATH, "Reactome data - proteins ranked by log2_ratio_of_classes")[0],
    plot_top_ten(STEP05_ratio_of_classes, STEP01_FILE_PATH, "Reactome data - proteins ranked by ratio_of_classes")[0],
    plot_top_ten(STEP05_signal_to_noise, STEP01_FILE_PATH, "Reactome data - proteins ranked by signal_to_noise")[0],
    plot_top_ten(STEP05_t_test, STEP01_FILE_PATH, "GSEA - proteins ranked by t_test")[0],
    
    plot_top_ten(STEP06_ABS_S2N_PATH, STEP01_FILE_PATH, "KEGG data - proteins ranked by |S2N|")[0],
    plot_top_ten(STEP06_S2N_PATH, STEP01_FILE_PATH, "KEGG data - proteins ranked by S2N")[0],
).configure_axis(
    grid=True
).configure_title(
    fontSize=16,
    anchor="end",
    offset=20
).resolve_scale(
    size="independent"
)
# Out:
# alt.VConcatChart(...)

# %%
plot_top_ten(STEP05_abs_signal_to_noise, STEP01_FILE_PATH, "Reactome data - proteins ranked by abs_signal_to_noise")[3]
# Out:
#                                                   Term  \
# 0                       Terminal pathway of complement
# 1    Erythrocytes take up oxygen and release carbon...
# 2    Defective factor XII causes hereditary angioedema
# 3                              Amine Oxidase reactions
# 4    Biogenic amines are oxidatively deaminated to ...
# 5       Defective MAOA causes Brunner syndrome (BRUNS)
# 6        Glyoxylate metabolism and glycine degradation
# 7           RNA Polymerase II Pre-transcription Events
# 8      Retrograde transport at the Trans-Golgi-Network
# 9    Class C/3 (Metabotropic glutamate/pheromone re...
# 10                    O-linked glycosylation of mucins
# 11                                  DAP12 interactions
# 12     Export of Viral Ribonucleoproteins from Nucleus
# 13                                   Inhibition of PKR
# 14                             Activation of C3 and C5
# 15          Formation of RNA Pol II elongation complex
# 16          RNA Polymerase II Transcription Elongation
# 17                  Lysosphingolipid and LPA receptors
# 18         RNA Polymerase III Transcription Initiation
# 19   Defective SLC7A7 causes lysinuric protein into...
# 20           RNA Polymerase I Transcription Initiation
# 21   TFAP2A acts as a transcriptional repressor dur...
# 22     Defective SERPING1 causes hereditary angioedema
# 23   RNA Polymerase III Transcription Initiation Fr...
# 24   RNA Polymerase III Transcription Initiation Fr...
# 25   Defective POMGNT1 causes MDDGA3, MDDGB3 and MD...
# 26    Defective POMT1 causes MDDGA1, MDDGB1 and MDDGC1
# 27    Defective POMT2 causes MDDGA2, MDDGB2 and MDDGC2
# 28       Inhibition of Signaling by Overexpressed EGFR
# 29   Signaling by Overexpressed Wild-Type EGFR in C...
# ..                                                 ...
# 94                                Complex I biogenesis
# 95                            Propionyl-CoA catabolism
# 96   Interconversion of 2-oxoglutarate and 2-hydrox...
# 97                                 Degradation of GABA
# 98   Defective AMN causes hereditary megaloblastic ...
# 99   Defective CUBN causes hereditary megaloblastic...
# 100                   Defective NEU1 causes sialidosis
# 101   Defective SLC5A2 causes renal glucosuria (GLYS1)
# 102  Defective SLC12A1 causes Bartter syndrome 1 (BS1)
# 103                     Respiratory electron transport
# 104               Defective ACY1 causes encephalopathy
# 105                           UNC93B1 deficiency - HSE
# 106  Defective HLCS causes multiple carboxylase def...
# 107                                    Phenylketonuria
# 108                    Hereditary fructose intolerance
# 109               Serotonin and melatonin biosynthesis
# 110  Defective GNE causes sialuria, Nonaka myopathy...
# 111  Biosynthesis of DPAn-3-derived 13-series resol...
# 112            Biosynthesis of DPAn-3-derived maresins
# 113  Biosynthesis of DPAn-3-derived protectins and ...
# 114                Blockage of phagosome acidification
# 115                              Agmatine biosynthesis
# 116  Defective SLC2A1 causes GLUT1 deficiency syndr...
# 117        Conjugation of phenylacetate with glutamine
# 118                               Essential pentosuria
# 119                             Ubiquinol biosynthesis
# 120  Respiratory electron transport, ATP synthesis ...
# 121                LTC4-CYSLTR mediated IL4 production
# 122                              TLR3 deficiency - HSE
# 123    Defective SLC6A19 causes Hartnup disorder (HND)
#
#      pathway_times_enriched  pathway_avg_rank
# 0                         3          2.333333
# 1                         2          1.000000
# 2                         2          5.000000
# 3                         2          8.000000
# 4                         2          8.000000
# 5                         2         14.500000
# 6                         2         45.500000
# 7                         1          1.000000
# 8                         1          1.000000
# 9                         1          1.000000
# 10                        1          1.000000
# 11                        1          2.000000
# 12                        1          2.000000
# 13                        1          2.000000
# 14                        1          2.000000
# 15                        1          2.500000
# 16                        1          2.500000
# 17                        1          3.000000
# 18                        1          4.000000
# 19                        1          4.000000
# 20                        1          5.000000
# 21                        1          5.000000
# 22                        1          5.000000
# 23                        1          6.000000
# 24                        1          7.000000
# 25                        1          7.000000
# 26                        1          7.000000
# 27                        1          7.000000
# 28                        1          7.500000
# 29                        1          7.500000
# ..                      ...               ...
# 94                        1         63.000000
# 95                        1         64.000000
# 96                        1         65.000000
# 97                        1         66.000000
# 98                        1         67.500000
# 99                        1         67.500000
# 100                       1         69.000000
# 101                       1         70.000000
# 102                       1         71.000000
# 103                       1         72.000000
# 104                       1         73.000000
# 105                       1         74.000000
# 106                       1         75.000000
# 107                       1         76.000000
# 108                       1         77.000000
# 109                       1         78.000000
# 110                       1         79.000000
# 111                       1         81.000000
# 112                       1         81.000000
# 113                       1         81.000000
# 114                       1         83.000000
# 115                       1         84.000000
# 116                       1         85.000000
# 117                       1         86.000000
# 118                       1         87.000000
# 119                       1         88.000000
# 120                       1         89.000000
# 121                       1         91.000000
# 122                       1         92.000000
# 123                       1         93.000000
#
# [124 rows x 3 columns]

# %%
plot_top_ten(STEP05_diff_of_classes, STEP01_FILE_PATH, "Reactome data - proteins ranked by diff_of_classes")[3]
# Out:
#                                                   Term  \
# 0    Major pathway of rRNA processing in the nucleo...
# 1    Activation of the mRNA upon binding of the cap...
# 2       Ribosomal scanning and start codon recognition
# 3             Translation initiation complex formation
# 4    Transport of Mature mRNA Derived from an Intro...
# 5                NS1 Mediated Effects on Host Pathways
# 6                        mRNA Splicing - Major Pathway
# 7                         Metabolism of non-coding RNA
# 8                                       snRNP Assembly
# 9          Transport of the SLBP Dependant Mature mRNA
# 10       Transport of the SLBP independent Mature mRNA
# 11                                     tRNA processing
# 12          Formation of RNA Pol II elongation complex
# 13          RNA Polymerase II Transcription Elongation
# 14          rRNA processing in the nucleus and cytosol
# 15            SUMOylation of ubiquitinylation proteins
# 16                                 Influenza Infection
# 17                 SUMOylation of RNA binding proteins
# 18                     Transcription of the HIV genome
# 19             SUMOylation of DNA replication proteins
# 20   Nonsense Mediated Decay (NMD) enhanced by the ...
# 21                       Nonsense-Mediated Decay (NMD)
# 22   Influenza Viral RNA Transcription and Replication
# 23                 RNA Polymerase I Promoter Clearance
# 24           NoRC negatively regulates rRNA expression
# 25   Gap-filling DNA repair synthesis and ligation ...
# 26                   Eukaryotic Translation Elongation
# 27                Cap-dependent Translation Initiation
# 28                   Eukaryotic Translation Initiation
# 29   Formation of HIV elongation complex in the abs...
# ..                                                 ...
# 512                      Synthesis of diphthamide-EEF2
# 513  Activation, myristolyation of BID and transloc...
# 514                    G2/M DNA replication checkpoint
# 515  Resolution of AP sites via the single-nucleoti...
# 516            Post-chaperonin tubulin folding pathway
# 517  Gene and protein expression by JAK-STAT signal...
# 518  InlB-mediated entry of Listeria monocytogenes ...
# 519                        MicroRNA (miRNA) biogenesis
# 520       Synthesis of very long-chain fatty acyl-CoAs
# 521                                         Glycolysis
# 522               rRNA processing in the mitochondrion
# 523  APEX1-Independent Resolution of AP Sites via t...
# 524                       Folding of actin by CCT/TriC
# 525                 Estrogen-dependent gene expression
# 526  Cooperation of Prefoldin and TriC/CCT  in acti...
# 527   Assembly of Viral Components at the Budding Site
# 528                         Virus Assembly and Release
# 529  Negative regulation of activity of TFAP2 (AP-2...
# 530  Binding of TCF/LEF:CTNNB1 to target gene promo...
# 531                      RUNX3 regulates WNT signaling
# 532           Displacement of DNA glycosylase by APEX1
# 533                                      vRNP Assembly
# 534                 Glutamate and glutamine metabolism
# 535  NR1H2 & NR1H3 regulate gene expression linked ...
# 536                               ER-Phagosome pathway
# 537            Synthesis of dolichyl-phosphate-glucose
# 538  Insulin effects increased synthesis of Xylulos...
# 539  Abasic sugar-phosphate removal via the single-...
# 540  NOTCH1 Intracellular Domain Regulates Transcri...
# 541  RUNX1 regulates transcription of genes involve...
#
#      pathway_times_enriched  pathway_avg_rank
# 0                         5            35.800
# 1                         5            66.400
# 2                         5            70.800
# 3                         5            73.400
# 4                         4            13.250
# 5                         4            17.250
# 6                         4            19.500
# 7                         4            23.500
# 8                         4            23.500
# 9                         4            31.250
# 10                        4            36.000
# 11                        4            36.750
# 12                        4            41.000
# 13                        4            41.000
# 14                        4            41.250
# 15                        4            42.750
# 16                        4            42.750
# 17                        4            43.250
# 18                        4            46.000
# 19                        4            47.000
# 20                        4            47.500
# 21                        4            47.500
# 22                        4            52.750
# 23                        4            53.625
# 24                        4            54.500
# 25                        4            60.500
# 26                        4            61.750
# 27                        4            62.000
# 28                        4            62.000
# 29                        4            63.250
# ..                      ...               ...
# 512                       1           363.000
# 513                       1           365.000
# 514                       1           368.000
# 515                       1           369.000
# 516                       1           369.000
# 517                       1           370.000
# 518                       1           371.000
# 519                       1           372.000
# 520                       1           373.000
# 521                       1           373.000
# 522                       1           374.000
# 523                       1           375.000
# 524                       1           377.000
# 525                       1           383.000
# 526                       1           383.000
# 527                       1           384.500
# 528                       1           384.500
# 529                       1           385.000
# 530                       1           386.500
# 531                       1           386.500
# 532                       1           388.000
# 533                       1           392.000
# 534                       1           395.000
# 535                       1           400.000
# 536                       1           403.000
# 537                       1           404.000
# 538                       1           405.000
# 539                       1           407.000
# 540                       1           408.000
# 541                       1           409.000
#
# [542 rows x 3 columns]

# %%
plot_top_ten(STEP05_log2_ratio_of_classes, STEP01_FILE_PATH, "Reactome data - proteins ranked by log2_ratio_of_classes")[3]
# Out:
# Empty DataFrame
# Columns: [Term, pathway_times_enriched, pathway_avg_rank]
# Index: []

# %%
plot_top_ten(STEP05_ratio_of_classes, STEP01_FILE_PATH, "Reactome data - proteins ranked by ratio_of_classes")[3]
# Out:
#                                                   Term  \
# 0          Toxicity of botulinum toxin type D (BoNT/D)
# 1          Toxicity of botulinum toxin type F (BoNT/F)
# 2    Synthesis of 12-eicosatetraenoic acid derivatives
# 3                         Myoclonic epilepsy of Lafora
# 4                      Passive transport by Aquaporins
# 5                                 CREB phosphorylation
# 6                 Hypusine synthesis from eIF5A-lysine
# 7                         IKBKB deficiency causes SCID
# 8    IKBKG deficiency causes anhidrotic ectodermal ...
# 9                                   Potassium Channels
# 10                                      p38MAPK events
# 11       Activated NTRK2 signals through FRS2 and FRS3
# 12                    Biosynthesis of DPA-derived SPMs
# 13                         Biosynthesis of DPAn-3 SPMs
# 14                                   Signalling to RAS
# 15                               MAPK1/MAPK3 signaling
# 16                                      FLT3 Signaling
# 17                              RAF/MAP kinase cascade
# 18          Miscellaneous transport and binding events
# 19                            Interleukin-18 signaling
# 20                      MAPK family signaling cascades
# 21                                     Glucuronidation
# 22                       Signaling by FGFR4 in disease
# 23                           Signaling by NTRK2 (TRKB)
# 24              mRNA decay by 5' to 3' exoribonuclease
# 25   Defective MMAB causes methylmalonic aciduria t...
# 26                                  Muscle contraction
# 27                                   Signaling by GPCR
# 28   TFAP2 (AP-2) family regulates transcription of...
# 29                        Prolactin receptor signaling
# ..                                                 ...
# 459               Signaling by FGFR3 fusions in cancer
# 460                           Metabolism of porphyrins
# 461                      Signaling by PDGFR in disease
# 462  Defective SLC5A1 causes congenital glucose/gal...
# 463                              Intestinal absorption
# 464                       Intestinal hexose absorption
# 465                        Signaling by Erythropoietin
# 466              NCAM signaling for neurite out-growth
# 467                               Collagen degradation
# 468                          Signaling by NTRK3 (TRKC)
# 469                      SHC1 events in EGFR signaling
# 470                              Pyrimidine catabolism
# 471                            TICAM1 deficiency - HSE
# 472                              TLR3 deficiency - HSE
# 473                                 DAP12 interactions
# 474           Generation of second messenger molecules
# 475                                 NCAM1 interactions
# 476  Constitutive Signaling by Ligand-Responsive EG...
# 477                        Signaling by EGFR in Cancer
# 478  Signaling by Ligand-Responsive EGFR Variants i...
# 479                      ERBB2 Regulates Cell Motility
# 480                   The activation of arylsulfatases
# 481                                     RAS processing
# 482                 Constitutive Signaling by EGFRvIII
# 483                    Signaling by EGFRvIII in Cancer
# 484  BH3-only proteins associate with and inactivat...
# 485                        MET activates RAS signaling
# 486                                    DAP12 signaling
# 487  RUNX1 regulates transcription of genes involve...
# 488                                    HSF1 activation
#
#      pathway_times_enriched  pathway_avg_rank
# 0                         2             28.75
# 1                         2             28.75
# 2                         2             29.50
# 3                         2             36.50
# 4                         2             36.50
# 5                         2             46.50
# 6                         2             53.50
# 7                         2             66.00
# 8                         2             66.00
# 9                         2             75.00
# 10                        2             78.00
# 11                        2             92.00
# 12                        2             93.50
# 13                        2             93.50
# 14                        2             96.50
# 15                        2            100.50
# 16                        2            105.50
# 17                        2            105.50
# 18                        2            115.50
# 19                        2            117.50
# 20                        2            118.00
# 21                        2            128.00
# 22                        2            148.00
# 23                        2            151.00
# 24                        1              1.00
# 25                        1              1.00
# 26                        1              1.00
# 27                        1              1.00
# 28                        1              1.00
# 29                        1              1.00
# ..                      ...               ...
# 459                       1            190.00
# 460                       1            191.00
# 461                       1            194.00
# 462                       1            196.00
# 463                       1            196.00
# 464                       1            196.00
# 465                       1            198.00
# 466                       1            199.00
# 467                       1            201.00
# 468                       1            202.00
# 469                       1            204.00
# 470                       1            205.00
# 471                       1            206.50
# 472                       1            206.50
# 473                       1            208.00
# 474                       1            209.00
# 475                       1            210.00
# 476                       1            212.00
# 477                       1            212.00
# 478                       1            212.00
# 479                       1            214.00
# 480                       1            215.00
# 481                       1            216.00
# 482                       1            217.50
# 483                       1            217.50
# 484                       1            219.00
# 485                       1            220.00
# 486                       1            221.00
# 487                       1            223.00
# 488                       1            224.00
#
# [489 rows x 3 columns]

# %%
plot_top_ten(STEP05_signal_to_noise, STEP01_FILE_PATH, "Reactome data - proteins ranked by signal_to_noise")[3]
# Out:
#                                                    Term  \
# 0     Paradoxical activation of RAF signaling by kin...
# 1                              Signaling by RAS mutants
# 2     Signaling by moderate kinase activity BRAF mut...
# 3                   Signaling downstream of RAS mutants
# 4                             Signaling by RAF1 mutants
# 5                 NCAM signaling for neurite out-growth
# 6                         G alpha (q) signalling events
# 7                                  Platelet homeostasis
# 8       PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling
# 9                                   GPCR ligand binding
# 10                     Host Interactions of HIV factors
# 11                                   Potassium Channels
# 12    Vasopressin regulates renal water homeostasis ...
# 13                         Aquaporin-mediated transport
# 14    Influenza Viral RNA Transcription and Replication
# 15                    G alpha (12/13) signalling events
# 16            ADP signalling through P2Y purinoceptor 1
# 17                     Extra-nuclear estrogen signaling
# 18                        G alpha (s) signalling events
# 19                                 G-protein activation
# 20                                 Signal amplification
# 21                      Inwardly rectifying K+ channels
# 22                            G-protein mediated events
# 23       Signaling by high-kinase activity BRAF mutants
# 24                             GABA receptor activation
# 25                       Glucagon-type ligand receptors
# 26                    Signaling by BRAF and RAF fusions
# 27                        Activation of GABAB receptors
# 28                           GABA B receptor activation
# 29         Response of EIF2AK1 (HRI) to heme deficiency
# ...                                                 ...
# 1702            Modulation by Mtb of host immune system
# 1703            Pre-NOTCH Transcription and Translation
# 1704  NOTCH3 Intracellular Domain Regulates Transcri...
# 1705  TNF receptor superfamily (TNFSF) members media...
# 1706  Classical antibody-mediated complement activation
# 1707                   Wax and plasmalogen biosynthesis
# 1708               Budding and maturation of HIV virion
# 1709  Defective B3GALTL causes Peters-plus syndrome ...
# 1710  Inactivation, recovery and regulation of the p...
# 1711                      The phototransduction cascade
# 1712  Defective CYP11A1 causes Adrenal insufficiency...
# 1713        Electron transport from NADPH to Ferredoxin
# 1714  RUNX1 regulates transcription of genes involve...
# 1715                 Biosynthesis of D-series resolvins
# 1716                                  Inhibition of PKR
# 1717  POU5F1 (OCT4), SOX2, NANOG activate genes rela...
# 1718             Signaling by the B Cell Receptor (BCR)
# 1719         Defective SLC26A2 causes chondrodysplasias
# 1720        Defective BTD causes biotidinase deficiency
# 1721               RUNX3 regulates CDKN1A transcription
# 1722                                  Lactose synthesis
# 1723                           Interleukin-23 signaling
# 1724                               Essential pentosuria
# 1725                   The activation of arylsulfatases
# 1726     Synthesis of Leukotrienes (LT) and Eoxins (EX)
# 1727     Defective MAOA causes Brunner syndrome (BRUNS)
# 1728  Defective CP causes aceruloplasminemia (ACERULOP)
# 1729  Defective SLC40A1 causes hemochromatosis 4 (HF...
# 1730                                    DNA methylation
# 1731                           Suppression of autophagy
#
#       pathway_times_enriched  pathway_avg_rank
# 0                          8        160.625000
# 1                          8        160.625000
# 2                          8        160.625000
# 3                          8        160.625000
# 4                          8        192.875000
# 5                          7         70.428571
# 6                          7         74.857143
# 7                          7        109.142857
# 8                          7        129.428571
# 9                          7        137.000000
# 10                         7        138.428571
# 11                         7        138.714286
# 12                         7        149.071429
# 13                         7        152.642857
# 14                         7        154.285714
# 15                         7        160.857143
# 16                         7        165.428571
# 17                         7        188.857143
# 18                         7        195.142857
# 19                         7        221.857143
# 20                         7        236.714286
# 21                         7        250.142857
# 22                         7        251.500000
# 23                         7        255.857143
# 24                         7        256.571429
# 25                         7        257.071429
# 26                         7        262.857143
# 27                         7        263.785714
# 28                         7        263.785714
# 29                         7        270.428571
# ...                      ...               ...
# 1702                       1       1004.000000
# 1703                       1       1010.000000
# 1704                       1       1019.000000
# 1705                       1       1020.000000
# 1706                       1       1024.000000
# 1707                       1       1025.000000
# 1708                       1       1027.000000
# 1709                       1       1028.000000
# 1710                       1       1040.500000
# 1711                       1       1040.500000
# 1712                       1       1043.500000
# 1713                       1       1043.500000
# 1714                       1       1054.000000
# 1715                       1       1055.000000
# 1716                       1       1056.000000
# 1717                       1       1062.000000
# 1718                       1       1065.000000
# 1719                       1       1066.000000
# 1720                       1       1068.000000
# 1721                       1       1069.000000
# 1722                       1       1070.000000
# 1723                       1       1077.000000
# 1724                       1       1079.000000
# 1725                       1       1081.000000
# 1726                       1       1083.000000
# 1727                       1       1086.000000
# 1728                       1       1088.500000
# 1729                       1       1088.500000
# 1730                       1       1094.000000
# 1731                       1       1096.000000
#
# [1732 rows x 3 columns]

# %%
plot_top_ten(STEP05_t_test, STEP01_FILE_PATH, "Reactome data - proteins ranked by t_test")[3]
# Out:
#                                                    Term  \
# 0     Paradoxical activation of RAF signaling by kin...
# 1                              Signaling by RAS mutants
# 2     Signaling by moderate kinase activity BRAF mut...
# 3                   Signaling downstream of RAS mutants
# 4                             Signaling by RAF1 mutants
# 5                     Signaling by BRAF and RAF fusions
# 6                 NCAM signaling for neurite out-growth
# 7                         G alpha (q) signalling events
# 8                                  Platelet homeostasis
# 9       PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling
# 10    Activation of kainate receptors upon glutamate...
# 11                                   Potassium Channels
# 12                                  GPCR ligand binding
# 13                     Host Interactions of HIV factors
# 14    Vasopressin regulates renal water homeostasis ...
# 15                         Aquaporin-mediated transport
# 16    Influenza Viral RNA Transcription and Replication
# 17            ADP signalling through P2Y purinoceptor 1
# 18                    G alpha (12/13) signalling events
# 19                     Extra-nuclear estrogen signaling
# 20                        G alpha (s) signalling events
# 21    Glucagon-like Peptide-1 (GLP1) regulates insul...
# 22                                 G-protein activation
# 23                                 Signal amplification
# 24                             PLC beta mediated events
# 25                      Inwardly rectifying K+ channels
# 26                            G-protein mediated events
# 27       Signaling by high-kinase activity BRAF mutants
# 28                             GABA receptor activation
# 29                       Glucagon-type ligand receptors
# ...                                                 ...
# 1696  Phosphorylation of proteins involved in the G2...
# 1697                                Degradation of GABA
# 1698                Negative regulation of MET activity
# 1699            Pre-NOTCH Transcription and Translation
# 1700                                      HDL clearance
# 1701     Beta oxidation of myristoyl-CoA to lauroyl-CoA
# 1702  TNF receptor superfamily (TNFSF) members media...
# 1703               RUNX3 regulates CDKN1A transcription
# 1704            Modulation by Mtb of host immune system
# 1705  Classical antibody-mediated complement activation
# 1706               Budding and maturation of HIV virion
# 1707                     Glycerophospholipid catabolism
# 1708                                Fructose catabolism
# 1709  NOTCH3 Intracellular Domain Regulates Transcri...
# 1710  POU5F1 (OCT4), SOX2, NANOG activate genes rela...
# 1711                   Wax and plasmalogen biosynthesis
# 1712  Defective CYP11A1 causes Adrenal insufficiency...
# 1713        Electron transport from NADPH to Ferredoxin
# 1714  RUNX1 regulates transcription of genes involve...
# 1715                 Biosynthesis of D-series resolvins
# 1716             Signaling by the B Cell Receptor (BCR)
# 1717                                  Inhibition of PKR
# 1718  Inactivation, recovery and regulation of the p...
# 1719                      The phototransduction cascade
# 1720         Defective SLC26A2 causes chondrodysplasias
# 1721        Defective BTD causes biotidinase deficiency
# 1722                   The activation of arylsulfatases
# 1723  POU5F1 (OCT4), SOX2, NANOG repress genes relat...
# 1724                               Essential pentosuria
# 1725                                    DNA methylation
#
#       pathway_times_enriched  pathway_avg_rank
# 0                          8        158.625000
# 1                          8        158.625000
# 2                          8        158.625000
# 3                          8        158.625000
# 4                          8        194.625000
# 5                          8        288.500000
# 6                          7         72.285714
# 7                          7         82.142857
# 8                          7        111.285714
# 9                          7        122.571429
# 10                         7        131.857143
# 11                         7        137.857143
# 12                         7        142.571429
# 13                         7        152.714286
# 14                         7        153.214286
# 15                         7        154.500000
# 16                         7        155.285714
# 17                         7        163.285714
# 18                         7        173.285714
# 19                         7        178.285714
# 20                         7        198.857143
# 21                         7        214.714286
# 22                         7        228.571429
# 23                         7        231.285714
# 24                         7        244.500000
# 25                         7        245.428571
# 26                         7        246.357143
# 27                         7        246.857143
# 28                         7        255.000000
# 29                         7        257.500000
# ...                      ...               ...
# 1696                       1        993.000000
# 1697                       1        999.000000
# 1698                       1       1000.000000
# 1699                       1       1001.000000
# 1700                       1       1004.000000
# 1701                       1       1005.000000
# 1702                       1       1008.000000
# 1703                       1       1018.000000
# 1704                       1       1021.000000
# 1705                       1       1022.000000
# 1706                       1       1024.000000
# 1707                       1       1025.000000
# 1708                       1       1029.000000
# 1709                       1       1031.000000
# 1710                       1       1032.000000
# 1711                       1       1038.000000
# 1712                       1       1044.500000
# 1713                       1       1044.500000
# 1714                       1       1048.000000
# 1715                       1       1051.000000
# 1716                       1       1054.000000
# 1717                       1       1055.000000
# 1718                       1       1066.500000
# 1719                       1       1066.500000
# 1720                       1       1072.000000
# 1721                       1       1073.000000
# 1722                       1       1076.000000
# 1723                       1       1080.000000
# 1724                       1       1082.000000
# 1725                       1       1097.000000
#
# [1726 rows x 3 columns]

# %%
df = pd.read_csv(STEP05_log2_ratio_of_classes, sep="\t", index_col=0)

# %%
df["fdr"].min()
# Out:
# 0.8541666825504897

# %%
def find_neutrophil_degranulation(fp):
    enrich = plot_top_ten(fp, STEP01_FILE_PATH, "Reactome data - proteins ranked by |S2N|", fdr=1)[1]

    # enrich = enrich[enrich["pathway_times_enriched"] == 8]
    ranks = enrich[["Term", "pathway_avg_rank"]].\
        set_index("Term").\
        drop_duplicates(keep="first").\
        rank()["pathway_avg_rank"].\
        rename("pathway_overall_rank")

    enrich = enrich.merge(
        right=ranks,
        left_on="Term",
        right_on="Term",
        validate="many_to_one")

    return enrich[enrich["Term"] == "Neutrophil degranulation"]

# %%
find_neutrophil_degranulation(STEP05_abs_signal_to_noise)
# Out:
#                            Term        es       nes      pval       fdr  \
# 10408  Neutrophil degranulation  0.443041  1.474740  0.000000  0.548928
# 10409  Neutrophil degranulation  0.337260  1.095910  0.228904  0.703070
# 10410  Neutrophil degranulation  0.350014  1.141544  0.176256  0.668910
# 10411  Neutrophil degranulation  0.334066  1.095346  0.297285  0.752959
# 10412  Neutrophil degranulation  0.460514  1.474212  0.002217  0.364215
# 10413  Neutrophil degranulation  0.309145  1.009420  0.417937  0.819957
# 10414  Neutrophil degranulation  0.311450  1.003927  0.465463  0.798988
# 10415  Neutrophil degranulation  0.384449  1.233823  0.034091  0.676408
#
#        geneset_size  matched_size  \
# 10408           479           427
# 10409           479           405
# 10410           479           427
# 10411           479           432
# 10412           479           448
# 10413           479           423
# 10414           479           409
# 10415           479           418
#
#                                                    genes  \
# 10408  PYGL;GGH;NDUFC2;TYROBP;FCER1G;ITGAX;RAP2B;LPCA...
# 10409  METTL7A;S100A11;HSP90AB1;AGL;CNN2;RAB5B;CFD;XR...
# 10410  AHSG;EEF2;SERPINA1;TIMP2;COPB1;A1BG;PSMD2;DYNL...
# 10411  AP2A2;HSPA8;TOLLIP;ATP6V1D;LRRC7;NDUFC2;KCNAB2...
# 10412  SPTAN1;AHSG;TTR;CFD;ORM2;A1BG;SERPINA1;CNN2;RA...
# 10413  SPTAN1;EEF2;VAT1;CD93;CD55;CAT;SERPINB6;PECAM1...
# 10414  SPTAN1;CAT;PECAM1;VCL;ANXA2;CD36;HBB;CD93;RAP1...
# 10415  HSP90AB1;STOM;PRSS3;HSP90AA1;ILF2;COPB1;PECAM1...
#
#                                              ledge_genes  cancer_type  \
# 10408  PYGL;GGH;NDUFC2;TYROBP;FCER1G;ITGAX;RAP2B;LPCA...        ccrcc
# 10409  METTL7A;S100A11;HSP90AB1;AGL;CNN2;RAB5B;CFD;XR...        colon
# 10410  AHSG;EEF2;SERPINA1;TIMP2;COPB1;A1BG;PSMD2;DYNL...  endometrial
# 10411  AP2A2;HSPA8;TOLLIP;ATP6V1D;LRRC7;NDUFC2;KCNAB2...          gbm
# 10412  SPTAN1;AHSG;TTR;CFD;ORM2;A1BG;SERPINA1;CNN2;RA...        hnscc
# 10413  SPTAN1;EEF2;VAT1;CD93;CD55;CAT;SERPINB6;PECAM1...         lscc
# 10414  SPTAN1;CAT;PECAM1;VCL;ANXA2;CD36;HBB;CD93;RAP1...         luad
# 10415  HSP90AB1;STOM;PRSS3;HSP90AA1;ILF2;COPB1;PECAM1...      ovarian
#
#         abs_nes  cancer_rank_abs_nes  pathway_times_enriched  \
# 10408  1.474740                922.0                       8
# 10409  1.095910               1582.0                       8
# 10410  1.141544               1474.0                       8
# 10411  1.095346               1589.0                       8
# 10412  1.474212               1096.0                       8
# 10413  1.009420               1734.0                       8
# 10414  1.003927               1778.0                       8
# 10415  1.233823               1239.0                       8
#
#        pathway_avg_rank  pathway_overall_rank
# 10408           1426.75                1483.0
# 10409           1426.75                1483.0
# 10410           1426.75                1483.0
# 10411           1426.75                1483.0
# 10412           1426.75                1483.0
# 10413           1426.75                1483.0
# 10414           1426.75                1483.0
# 10415           1426.75                1483.0

# %%
find_neutrophil_degranulation(STEP05_diff_of_classes)
# Out:
#                           Term        es       nes      pval       fdr  \
# 8184  Neutrophil degranulation  0.402375  2.329713  0.228597  0.484294
# 8185  Neutrophil degranulation -0.234137 -1.460782  0.851782  0.853043
# 8186  Neutrophil degranulation  0.382288  2.147134  0.365123  0.772177
# 8187  Neutrophil degranulation  0.344896  1.817912  0.528384  0.817244
# 8188  Neutrophil degranulation  0.235027  1.492685  0.938557  1.000000
# 8189  Neutrophil degranulation -0.392260 -2.377807  0.338095  0.600050
# 8190  Neutrophil degranulation -0.432713 -2.553530  0.192096  0.480826
# 8191  Neutrophil degranulation -0.480385 -3.021381  0.045331  0.355939
#
#       geneset_size  matched_size  \
# 8184           479           427
# 8185           479           405
# 8186           479           427
# 8187           479           432
# 8188           479           448
# 8189           479           423
# 8190           479           409
# 8191           479           418
#
#                                                   genes  \
# 8184  FCER1G;TYROBP;FTL;PYGL;FTH1;ITGAX;SLC2A3;CYBB;...
# 8185  S100P;S100A9;S100A8;S100A11;S100A12;CAMP;LCN2;...
# 8186  S100A8;S100A9;FCER1G;LTF;S100A12;DSP;LCN2;CAMP...
# 8187  SERPINA1;HBB;S100A11;ANXA2;FCER1G;CD44;SERPINA...
# 8188  MGAM;AOC1;CEP290;CR1;FCER1G;CAMP;PLAU;EPX;MCEM...
# 8189  DSP;PKP1;PLAU;SERPINB3;CKAP4;JUP;TNFAIP6;S100A...
# 8190  DSP;PLAU;TXNDC5;CKAP4;MLEC;NEU1;DNAJC3;FUCA1;H...
# 8191  NPC2;PKM;HSP90AB1;ILF2;MIF;SRP14;HSP90AA1;CD47...
#
#                                             ledge_genes  cancer_type  \
# 8184  FCER1G;TYROBP;FTL;PYGL;FTH1;ITGAX;SLC2A3;CYBB;...        ccrcc
# 8185  RNASET2;ITGAV;CEACAM1;ADAM10;CFP;CTSC;ACTR1B;M...        colon
# 8186  S100A8;S100A9;FCER1G;LTF;S100A12;DSP;LCN2;CAMP...  endometrial
# 8187  SERPINA1;HBB;S100A11;ANXA2;FCER1G;CD44;SERPINA...          gbm
# 8188  MGAM;AOC1;CEP290;CR1;FCER1G;CAMP;PLAU;EPX;MCEM...        hnscc
# 8189  RAB14;DOCK2;TMC6;CEACAM8;RAB4B;LRRC7;CRISPLD2;...         lscc
# 8190  AZU1;S100A9;CEACAM8;STK10;SVIP;DEFA4;NAPRT;DNA...         luad
# 8191  PLEKHO2;HEBP2;ROCK1;CTSH;ARHGAP9;SDCBP;CR1;CPP...      ovarian
#
#        abs_nes  cancer_rank_abs_nes  pathway_times_enriched  pathway_avg_rank  \
# 8184  2.329713               1098.0                       8          1203.125
# 8185  1.460782               2009.0                       8          1203.125
# 8186  2.147134               1260.0                       8          1203.125
# 8187  1.817912               1668.0                       8          1203.125
# 8188  1.492685               1368.0                       8          1203.125
# 8189  2.377807               1014.0                       8          1203.125
# 8190  2.553530                773.0                       8          1203.125
# 8191  3.021381                435.0                       8          1203.125
#
#       pathway_overall_rank
# 8184                1048.0
# 8185                1048.0
# 8186                1048.0
# 8187                1048.0
# 8188                1048.0
# 8189                1048.0
# 8190                1048.0
# 8191                1048.0

# %%
find_neutrophil_degranulation(STEP05_log2_ratio_of_classes)
# Out:
#                           Term        es       nes  pval  fdr  geneset_size  \
# 1772  Neutrophil degranulation  0.264286  1.039035   1.0  1.0           479
#
#       matched_size                                              genes  \
# 1772           448  PTPRN2;P2RX1;AOC1;MMP25;NFASC;MCEMP1;MGAM;CEP2...
#
#                                             ledge_genes cancer_type   abs_nes  \
# 1772  PTPRN2;P2RX1;AOC1;MMP25;NFASC;MCEMP1;MGAM;CEP2...       hnscc  1.039035
#
#       cancer_rank_abs_nes  pathway_times_enriched  pathway_avg_rank  \
# 1772               1972.0                       1            1972.0
#
#       pathway_overall_rank
# 1772                1773.0

# %%
find_neutrophil_degranulation(STEP05_ratio_of_classes)
# Out:
#                            Term        es       nes      pval       fdr  \
# 11424  Neutrophil degranulation -0.320748 -1.881164  0.699888  0.883099
# 11425  Neutrophil degranulation -0.330949 -1.461890  0.913725  1.000000
# 11426  Neutrophil degranulation -0.486678 -1.629601  0.631119  1.000000
# 11427  Neutrophil degranulation  0.134445  0.815357  0.588816  0.993212
# 11428  Neutrophil degranulation  0.286571  1.197760  0.874494  1.000000
# 11429  Neutrophil degranulation -0.395257 -2.082395  0.555435  1.000000
# 11430  Neutrophil degranulation  0.418587  1.769275  0.391486  0.627585
#
#        geneset_size  matched_size  \
# 11424           479           427
# 11425           479           427
# 11426           479           432
# 11427           479           448
# 11428           479           423
# 11429           479           409
# 11430           479           418
#
#                                                    genes  \
# 11424  PPIE;PSMD6;CHI3L1;RHOA;PSMD2;SERPINB10;DEFA4;R...
# 11425  TNFAIP6;CD300A;CD55;ALDH3B1;UNC13D;PGM1;LAMTOR...
# 11426  CYB5R3;CEACAM8;PLAUR;GM2A;ORMDL3;PSMB7;ATAD3B;...
# 11427  PTPRN2;P2RX1;AOC1;MMP25;NFASC;MCEMP1;MGAM;CEP2...
# 11428  MMP8;RETN;MAN2B1;GM2A;PADI2;FABP5;CD300A;KCMF1...
# 11429  PSMB7;GHDC;RAB6A;HLA-B;TMC6;SNAP29;CHIT1;EPX;C...
# 11430  DIAPH1;HSPA6;TUBB;GSDMD;LRMP;ALOX5;KRT1;ARSB;R...
#
#                                              ledge_genes  cancer_type  \
# 11424  LRMP;PIGR;EEF2;VAT1;APRT;ATAD3B;RAC1;LYZ;FCGR3...        ccrcc
# 11425  FUCA1;ITGAV;SNAP29;LRMP;PYCARD;CEACAM8;MAN2B1;...  endometrial
# 11426  BST2;SLC44A2;TLR2;QSOX1;LYZ;FGR;FUCA1;RAB6A;LP...          gbm
# 11427  PTPRN2;P2RX1;AOC1;MMP25;NFASC;MCEMP1;MGAM;CEP2...        hnscc
# 11428  MMP8;RETN;MAN2B1;GM2A;PADI2;FABP5;CD300A;KCMF1...         lscc
# 11429  HP;AGA;PSMD6;MME;HBB;FCAR;ITGAM;FCN1;XRCC6;P2R...         luad
# 11430  DIAPH1;HSPA6;TUBB;GSDMD;LRMP;ALOX5;KRT1;ARSB;R...      ovarian
#
#         abs_nes  cancer_rank_abs_nes  pathway_times_enriched  \
# 11424  1.881164               1401.0                       7
# 11425  1.461890               1352.0                       7
# 11426  1.629601               1292.0                       7
# 11427  0.815357               2196.0                       7
# 11428  1.197760               1941.0                       7
# 11429  2.082395                997.0                       7
# 11430  1.769275               1308.0                       7
#
#        pathway_avg_rank  pathway_overall_rank
# 11424       1498.142857                1745.0
# 11425       1498.142857                1745.0
# 11426       1498.142857                1745.0
# 11427       1498.142857                1745.0
# 11428       1498.142857                1745.0
# 11429       1498.142857                1745.0
# 11430       1498.142857                1745.0

# %%
find_neutrophil_degranulation(STEP05_signal_to_noise)
# Out:
#                           Term        es       nes      pval       fdr  \
# 9672  Neutrophil degranulation  0.366073  2.955986  0.042945  0.256524
# 9673  Neutrophil degranulation  0.177983  1.432615  0.814151  0.885181
# 9674  Neutrophil degranulation  0.331414  2.435937  0.244565  0.659998
# 9675  Neutrophil degranulation  0.196746  1.279314  0.782756  0.921631
# 9676  Neutrophil degranulation  0.259328  2.089915  0.401060  0.557506
# 9677  Neutrophil degranulation -0.336553 -2.402527  0.306912  0.503667
# 9678  Neutrophil degranulation -0.326192 -2.421644  0.250681  0.476034
# 9679  Neutrophil degranulation -0.304473 -2.552527  0.224976  0.480426
#
#       geneset_size  matched_size  \
# 9672           479           427
# 9673           479           405
# 9674           479           427
# 9675           479           432
# 9676           479           448
# 9677           479           423
# 9678           479           409
# 9679           479           418
#
#                                                   genes  \
# 9672  PYGL;TYROBP;FCER1G;ITGAX;RAP2B;LPCAT1;CYBB;ALD...
# 9673  S100A11;HSP90AB1;CNN2;XRCC6;S100P;ILF2;PA2G4;P...
# 9674  EEF2;COPB1;PSMD2;DYNLT1;DSP;JUP;PKM;NBEAL2;CTS...
# 9675  IDH1;PGM2;STK10;IQGAP2;EEF1A1;PYGL;SERPINB6;TY...
# 9676  CNN2;PLAU;IGF2R;LPCAT1;FCER1G;HSP90AB1;ITGAX;M...
# 9677  EEF2;CKAP4;DDX3X;DSP;HSP90AB1;PLAU;PA2G4;ILF2;...
# 9678  COPB1;EEF2;SRP14;HSP90AB1;PSMD3;PSMD6;DNAJC3;P...
# 9679  HSP90AB1;HSP90AA1;ILF2;COPB1;EEF1A1;EEF2;NPC2;...
#
#                                             ledge_genes  cancer_type  \
# 9672  PYGL;TYROBP;FCER1G;ITGAX;RAP2B;LPCAT1;CYBB;ALD...        ccrcc
# 9673  S100A11;HSP90AB1;CNN2;XRCC6;S100P;ILF2;PA2G4;P...        colon
# 9674  EEF2;COPB1;PSMD2;DYNLT1;DSP;JUP;PKM;NBEAL2;CTS...  endometrial
# 9675  IDH1;PGM2;STK10;IQGAP2;EEF1A1;PYGL;SERPINB6;TY...          gbm
# 9676  CNN2;PLAU;IGF2R;LPCAT1;FCER1G;HSP90AB1;ITGAX;M...        hnscc
# 9677  SIGLEC9;LRRC7;PTPRJ;OSTF1;PGM2;VNN1;HGSNAT;LIL...         lscc
# 9678  LILRB3;GSTP1;STK11IP;PAFAH1B2;COTL1;SLPI;MGAM;...         luad
# 9679  STK11IP;SLC15A4;HEBP2;SLPI;S100A9;FLG2;MNDA;TO...      ovarian
#
#        abs_nes  cancer_rank_abs_nes  pathway_times_enriched  pathway_avg_rank  \
# 9672  2.955986                437.0                       8           1299.25
# 9673  1.432615               1988.0                       8           1299.25
# 9674  2.435937                928.0                       8           1299.25
# 9675  1.279314               2114.0                       8           1299.25
# 9676  2.089915               1687.0                       8           1299.25
# 9677  2.402527               1145.0                       8           1299.25
# 9678  2.421644               1109.0                       8           1299.25
# 9679  2.552527                986.0                       8           1299.25
#
#       pathway_overall_rank
# 9672                1248.0
# 9673                1248.0
# 9674                1248.0
# 9675                1248.0
# 9676                1248.0
# 9677                1248.0
# 9678                1248.0
# 9679                1248.0

# %%
find_neutrophil_degranulation(STEP05_t_test)
# Out:
#                           Term        es       nes      pval       fdr  \
# 9728  Neutrophil degranulation  0.363073  2.930958  0.053556  0.258452
# 9729  Neutrophil degranulation  0.172719  1.386814  0.846516  0.900781
# 9730  Neutrophil degranulation  0.327291  2.395131  0.262635  0.693537
# 9731  Neutrophil degranulation  0.192165  1.253155  0.800509  0.925179
# 9732  Neutrophil degranulation  0.257080  2.070832  0.418358  0.568355
# 9733  Neutrophil degranulation -0.341842 -2.443492  0.292976  0.477470
# 9734  Neutrophil degranulation -0.331756 -2.459892  0.233908  0.459798
# 9735  Neutrophil degranulation -0.305249 -2.558660  0.225191  0.476000
#
#       geneset_size  matched_size  \
# 9728           479           427
# 9729           479           405
# 9730           479           427
# 9731           479           432
# 9732           479           448
# 9733           479           423
# 9734           479           409
# 9735           479           418
#
#                                                   genes  \
# 9728  PYGL;TYROBP;FCER1G;ITGAX;RAP2B;CYBB;LPCAT1;ALD...
# 9729  S100A11;HSP90AB1;CNN2;XRCC6;S100P;ILF2;PA2G4;P...
# 9730  EEF2;COPB1;PSMD2;DYNLT1;DSP;JUP;PKM;PSMD1;NBEA...
# 9731  IDH1;PGM2;EEF1A1;IQGAP2;APAF1;STK10;CPNE3;TYRO...
# 9732  CNN2;PLAU;LPCAT1;IGF2R;FCER1G;HSP90AB1;MNDA;IT...
# 9733  EEF2;CKAP4;DDX3X;DSP;HSP90AB1;ILF2;PLAU;PA2G4;...
# 9734  COPB1;SRP14;EEF2;PSMD3;HSP90AB1;PSMD6;PDAP1;DN...
# 9735  HSP90AB1;HSP90AA1;ILF2;COPB1;EEF1A1;EEF2;PKM;X...
#
#                                             ledge_genes  cancer_type  \
# 9728  PYGL;TYROBP;FCER1G;ITGAX;RAP2B;CYBB;LPCAT1;ALD...        ccrcc
# 9729  S100A11;HSP90AB1;CNN2;XRCC6;S100P;ILF2;PA2G4;P...        colon
# 9730  EEF2;COPB1;PSMD2;DYNLT1;DSP;JUP;PKM;PSMD1;NBEA...  endometrial
# 9731  IDH1;PGM2;EEF1A1;IQGAP2;APAF1;STK10;CPNE3;TYRO...          gbm
# 9732  CNN2;PLAU;LPCAT1;IGF2R;FCER1G;HSP90AB1;MNDA;IT...        hnscc
# 9733  C5AR1;CTSZ;FTL;GAA;CAPN1;HK3;BST1;RAB31;COTL1;...         lscc
# 9734  CAMP;STK11IP;CTSD;COTL1;LTF;MGAM;DOCK2;SLPI;IQ...         luad
# 9735  STK11IP;AP2A2;SLC15A4;TOM1;HEBP2;SLPI;S100A9;H...      ovarian
#
#        abs_nes  cancer_rank_abs_nes  pathway_times_enriched  pathway_avg_rank  \
# 9728  2.930958                472.0                       8          1305.625
# 9729  1.386814               2018.0                       8          1305.625
# 9730  2.395131                979.0                       8          1305.625
# 9731  1.253155               2123.0                       8          1305.625
# 9732  2.070832               1702.0                       8          1305.625
# 9733  2.443492               1113.0                       8          1305.625
# 9734  2.459892               1060.0                       8          1305.625
# 9735  2.558660                978.0                       8          1305.625
#
#       pathway_overall_rank
# 9728                1257.0
# 9729                1257.0
# 9730                1257.0
# 9731                1257.0
# 9732                1257.0
# 9733                1257.0
# 9734                1257.0
# 9735                1257.0

# %% [markdown]
# ## Figure 2: Expression of proteins in the neutrophil degranulation pathway

# %%
# Get the ID the top expessed pathway
neutro_pathway_ids = enrichment_data.\
    loc[enrichment_data["name"] == "Neutrophil degranulation", "pathway_id"].\
    unique()

if len(neutro_pathway_ids) != 1:
    raise ValueError("Multiple pathways found.")
    
neutro_pathway_id = neutro_pathway_ids[0]

# %% [markdown]
# ### A: With proteins in different orders for the up and down categories

# %%
def expr_heatmap(expr_data, enrich_data, pathway_id, up_or_down, max_p, x_title=True):
    """Make a heatmap with proteins on the X axis, cancer types on the Y 
    axis, and the color reflecting the expression of that protein in that
    cancer type.
    
    Parameters:
    expr_data (pandas.DataFrame): A dataframe with columns "cancer_type", "protein_str", "adj_p", and "simplified_change".
    enrich_data (pandas.DataFrame): A dataframe with columns "cancer_type" and "mean_expr" (i.e. mean expression for the pathway of interest).
    pathway_id (str): The Reactome pathway id for the pathway you want the heatmap for.
    up_or_down (str): Either "up" or "down"; whether to plot cancers where the pathway is up, or where it's down.
    max_p (float): The minimum p value for a protein to be included on the plot. If max_p > 0.05, then proteins with 0.05 <= p < max_p will be marked as marginally significant.
    x_title (bool): Whether to include an x axis title.
    
    Returns:
    altair.Chart: The heatmap.
    """
    # Filter expression data by p value
    expr_data = expr_data[expr_data["adj_p"] < max_p]
    
    # Get expression data for proteins in the pathway
    pathway_proteins = ut.search_reactome_proteins_in_pathways(pathway_id)
    pathway_expr = expr_data[expr_data["protein_str"].isin(pathway_proteins["member"])]
    
    # Categorize the cancer types as the neutrophil degranulation pathway's mean expression being up or down
    if up_or_down == "up":
        comparison = operator.gt
    elif up_or_down == "down":
        comparison = operator.lt
    else:
        raise ValueError(f"Invalid value for up_or_down parameter: '{up_or_down}'")
    
    sel_cancers = enrich_data.\
        loc[(enrich_data["pathway_id"] == neutro_pathway_id) & (comparison(enrich_data["mean_expr"], 0)),
           ["cancer_type", "mean_expr"]]

    # Select data for the specified cancer types
    selected_expr_data = pathway_expr[pathway_expr["cancer_type"].isin(sel_cancers["cancer_type"])]

    # Sort proteins by mean expression across selected cancer types
    prot_order = selected_expr_data.groupby("protein_str")[["simplified_change", "cancer_type"]].\
        agg({
            "simplified_change": np.mean,
            "cancer_type": "count"
        })

    prot_order = prot_order.assign(
            cancer_type=np.copysign(prot_order["cancer_type"], prot_order["simplified_change"])
        ).\
        sort_values(by=["simplified_change", "cancer_type"])

    # Sort cancer types by mean pathway expression
    cancer_order = sel_cancers.\
        sort_values(by="mean_expr", ascending=False).\
        loc[:, "cancer_type"]
    
    # Map simplified_change to legend values
    selected_expr_data = selected_expr_data.assign(
        tumor_up_down=selected_expr_data["simplified_change"].replace({
            1: "Up (adj p < 0.05)",
            MSV: f"Up (0.05 <= adj p < {max_p})",
            0: "No change",
            -MSV: f"Down (0.05 <= adj p < {max_p})",
            -1: "Down (adj p < 0.05)"
        })
    )
    
    # Plot
    plot = alt.Chart(selected_expr_data).mark_rect().encode(
        x=alt.X(
            "protein_str:N",
            sort=prot_order.index.values,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=f"Proteins for {pathway_id} (different order in each facet)" if x_title else ""
            )
        ),
        y=alt.Y(
            "cancer_type:N",
            sort=cancer_order.values,
            axis=alt.Axis(
                title=f"Pathway {up_or_down} in tumor"
            )
        ),
        color=alt.Color(
            "tumor_up_down:N",
            scale=alt.Scale(
                domain=[
                    "Up (adj p < 0.05)",
                    f"Up (0.05 <= adj p < {max_p})",
                    "No change",
                    f"Down (0.05 <= adj p < {max_p})",
                    "Down (adj p < 0.05)"
                ],
                range=["#bf363a",
                       "#f6bda4",
                       "#f2efee",
                       "#afd3e6",
                       "#1e588a"
                ]
            ),
            legend=alt.Legend(
                title="Expression in tumor"
            )
        ),
    ).properties(
        width=700,
        height=175
    )
    
    return plot

# %%
# Plot
alt.vconcat(
    expr_heatmap(all_expression_data, enrichment_data, neutro_pathway_id, "up", max_p=0.2, x_title=False),
    expr_heatmap(all_expression_data, enrichment_data, neutro_pathway_id, "down", max_p=0.2)
)

# %% [markdown]
# ### B: With same sorting for both

# %%
def expr_heatmap_alt_sort(expr_data, enrich_data, pathway_id, max_p):
    """Make a heatmap with proteins on the X axis, cancer types on the Y 
    axis, and the color reflecting the expression of that protein in that
    cancer type.
    
    Parameters:
    expr_data (pandas.DataFrame): A dataframe with columns "cancer_type", "protein_str", "adj_p", and "simplified_change".
    enrich_data (pandas.DataFrame): A dataframe with columns "cancer_type" and "mean_expr" (i.e. mean expression for the pathway of interest).
    pathway_id (str): The Reactome pathway id for the pathway you want the heatmap for.
    up_or_down (str): Either "up" or "down"; whether to plot cancers where the pathway is up, or where it's down.
    max_p (float): The minimum p value for a protein to be included on the plot. If max_p > 0.05, then proteins with 0.05 <= p < max_p will be marked as marginally significant.
    
    Returns:
    altair.Chart: The heatmap.
    """
    # Filter expression data by p value
    expr_data = expr_data[expr_data["adj_p"] < max_p]
    
    # Get expression data for proteins in the pathway
    pathway_proteins = ut.search_reactome_proteins_in_pathways(pathway_id)
    pathway_expr = expr_data[expr_data["protein_str"].isin(pathway_proteins["member"])]
    
    # Sort proteins by mean expression across all cancer types
    prot_order = pathway_expr.groupby("protein_str")[["simplified_change", "cancer_type"]].\
        agg({
            "simplified_change": np.mean,
            "cancer_type": "count"
        })

    prot_order = prot_order.assign(
            cancer_type=np.copysign(prot_order["cancer_type"], prot_order["simplified_change"])
        ).\
        sort_values(by=["simplified_change", "cancer_type"])

    # Sort cancer types by mean pathway expression
    sel_cancers = enrich_data.\
        loc[enrich_data["pathway_id"] == neutro_pathway_id, ["cancer_type", "mean_expr"]]
        
    sel_cancers = sel_cancers.\
        assign(up_or_down=np.where(sel_cancers["mean_expr"] > 0, "Pathway up in tumor", "Pathway down in tumor")).\
        sort_values(by="mean_expr", ascending=False).\
        loc[:, ["cancer_type", "up_or_down"]]
    
    cancer_order = sel_cancers["cancer_type"].values
    
    pathway_expr = pathway_expr.merge(
        right=sel_cancers,
        how="inner",
        left_on="cancer_type",
        right_on="cancer_type",
        validate="many_to_one"
    )
    
    # Map simplified_change to legend values
    pathway_expr = pathway_expr.assign(
        tumor_up_down=pathway_expr["simplified_change"].replace({
            1: "Up (adj p < 0.05)",
            MSV: f"Up (0.05 <= adj p < {max_p})",
            0: "No change",
            -MSV: f"Down (0.05 <= adj p < {max_p})",
            -1: "Down (adj p < 0.05)"
        })
    )
    
    # Plot
    plot = alt.Chart(pathway_expr).mark_rect().encode(
        x=alt.X(
            "protein_str:N",
            sort=prot_order.index.values,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=f"Proteins for {pathway_id} (same order in both facets)"
            )
        ),
        y=alt.Y(
            "cancer_type:N",
            sort=cancer_order,
            axis=alt.Axis(
                title=""
            )
        ),
        color=alt.Color(
            "tumor_up_down:N",
            scale=alt.Scale(
                domain=[
                    "Up (adj p < 0.05)",
                    f"Up (0.05 <= adj p < {max_p})",
                    "No change",
                    f"Down (0.05 <= adj p < {max_p})",
                    "Down (adj p < 0.05)"
                ],
                range=["#bf363a",
                       "#f6bda4",
                       "#f2efee",
                       "#afd3e6",
                       "#1e588a"
                ]
            ),
            legend=alt.Legend(
                title="Expression in tumor"
            )
        ),
        row=alt.Row(
            "up_or_down:N",
            sort="descending",
            title="",
            header=alt.Header(
                labelFontStyle="bold"
            )
        )
    ).properties(
        width=600,
        height=150
    ).resolve_scale(
        y="independent" # This makes it so each facet (up or down) only has the cancers that are in that category
    )
    
    return plot

# %%
# Plot
expr_heatmap_alt_sort(all_expression_data, enrichment_data, neutro_pathway_id, max_p=0.2)

# %% [markdown]
# ## Figure 3: Pathway overlay for neutrophil degranulation

# %%
def pathway_overlay_wrapper(pathway_id, exp_data, enrich_data, up_or_down):
    
    prots = ut.search_reactome_proteins_in_pathways(pathway_id)
    
    # Categorize the cancer types as the neutrophil degranulation pathway's mean expression being up or down
    if up_or_down == "up":
        comparison = operator.gt
    elif up_or_down == "down":
        comparison = operator.lt
    else:
        raise ValueError(f"Invalid value for up_or_down parameter: '{up_or_down}'")
    
    sel_cancers = enrich_data.\
        loc[(enrich_data["pathway_id"] == neutro_pathway_id) & (comparison(enrich_data["mean_expr"], 0)),
            "cancer_type"]
    
    # Select the desired expression data and average the simplified change across cancer types
    sel_exp = exp_data.\
        loc[
            exp_data["protein_str"].isin(prots["member"]) & 
            exp_data["cancer_type"].isin(sel_cancers),
            ["protein_str", "simplified_change"]
        ].\
        groupby("protein_str").\
        agg(np.mean).\
        rename(columns={"simplified_change": f"{up_or_down}_simp_change"})
    
    img_name = f"{TIME_START}_{pathway_id}_{up_or_down}.png"
    img_path = os.path.join(STEP07_DIR, img_name)
    
    token, _ = ut.reactome_enrichment_analysis(
        analysis_type="ranked", 
        data=sel_exp, 
        sort_by="ENTITIES_FDR", 
        ascending=True,
        include_high_level_diagrams=True, 
        include_interactors=False)
    
    _, img_path = ut.reactome_pathway_overlay(
        analysis_token=token,
        pathway=pathway_id,
        open_browser=False,
        export_path=img_path,
        image_format="png",
        display_col_idx=None,
        diagram_colors="Modern",
        overlay_colors="Standard",
        quality=10
    )

    _, url = ut.reactome_pathway_overlay(
        analysis_token=token,
        pathway=pathway_id,
        open_browser=False,
    )

    return img_path, url

# %%
# Note that we're using expression_data, not all_expression_data; the former has
# only proteins where reject_null

up_image_path, up_url = pathway_overlay_wrapper(neutro_pathway_id, expression_data, enrichment_data, "up")

# %%
IPython.display.HTML(f'<a href={up_url}>{up_url}</a>')

# %%
IPython.display.Image(up_image_path)

# %%
# Note that we're using expression_data, not all_expression_data; the former has
# only proteins where reject_null

down_image_path, down_url = pathway_overlay_wrapper(neutro_pathway_id, expression_data, enrichment_data, "down")

# %%
IPython.display.HTML(f'<a href={down_url}>{down_url}</a>')

# %%
IPython.display.Image(down_image_path)
