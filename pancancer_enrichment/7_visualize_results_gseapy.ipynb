# %% [markdown]
# # Pancancer enrichment analysis step 7: Make figures from GSEApy data

# %% [markdown]
# ## Setup

# %%
import cptac
import cptac.utils as ut
import os
import datetime
import altair as alt
import numpy as np
import pandas as pd
import operator
import IPython.display

# %%
TIME_START = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

STEP1_DIR = "step1_outputs"
STEP1_FILE = "tumor_change_20200529_195104_10000_perm.tsv"
STEP1_FILE_PATH = os.path.join(STEP1_DIR, STEP1_FILE)

STEP5_DIR = "step5_outputs"
STEP5_FILE = "enrichment_gseapy_reactome_20200616_124447.tsv"
STEP5_FILE_PATH = os.path.join(STEP5_DIR, STEP5_FILE)

STEP6_DIR = "step6_outputs"
STEP6_FILE = "enrichment_gseapy_kegg_20200616_145235.tsv"
STEP6_FILE_PATH = os.path.join(STEP6_DIR, STEP6_FILE)

STEP7_DIR = "step7_outputs"

if not os.path.isdir(STEP7_DIR):
    os.mkdir(STEP7_DIR)
    
MSV = 0.5 # Simplified expression value for marginally significant proteins

# %%
# Altair options
# alt.data_transformers.disable_max_rows()
# alt.data_transformers.enable('json')

# %% [markdown]
# ## Read in data from steps 1, 5, and 6

# %%
all_expression_data = pd.read_csv(STEP1_FILE_PATH, sep="\t", index_col=0)

# Make a column where all increases are +1 and all decreases 
# are -1, because these are ratioed abundances, so we can't 
# compare magnitudes between genes--we can only compare whether 
# there was a change, and whether it was positive or negative
all_expression_data = all_expression_data.assign(simplified_change=np.nan)

# adj p < 0.05 and change > 1 => +1
all_expression_data.loc[
    (all_expression_data["change"] > 0) & (all_expression_data["adj_p"] < 0.05), 
    "simplified_change"
] = 1

# adj p >= 0.05 and change > 1 => +0.5
all_expression_data.loc[(all_expression_data["change"] > 0) & (all_expression_data["adj_p"] >= 0.05),
    "simplified_change"
] = MSV

# change == 0 => 0
all_expression_data.loc[
    all_expression_data["change"] == 0,
    "simplified_change"
] = 0

# adj p >= 0.05 and change < 1 => -0.5
all_expression_data.loc[(all_expression_data["change"] < 0) & (all_expression_data["adj_p"] >= 0.05), 
    "simplified_change"
] = -MSV

# adj p < 0.05 and change < 1 => -1
all_expression_data.loc[
    (all_expression_data["change"] < 0) & (all_expression_data["adj_p"] < 0.05),
    "simplified_change"
] = -1

# Select just the proteins where we chose to reject the null hypothesis of no change
expression_data = all_expression_data[all_expression_data["reject_null"]]

all_expression_data
# Out:
#       cancer_type                       protein    change   P_val     adj_p  \
# 0           ccrcc       ('A1BG', 'NP_570602.2')  0.282928  0.0000  0.000000
# 1           ccrcc       ('A1CF', 'NP_620310.1') -0.551358  0.0000  0.000000
# 2           ccrcc        ('A2M', 'NP_000005.2')  0.595512  0.0000  0.000000
# 3           ccrcc  ('A4GALT', 'NP_001304967.1')  0.479410  0.1735  0.214310
# 4           ccrcc       ('AAAS', 'NP_056480.1')  0.173579  0.0000  0.000000
# 5           ccrcc       ('AACS', 'NP_076417.2') -0.215967  0.0000  0.000000
# 6           ccrcc      ('AADAC', 'NP_001077.2')  0.147423  0.7481  0.784497
# 7           ccrcc   ('AADAT', 'NP_001273612.1') -1.818291  0.0000  0.000000
# 8           ccrcc      ('AAED1', 'NP_714542.1')  0.426052  0.0000  0.000000
# 9           ccrcc      ('AAGAB', 'NP_078942.3') -0.070117  0.0009  0.001554
# 10          ccrcc       ('AAK1', 'NP_055726.3') -0.307917  0.0000  0.000000
# 11          ccrcc       ('AAMP', 'NP_001078.2')  0.328956  0.0000  0.000000
# 12          ccrcc    ('AAR2', 'NP_001258803.1')  0.260477  0.0000  0.000000
# 13          ccrcc       ('AARS', 'NP_001596.2')  0.171212  0.0000  0.000000
# 14          ccrcc      ('AARS2', 'NP_065796.1') -0.084635  0.0102  0.015459
# 15          ccrcc  ('AARSD1', 'NP_001248363.1')  0.217840  0.0000  0.000000
# 16          ccrcc   ('AASDH', 'NP_001273597.1') -0.035299  0.8544  0.877806
# 17          ccrcc   ('AASDHPPT', 'NP_056238.2')  0.025985  0.2636  0.313190
# 18          ccrcc       ('AASS', 'NP_005754.2') -1.614744  0.0000  0.000000
# 19          ccrcc       ('AATF', 'NP_036270.1')  0.388488  0.0000  0.000000
# 20          ccrcc       ('ABAT', 'NP_000654.2') -2.250937  0.0000  0.000000
# 21          ccrcc      ('ABCA1', 'NP_005493.2')  0.558242  0.0000  0.000000
# 22          ccrcc     ('ABCA12', 'NP_056472.2')  0.249142  0.0036  0.005803
# 23          ccrcc      ('ABCA2', 'NP_997698.1') -0.130617  0.0033  0.005344
# 24          ccrcc      ('ABCA3', 'NP_001080.2') -0.169564  0.4012  0.455638
# 25          ccrcc      ('ABCA5', 'NP_061142.2') -0.082137  0.4792  0.533063
# 26          ccrcc      ('ABCA6', 'NP_525023.2') -0.176452  0.3800  0.434335
# 27          ccrcc   ('ABCA8', 'NP_001275914.1') -0.828206  0.0000  0.000000
# 28          ccrcc   ('ABCB1', 'NP_001335874.1') -1.318350  0.0000  0.000000
# 29          ccrcc     ('ABCB10', 'NP_036221.2')  0.159938  0.0009  0.001554
# ...           ...                           ...       ...     ...       ...
# 86229     ovarian    ('ZNF865', 'NP_001182534') -0.400890  0.0064  0.009973
# 86230     ovarian        ('ZNF90', 'NP_009069')  0.360028  0.0000  0.000000
# 86231     ovarian        ('ZNF93', 'NP_112495')  0.352226  0.0000  0.000000
# 86232     ovarian     ('ZNF98', 'NP_001092096')  0.337325  0.0002  0.000368
# 86233     ovarian        ('ZNFX1', 'NP_066363') -0.118389  0.0696  0.092734
# 86234     ovarian       ('ZNHIT1', 'NP_006340')  0.616547  0.0895  0.116891
# 86235     ovarian       ('ZNHIT2', 'NP_055020')  0.160762  0.0619  0.083208
# 86236     ovarian       ('ZNHIT3', 'NP_004764') -0.382495  0.0183  0.026760
# 86237     ovarian       ('ZNHIT6', 'NP_060423')  0.345058  0.0008  0.001390
# 86238     ovarian        ('ZNRF1', 'NP_115644') -0.329103  0.0562  0.076055
# 86239     ovarian        ('ZNRF2', 'NP_667339')  0.240016  0.0311  0.043897
# 86240     ovarian         ('ZPR1', 'NP_003895')  0.229895  0.0048  0.007610
# 86241     ovarian       ('ZRANB2', 'NP_976225')  0.438710  0.0000  0.000000
# 86242     ovarian        ('ZRSR2', 'NP_005080')  0.133788  0.6057  0.654192
# 86243     ovarian   ('ZSCAN18', 'NP_001139014') -0.160106  0.3199  0.372488
# 86244     ovarian       ('ZSCAN2', 'NP_870992')  0.414704  0.0001  0.000188
# 86245     ovarian      ('ZSCAN25', 'NP_660090')  0.065645  0.6050  0.653567
# 86246     ovarian   ('ZSCAN26', 'NP_001018854') -0.427857  0.1220  0.155300
# 86247     ovarian      ('ZSCAN29', 'NP_689668')  0.201903  0.0338  0.047420
# 86248     ovarian   ('ZSCAN30', 'NP_001106205') -0.883458  0.0004  0.000717
# 86249     ovarian      ('ZSCAN31', 'NP_665916')  0.031276  0.8165  0.844845
# 86250     ovarian   ('ZSCAN32', 'NP_001271456') -0.554950  0.0041  0.006555
# 86251     ovarian    ('ZSWIM8', 'NP_001229416') -0.111356  0.1962  0.239748
# 86252     ovarian         ('ZW10', 'NP_004715')  0.272076  0.0000  0.000000
# 86253     ovarian       ('ZWILCH', 'NP_060445')  0.303400  0.0648  0.086793
# 86254     ovarian        ('ZWINT', 'NP_008988')  0.046030  0.8252  0.852436
# 86255     ovarian       ('ZYG11B', 'NP_078922') -0.087644  0.2133  0.258770
# 86256     ovarian       ('ZYX', 'NP_001010972') -0.551746  0.0000  0.000000
# 86257     ovarian        ('ZZEF1', 'NP_055928') -0.256154  0.0001  0.000188
# 86258     ovarian         ('ZZZ3', 'NP_056349') -0.026948  0.8168  0.845115
#
#        reject_null protein_str  simplified_change
# 0             True        A1BG                1.0
# 1             True        A1CF               -1.0
# 2             True         A2M                1.0
# 3            False      A4GALT                0.5
# 4             True        AAAS                1.0
# 5             True        AACS               -1.0
# 6            False       AADAC                0.5
# 7             True       AADAT               -1.0
# 8             True       AAED1                1.0
# 9             True       AAGAB               -1.0
# 10            True        AAK1               -1.0
# 11            True        AAMP                1.0
# 12            True        AAR2                1.0
# 13            True        AARS                1.0
# 14            True       AARS2               -1.0
# 15            True      AARSD1                1.0
# 16           False       AASDH               -0.5
# 17           False    AASDHPPT                0.5
# 18            True        AASS               -1.0
# 19            True        AATF                1.0
# 20            True        ABAT               -1.0
# 21            True       ABCA1                1.0
# 22            True      ABCA12                1.0
# 23            True       ABCA2               -1.0
# 24           False       ABCA3               -0.5
# 25           False       ABCA5               -0.5
# 26           False       ABCA6               -0.5
# 27            True       ABCA8               -1.0
# 28            True       ABCB1               -1.0
# 29            True      ABCB10                1.0
# ...            ...         ...                ...
# 86229         True      ZNF865               -1.0
# 86230         True       ZNF90                1.0
# 86231         True       ZNF93                1.0
# 86232         True       ZNF98                1.0
# 86233        False       ZNFX1               -0.5
# 86234        False      ZNHIT1                0.5
# 86235        False      ZNHIT2                0.5
# 86236         True      ZNHIT3               -1.0
# 86237         True      ZNHIT6                1.0
# 86238        False       ZNRF1               -0.5
# 86239         True       ZNRF2                1.0
# 86240         True        ZPR1                1.0
# 86241         True      ZRANB2                1.0
# 86242        False       ZRSR2                0.5
# 86243        False     ZSCAN18               -0.5
# 86244         True      ZSCAN2                1.0
# 86245        False     ZSCAN25                0.5
# 86246        False     ZSCAN26               -0.5
# 86247         True     ZSCAN29                1.0
# 86248         True     ZSCAN30               -1.0
# 86249        False     ZSCAN31                0.5
# 86250         True     ZSCAN32               -1.0
# 86251        False      ZSWIM8               -0.5
# 86252         True        ZW10                1.0
# 86253        False      ZWILCH                0.5
# 86254        False       ZWINT                0.5
# 86255        False      ZYG11B               -0.5
# 86256         True         ZYX               -1.0
# 86257         True       ZZEF1               -1.0
# 86258        False        ZZZ3               -0.5
#
# [86259 rows x 8 columns]

# %%
enrichment_data = pd.read_csv(STEP6_FILE_PATH, sep="\t")
enrichment_data.sort_values(by=["cancer_type", "fdr"])

# Assign pathway ranks within each cancer type based on FDR
enrichment_data = enrichment_data.\
    assign(cancer_rank_fdr=enrichment_data.groupby("cancer_type")["fdr"].rank()).\
    sort_values(by=["cancer_type", "cancer_rank_fdr"]).\
    reset_index(drop=True)

# Make a table with summary info for all pathways
enrichment_summary = enrichment_data[["Term"]].drop_duplicates(keep="first")

pathway_times_enriched = enrichment_summary["Term"].apply(
    lambda x: enrichment_data[enrichment_data["Term"] == x].shape[0])

avg_rank = enrichment_summary["Term"].apply(
    lambda x: enrichment_data.loc[enrichment_data["Term"] == x, "cancer_rank_fdr"].mean())

enrichment_summary = enrichment_summary.\
    assign(
        pathway_times_enriched=pathway_times_enriched,
        pathway_avg_rank=avg_rank).\
    sort_values(
        by=["pathway_times_enriched", "pathway_avg_rank"],
        ascending=[False, True]).\
    reset_index(drop=True)

# Merge in the original enrichment data
enrichment_data = enrichment_data.\
    merge(
        enrichment_summary,
        how="outer",
        left_on="Term",
        right_on="Term",
        validate="many_to_one"
    ).\
    sort_values(
        by=["pathway_times_enriched", "pathway_avg_rank", "cancer_type"],
        ascending=[False, True, True]
    )

enrichment_data
# Out:
#                                         Term        es        nes      pval  \
# 208                 Phenylalanine metabolism  0.657807   1.854341  0.003534
# 209                 Phenylalanine metabolism  0.706748   1.827627  0.000000
# 210                 Phenylalanine metabolism  0.654913   1.666574  0.006757
# 211                 Phenylalanine metabolism  0.558013   1.341542  0.106312
# 212                 Phenylalanine metabolism  0.778940   2.015247  0.000000
# 213                 Phenylalanine metabolism  0.686332   1.751579  0.013699
# 214                 Phenylalanine metabolism  0.615792   1.629164  0.014035
# 215                 Phenylalanine metabolism  0.733474   1.908044  0.000000
# 816                  African trypanosomiasis  0.515014   1.449684  0.043189
# 817                  African trypanosomiasis  0.605373   1.677812  0.013423
# 818                  African trypanosomiasis  0.508859   1.362123  0.097720
# 819                  African trypanosomiasis  0.570108   1.544051  0.009709
# 820                  African trypanosomiasis  0.577735   1.574366  0.009868
# 821                  African trypanosomiasis  0.551190   1.525737  0.029703
# 822                  African trypanosomiasis  0.644275   1.838677  0.000000
# 823                  African trypanosomiasis  0.594492   1.604029  0.012987
# 904                     Serotonergic synapse  0.477601   1.415118  0.000000
# 905                     Serotonergic synapse  0.587271   1.757455  0.000000
# 906                     Serotonergic synapse  0.456858   1.334571  0.035484
# 907                     Serotonergic synapse  0.583508   1.797619  0.000000
# 908                     Serotonergic synapse  0.506585   1.472052  0.006452
# 909                     Serotonergic synapse  0.482597   1.454758  0.009677
# 910                     Serotonergic synapse  0.563328   1.678920  0.000000
# 911                     Serotonergic synapse  0.504845   1.490106  0.022581
# 1560                   Circadian entrainment  0.431810   1.254960  0.058065
# 1561                   Circadian entrainment  0.664784   2.007989  0.000000
# 1562                   Circadian entrainment  0.480957   1.404056  0.022581
# 1563                   Circadian entrainment  0.630881   1.962250  0.000000
# 1564                   Circadian entrainment  0.497028   1.449590  0.003226
# 1565                   Circadian entrainment  0.527123   1.615357  0.003226
# ...                                      ...       ...        ...       ...
# 2030                    Steroid biosynthesis  0.327151   0.830201  0.726962
# 2031                    Steroid biosynthesis  0.340224   0.852818  0.733333
# 2400  Cytokine-cytokine receptor interaction  0.253430   0.719153  0.887097
# 2401  Cytokine-cytokine receptor interaction  0.180094   0.487941  0.993528
# 2402  Cytokine-cytokine receptor interaction  0.210072   0.606364  0.987097
# 2403  Cytokine-cytokine receptor interaction  0.131260   0.391923  0.996764
# 2404  Cytokine-cytokine receptor interaction  0.424053   1.265877  0.080645
# 2405  Cytokine-cytokine receptor interaction  0.266268   0.806202  0.861290
# 2406  Cytokine-cytokine receptor interaction  0.289873   0.867206  0.777419
# 2407  Cytokine-cytokine receptor interaction  0.369328   1.065292  0.345161
# 2240          Ubiquitin mediated proteolysis  0.318353   0.974516  0.538710
# 2241          Ubiquitin mediated proteolysis  0.230390   0.686509  0.970968
# 2242          Ubiquitin mediated proteolysis  0.264868   0.812428  0.912903
# 2243          Ubiquitin mediated proteolysis  0.352311   1.087548  0.300000
# 2244          Ubiquitin mediated proteolysis  0.401467   1.226909  0.058065
# 2245          Ubiquitin mediated proteolysis  0.215662   0.655825  0.961290
# 2246          Ubiquitin mediated proteolysis  0.252401   0.758792  0.945161
# 2247          Ubiquitin mediated proteolysis  0.241583   0.716181  0.987097
# 2440                  Fanconi anemia pathway  0.216240   0.575474  0.951140
# 2441                  Fanconi anemia pathway -0.220678 -16.648466  0.866667
# 2442                  Fanconi anemia pathway  0.218710   0.587261  0.974026
# 2443                  Fanconi anemia pathway  0.275570   0.758048  0.837209
# 2444                  Fanconi anemia pathway  0.303265   0.867217  0.720779
# 2445                  Fanconi anemia pathway  0.283107   0.801707  0.816129
# 2446                  Fanconi anemia pathway  0.161636   0.435838  0.993485
# 2447                  Fanconi anemia pathway  0.367532   0.988488  0.521036
# 2456                      Nicotine addiction  0.802609   2.741355  0.000000
# 2457                      Nicotine addiction -0.835396  -2.138030  0.257669
# 2458                      Nicotine addiction -0.709576  -4.863443  0.117647
# 2459                      Nicotine addiction -0.500679  -6.132698  0.290909
#
#            fdr  geneset_size  matched_size  \
# 208   0.046534            17            14
# 209   0.075529            17            11
# 210   0.349311            17            11
# 211   0.186387            17            11
# 212   0.075555            17            11
# 213   0.305905            17            10
# 214   0.184573            17            11
# 215   0.096327            17            11
# 816   0.124090            37            22
# 817   0.093873            37            21
# 818   0.303583            37            22
# 819   0.090558            37            24
# 820   0.099066            37            23
# 821   0.273624            37            20
# 822   0.202581            37            20
# 823   0.163210            37            21
# 904   0.133414           113            58
# 905   0.096944           113            50
# 906   0.344628           113            57
# 907   0.058136           113            70
# 908   0.101205           113            66
# 909   0.299297           113            60
# 910   0.162064           113            55
# 911   0.198528           113            57
# 1560  0.201734            97            55
# 1561  0.067879            97            43
# 1562  0.305705            97            52
# 1563  0.040152            97            76
# 1564  0.111026            97            57
# 1565  0.257314            97            56
# ...        ...           ...           ...
# 2030  0.972592            19            13
# 2031  0.921286            19            14
# 2400  0.939302           294            77
# 2401  0.999203           294            35
# 2402  0.999950           294            74
# 2403  0.998675           294            71
# 2404  0.148261           294           105
# 2405  1.000000           294            81
# 2406  0.953039           294            71
# 2407  0.659451           294            52
# 2240  0.610640           137           119
# 2241  0.987128           137            90
# 2242  0.934840           137           123
# 2243  0.493931           137           119
# 2244  0.172893           137           122
# 2245  1.000000           137           105
# 2246  1.000000           137            98
# 2247  0.988476           137           109
# 2440  0.982856            54            29
# 2441  0.688222            54            10
# 2442  0.994572            54            29
# 2443  0.921794            54            25
# 2444  0.762382            54            42
# 2445  1.000000            54            37
# 2446  1.000000            54            26
# 2447  0.750475            54            24
# 2456  0.000000            40            21
# 2457  0.896643            40             1
# 2458  0.964659            40             3
# 2459  0.918767            40             4
#
#                                                   genes  \
# 208   GLYAT;DDC;PAH;MIF;MAOA;IL4I1;AOC3;GOT2;HPD;GOT...
# 209   AOC3;MAOB;GOT1;MAOA;DDC;GOT2;IL4I1;ALDH1A3;MIF...
# 210   MAOB;IL4I1;AOC3;MAOA;ALDH1A3;ALDH3A1;MIF;ALDH3...
# 211   GOT2;GOT1;ALDH3B1;MIF;MAOA;IL4I1;AOC3;ALDH1A3;...
# 212   MAOB;AOC3;MAOA;GOT1;ALDH3A1;IL4I1;GOT2;MIF;ALD...
# 213   AOC3;MAOB;ALDH3B1;MAOA;IL4I1;GOT2;ALDH1A3;MIF;...
# 214   AOC3;ALDH3B1;MAOB;AOC2;IL4I1;MAOA;MIF;ALDH3A1;...
# 215   MAOB;MAOA;AOC3;ALDH1A3;MIF;ALDH3B1;ALDH3A1;IL4...
# 816   ICAM1;PLCB2;THOP1;VCAM1;PRKCA;IDO1;FAS;HBA2;MY...
# 817   GNAQ;PRKCA;PRKCB;LAMA4;PLCB1;THOP1;APOA1;KNG1;...
# 818   KNG1;APOA1;PRKCA;IL18;LAMA4;PLCB3;HPR;APOL1;FA...
# 819   PRKCG;PLCB1;GNAQ;PRKCB;APOA1;MYD88;KNG1;LAMA4;...
# 820   KNG1;PLCB1;APOA1;HPR;ICAM1;PLCB4;HBA2;HBB;IDO1...
# 821   PLCB1;GNAQ;HBB;HBA2;APOA1;PRKCA;ICAM1;KNG1;HPR...
# 822   GNAQ;HBA2;HBB;APOA1;PLCB1;PLCB4;KNG1;APOL1;PLC...
# 823   LAMA4;APOL1;KNG1;GNAQ;APOA1;HBA1;PLCB3;HBB;PLC...
# 904   ALOX5;DDC;MAPK1;PLCB2;GNG10;ITPR3;PRKCA;GNAI2;...
# 905   GNAO1;PTGS1;GNG2;MAOB;GNB1;ITPR1;PRKACB;GNAQ;G...
# 906   GNG11;GNAO1;MAOB;PRKCA;GNG7;MAPK3;CASP3;PLCB3;...
# 907   BRAF;PRKCG;ITPR1;CACNA1A;GNG3;GNB1;GNB5;GNAI1;...
# 908   MAPK3;MAOB;GNG11;PLCB1;APP;ITPR3;MAOA;GNB2;GNB...
# 909   MAPK3;GNG11;PLCB1;MAOB;GNAQ;GNB2;PLA2G4F;ALOX1...
# 910   GNAQ;MAPK3;PLCB1;PLCB4;SLC6A4;GNG11;CASP3;GNAI...
# 911   GNG11;MAOB;MAOA;GNG12;GNAI1;GNB3;GNAQ;ITPR1;CA...
# 1560  MAPK1;PLCB2;GNG10;ITPR3;PRKCA;GNAI2;CALML4;NOS...
# 1561  GNAO1;GNG2;GNB1;ITPR1;CAMK2G;PRKACB;GNAQ;CAMK2...
# 1562  GNG11;GNAO1;PRKCA;GNG7;MAPK3;PLCB3;GUCY1A2;GUC...
# 1563  PRKCG;ITPR1;CALM2;GRIN2A;GNG3;GNB1;GRIN2B;RYR2...
# 1564  MAPK3;GNG11;PLCB1;ITPR3;GNB2;GNB1;CALM1;PLCB4;...
# 1565  MAPK3;GNG11;PLCB1;GUCY1A2;GUCY1B1;PRKG1;GNAQ;G...
# ...                                                 ...
# 2030  LSS;SOAT1;CYP51A1;LIPA;SQLE;TM7SF2;DHCR24;NSDH...
# 2031  LSS;SQLE;EBP;LIPA;DHCR24;DHCR7;MSMO1;SC5D;SOAT...
# 2400  CD70;CD4;TGFB1;IFNGR1;IL16;INHBE;INHBC;CSF1R;C...
# 2401  CXCL12;FAS;PPBP;CSF1R;IL16;IFNGR1;CD4;CCL15;PF...
# 2402  CCL14;IL18;IL33;CXCL12;FAS;IL1RN;CTF1;BMPR1B;T...
# 2403  BMPR2;TNFRSF21;CNTFR;TNFRSF12A;ACVR2A;TGFB1;IL...
# 2404  IL33;CCL14;IL1RN;TGFB1;IL36A;TGFB3;GDF10;CXCL1...
# 2405  TGFBR2;IL6ST;ACVRL1;IL33;PPBP;GDF10;PF4;LIFR;C...
# 2406  TGFBR2;IL33;PPBP;PF4;BMPR2;IL6ST;ACVRL1;LIFR;C...
# 2407  IL33;CXCL12;PF4;IL6ST;CNTFR;PPBP;PF4V1;CCL14;C...
# 2240  UBE2L6;DDB2;PML;UBE2Z;CBL;NEDD4;UBE2Q1;CUL4B;U...
# 2241  PRPF19;PML;UBE2I;SAE1;UBA2;ANAPC7;CUL5;MID1;NE...
# 2242  NEDD4;FBXW8;NEDD4L;BIRC6;DET1;PRKN;UBE2G1;UBR5...
# 2243  HERC1;CUL3;TRIM32;UBE2O;SKP1;CUL1;UBE2Q1;UBE3B...
# 2244  CDC27;PML;ANAPC7;UBE2Z;UBE2L6;UBE2C;UBA6;UBE2M...
# 2245  CUL4B;UBR5;UBE2C;ANAPC7;CDC27;PRPF19;WWP2;NEDD...
# 2246  ELOB;NEDD4;CUL4B;CBL;ELOC;UBE2J1;HUWE1;WWP2;AN...
# 2247  PRPF19;UBE2E1;ELOB;NEDD4;UBE2E3;UBE2E2;CUL4B;S...
# 2440  RPA2;RPA1;RPA3;TELO2;FANCI;HES1;ERCC1;PMS2;POL...
# 2441  RPA2;FANCI;WDR48;UBE2T;RPA1;TOP3B;RPA3;CENPX;M...
# 2442  FANCI;RMI1;ATR;FANCD2;REV3L;POLI;TOP3A;CENPS-C...
# 2443  WDR48;ERCC4;BLM;RPA1;TELO2;MLH1;FANCI;RMI1;ATR...
# 2444  FANCI;TELO2;RPA3;PMS2;TOP3A;WDR48;UBE2T;ERCC1;...
# 2445  REV1;WDR48;ATR;FANCI;UBE2T;TELO2;BLM;MLH1;RPA1...
# 2446  WDR48;REV1;POLI;MLH1;SLX4;BRCA1;RPA1;RPA3;ERCC...
# 2447  RPA3;ATR;RPA1;RPA2;UBE2T;FANCD2;BLM;FANCI;POLI...
# 2456  CACNA1A;GRIN2A;GRIN2B;GRIN1;GRIA3;GRIA2;GABRG2...
# 2457                                             GABRB1
# 2458                             CACNA1A;CACNA1B;GABRG2
# 2459                        GABRG2;GRIN1;CACNA1A;GABRA4
#
#                                             ledge_genes  cancer_type  \
# 208     GLYAT;DDC;PAH;MIF;MAOA;IL4I1;AOC3;GOT2;HPD;GOT1        ccrcc
# 209                                 AOC3;MAOB;GOT1;MAOA        colon
# 210                                MAOB;IL4I1;AOC3;MAOA  endometrial
# 211                                           GOT2;GOT1          gbm
# 212                   MAOB;AOC3;MAOA;GOT1;ALDH3A1;IL4I1        hnscc
# 213                        AOC3;MAOB;ALDH3B1;MAOA;IL4I1         lscc
# 214                        AOC3;ALDH3B1;MAOB;AOC2;IL4I1         luad
# 215                          MAOB;MAOA;AOC3;ALDH1A3;MIF      ovarian
# 816   ICAM1;PLCB2;THOP1;VCAM1;PRKCA;IDO1;FAS;HBA2;MY...        ccrcc
# 817   GNAQ;PRKCA;PRKCB;LAMA4;PLCB1;THOP1;APOA1;KNG1;...        colon
# 818               KNG1;APOA1;PRKCA;IL18;LAMA4;PLCB3;HPR  endometrial
# 819   PRKCG;PLCB1;GNAQ;PRKCB;APOA1;MYD88;KNG1;LAMA4;...          gbm
# 820           KNG1;PLCB1;APOA1;HPR;ICAM1;PLCB4;HBA2;HBB        hnscc
# 821   PLCB1;GNAQ;HBB;HBA2;APOA1;PRKCA;ICAM1;KNG1;HPR...         lscc
# 822   GNAQ;HBA2;HBB;APOA1;PLCB1;PLCB4;KNG1;APOL1;PLC...         luad
# 823   LAMA4;APOL1;KNG1;GNAQ;APOA1;HBA1;PLCB3;HBB;PLC...      ovarian
# 904   ALOX5;DDC;MAPK1;PLCB2;GNG10;ITPR3;PRKCA;GNAI2;...        ccrcc
# 905   GNAO1;PTGS1;GNG2;MAOB;GNB1;ITPR1;PRKACB;GNAQ;G...        colon
# 906   GNG11;GNAO1;MAOB;PRKCA;GNG7;MAPK3;CASP3;PLCB3;...  endometrial
# 907   BRAF;PRKCG;ITPR1;CACNA1A;GNG3;GNB1;GNB5;GNAI1;...          gbm
# 908   MAPK3;MAOB;GNG11;PLCB1;APP;ITPR3;MAOA;GNB2;GNB...        hnscc
# 909   MAPK3;GNG11;PLCB1;MAOB;GNAQ;GNB2;PLA2G4F;ALOX1...         lscc
# 910   GNAQ;MAPK3;PLCB1;PLCB4;SLC6A4;GNG11;CASP3;GNAI...         luad
# 911   GNG11;MAOB;MAOA;GNG12;GNAI1;GNB3;GNAQ;ITPR1;CA...      ovarian
# 1560  MAPK1;PLCB2;GNG10;ITPR3;PRKCA;GNAI2;CALML4;NOS...        ccrcc
# 1561  GNAO1;GNG2;GNB1;ITPR1;CAMK2G;PRKACB;GNAQ;CAMK2...        colon
# 1562  GNG11;GNAO1;PRKCA;GNG7;MAPK3;PLCB3;GUCY1A2;GUC...  endometrial
# 1563  PRKCG;ITPR1;CALM2;GRIN2A;GNG3;GNB1;GRIN2B;RYR2...          gbm
# 1564  MAPK3;GNG11;PLCB1;ITPR3;GNB2;GNB1;CALM1;PLCB4;...        hnscc
# 1565  MAPK3;GNG11;PLCB1;GUCY1A2;GUCY1B1;PRKG1;GNAQ;G...         lscc
# ...                                                 ...          ...
# 2030    LSS;SOAT1;CYP51A1;LIPA;SQLE;TM7SF2;DHCR24;NSDHL         luad
# 2031                     LSS;SQLE;EBP;LIPA;DHCR24;DHCR7      ovarian
# 2400  CD70;CD4;TGFB1;IFNGR1;IL16;INHBE;INHBC;CSF1R;C...        ccrcc
# 2401  CXCL12;FAS;PPBP;CSF1R;IL16;IFNGR1;CD4;CCL15;PF...        colon
# 2402  CCL14;IL18;IL33;CXCL12;FAS;IL1RN;CTF1;BMPR1B;T...  endometrial
# 2403  BMPR2;TNFRSF21;CNTFR;TNFRSF12A;ACVR2A;TGFB1;IL...          gbm
# 2404  IL33;CCL14;IL1RN;TGFB1;IL36A;TGFB3;GDF10;CXCL1...        hnscc
# 2405  TGFBR2;IL6ST;ACVRL1;IL33;PPBP;GDF10;PF4;LIFR;C...         lscc
# 2406  TGFBR2;IL33;PPBP;PF4;BMPR2;IL6ST;ACVRL1;LIFR;C...         luad
# 2407  IL33;CXCL12;PF4;IL6ST;CNTFR;PPBP;PF4V1;CCL14;C...      ovarian
# 2240  UBE2L6;DDB2;PML;UBE2Z;CBL;NEDD4;UBE2Q1;CUL4B;U...        ccrcc
# 2241  PRPF19;PML;UBE2I;SAE1;UBA2;ANAPC7;CUL5;MID1;NE...        colon
# 2242  NEDD4;FBXW8;NEDD4L;BIRC6;DET1;PRKN;UBE2G1;UBR5...  endometrial
# 2243  HERC1;CUL3;TRIM32;UBE2O;SKP1;CUL1;UBE2Q1;UBE3B...          gbm
# 2244  CDC27;PML;ANAPC7;UBE2Z;UBE2L6;UBE2C;UBA6;UBE2M...        hnscc
# 2245  CUL4B;UBR5;UBE2C;ANAPC7;CDC27;PRPF19;WWP2;NEDD...         lscc
# 2246  ELOB;NEDD4;CUL4B;CBL;ELOC;UBE2J1;HUWE1;WWP2;AN...         luad
# 2247  PRPF19;UBE2E1;ELOB;NEDD4;UBE2E3;UBE2E2;CUL4B;S...      ovarian
# 2440  RPA2;RPA1;RPA3;TELO2;FANCI;HES1;ERCC1;PMS2;POL...        ccrcc
# 2441  RPA2;FANCI;WDR48;UBE2T;RPA1;TOP3B;RPA3;CENPX;M...        colon
# 2442  FANCI;RMI1;ATR;FANCD2;REV3L;POLI;TOP3A;CENPS-C...  endometrial
# 2443  WDR48;ERCC4;BLM;RPA1;TELO2;MLH1;FANCI;RMI1;ATR...          gbm
# 2444  FANCI;TELO2;RPA3;PMS2;TOP3A;WDR48;UBE2T;ERCC1;...        hnscc
# 2445  REV1;WDR48;ATR;FANCI;UBE2T;TELO2;BLM;MLH1;RPA1...         lscc
# 2446                                         WDR48;REV1         luad
# 2447  RPA3;ATR;RPA1;RPA2;UBE2T;FANCD2;BLM;FANCI;POLI...      ovarian
# 2456  CACNA1A;GRIN2A;GRIN2B;GRIN1;GRIA3;GRIA2;GABRG2...          gbm
# 2457                                             GABRB1        hnscc
# 2458                             CACNA1A;CACNA1B;GABRG2         lscc
# 2459                        GABRG2;GRIN1;CACNA1A;GABRA4         luad
#
#       cancer_rank_fdr  pathway_times_enriched  pathway_avg_rank
# 208              27.0                       8           41.0000
# 209               9.0                       8           41.0000
# 210              68.0                       8           41.0000
# 211             147.0                       8           41.0000
# 212              16.0                       8           41.0000
# 213              41.0                       8           41.0000
# 214              19.0                       8           41.0000
# 215               1.0                       8           41.0000
# 816             103.0                       8           43.8750
# 817              21.0                       8           43.8750
# 818              12.0                       8           43.8750
# 819              81.0                       8           43.8750
# 820              56.0                       8           43.8750
# 821              27.0                       8           43.8750
# 822              26.0                       8           43.8750
# 823              25.0                       8           43.8750
# 904             114.0                       8           51.2500
# 905              26.0                       8           51.2500
# 906              59.0                       8           51.2500
# 907              40.0                       8           51.2500
# 908              70.0                       8           51.2500
# 909              38.0                       8           51.2500
# 910              13.0                       8           51.2500
# 911              50.0                       8           51.2500
# 1560            196.0                       8           55.7500
# 1561              6.0                       8           55.7500
# 1562             16.0                       8           55.7500
# 1563             20.0                       8           55.7500
# 1564            160.0                       8           55.7500
# 1565             17.0                       8           55.7500
# ...               ...                     ...               ...
# 2030            257.0                       8          261.9375
# 2031            253.0                       8          261.9375
# 2400            301.0                       8          266.3125
# 2401            301.0                       8          266.3125
# 2402            307.0                       8          266.3125
# 2403            306.0                       8          266.3125
# 2404            237.0                       8          266.3125
# 2405            252.5                       8          266.3125
# 2406            245.0                       8          266.3125
# 2407            181.0                       8          266.3125
# 2240            281.0                       8          268.6250
# 2241            292.0                       8          268.6250
# 2242            275.0                       8          268.6250
# 2243            214.0                       8          268.6250
# 2244            258.0                       8          268.6250
# 2245            252.5                       8          268.6250
# 2246            291.5                       8          268.6250
# 2247            285.0                       8          268.6250
# 2440            306.0                       8          269.7500
# 2441            207.0                       8          269.7500
# 2442            297.0                       8          269.7500
# 2443            290.0                       8          269.7500
# 2444            304.0                       8          269.7500
# 2445            252.5                       8          269.7500
# 2446            291.5                       8          269.7500
# 2447            210.0                       8          269.7500
# 2456              1.5                       4          175.6250
# 2457            307.0                       4          175.6250
# 2458            170.0                       4          175.6250
# 2459            224.0                       4          175.6250
#
# [2460 rows x 13 columns]

# %% [markdown]
# ## Figure 1: Bubble plot

# %%
# Select top 10 for our plot
top_ten = enrichment_data["Term"].unique()[:10]
sel_enrich = enrichment_data[enrichment_data["Term"].isin(top_ten)]

# %%
# Calculate the mean expression for each pathway in each cancer type
mean_exprs = []

for idx in sel_enrich.index:
    genes = sel_enrich.loc[idx, "genes"].split(";")
    cancer_type = sel_enrich.loc[idx, "cancer_type"]
    
    genes_expr = expression_data.loc[
        expression_data["protein_str"].isin(genes),
        "simplified_change"
    ].mean()
    
    mean_exprs.append(genes_expr)
    
sel_enrich = sel_enrich.assign(mean_expr=mean_exprs)

# %%
sel_enrich = sel_enrich.assign(
    rank_size=1 / sel_enrich["cancer_rank_fdr"],
    avg_rank_size=1 / sel_enrich["pathway_avg_rank"])

individual = alt.Chart(sel_enrich).mark_circle().encode(
    x=alt.X(
        "Term:N",
        sort=sel_enrich["Term"].values,
        axis=alt.Axis(
            labelAngle=-30,
            labelFontSize=12,
            labelLimit=500,
            title="",
            titleFontSize=12
        )
    ),
    y=alt.Y(
        "cancer_type:N",
        axis=alt.Axis(
            title="Cancer type",
            titleFontSize=12
        ),
    ),
    size=alt.Size(
        "rank_size:Q",
        legend=None
    ),
    color=alt.Color(
        "mean_expr:Q",
        scale=alt.Scale(
            scheme="blueorange",
            domain=[-1, 1]
        ),
        legend=alt.Legend(
            title="Pathway tumor expression"
        )
    )
).properties(
    width=400,
    height=300
)

aggregate = alt.Chart(sel_enrich).mark_circle().encode(
    x=alt.X(
        "pathway_avg_rank:N",
        sort=sel_enrich["pathway_avg_rank"].values,
        axis=alt.Axis(
            labelAngle=-30,
            labelFontSize=12,
            labelLimit=500,
            title="Overall rank of pathway",
            titleFontSize=12
        )
    ),
    size=alt.Size(
        "avg_rank_size:Q",
        legend=None
    ),
).properties(
    width=400
)

alt.vconcat(aggregate, individual).configure_axis(
    grid=True
)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Figure 2: Expression of proteins in the neutrophil degranulation pathway

# %%
# Get the ID the top expessed pathway
neutro_pathway_ids = enrichment_data.\
    loc[enrichment_data["name"] == "Neutrophil degranulation", "pathway_id"].\
    unique()

if len(neutro_pathway_ids) != 1:
    raise ValueError("Multiple pathways found.")
    
neutro_pathway_id = neutro_pathway_ids[0]

# %% [markdown]
# ### A: With proteins in different orders for the up and down categories

# %%
def expr_heatmap(expr_data, enrich_data, pathway_id, up_or_down, max_p, x_title=True):
    """Make a heatmap with proteins on the X axis, cancer types on the Y 
    axis, and the color reflecting the expression of that protein in that
    cancer type.
    
    Parameters:
    expr_data (pandas.DataFrame): A dataframe with columns "cancer_type", "protein_str", "adj_p", and "simplified_change".
    enrich_data (pandas.DataFrame): A dataframe with columns "cancer_type" and "mean_expr" (i.e. mean expression for the pathway of interest).
    pathway_id (str): The Reactome pathway id for the pathway you want the heatmap for.
    up_or_down (str): Either "up" or "down"; whether to plot cancers where the pathway is up, or where it's down.
    max_p (float): The minimum p value for a protein to be included on the plot. If max_p > 0.05, then proteins with 0.05 <= p < max_p will be marked as marginally significant.
    x_title (bool): Whether to include an x axis title.
    
    Returns:
    altair.Chart: The heatmap.
    """
    # Filter expression data by p value
    expr_data = expr_data[expr_data["adj_p"] < max_p]
    
    # Get expression data for proteins in the pathway
    pathway_proteins = ut.search_reactome_proteins_in_pathways(pathway_id)
    pathway_expr = expr_data[expr_data["protein_str"].isin(pathway_proteins["member"])]
    
    # Categorize the cancer types as the neutrophil degranulation pathway's mean expression being up or down
    if up_or_down == "up":
        comparison = operator.gt
    elif up_or_down == "down":
        comparison = operator.lt
    else:
        raise ValueError(f"Invalid value for up_or_down parameter: '{up_or_down}'")
    
    sel_cancers = enrich_data.\
        loc[(enrich_data["pathway_id"] == neutro_pathway_id) & (comparison(enrich_data["mean_expr"], 0)),
           ["cancer_type", "mean_expr"]]

    # Select data for the specified cancer types
    selected_expr_data = pathway_expr[pathway_expr["cancer_type"].isin(sel_cancers["cancer_type"])]

    # Sort proteins by mean expression across selected cancer types
    prot_order = selected_expr_data.groupby("protein_str")[["simplified_change", "cancer_type"]].\
        agg({
            "simplified_change": np.mean,
            "cancer_type": "count"
        })

    prot_order = prot_order.assign(
            cancer_type=np.copysign(prot_order["cancer_type"], prot_order["simplified_change"])
        ).\
        sort_values(by=["simplified_change", "cancer_type"])

    # Sort cancer types by mean pathway expression
    cancer_order = sel_cancers.\
        sort_values(by="mean_expr", ascending=False).\
        loc[:, "cancer_type"]
    
    # Map simplified_change to legend values
    selected_expr_data = selected_expr_data.assign(
        tumor_up_down=selected_expr_data["simplified_change"].replace({
            1: "Up (adj p < 0.05)",
            MSV: f"Up (0.05 <= adj p < {max_p})",
            0: "No change",
            -MSV: f"Down (0.05 <= adj p < {max_p})",
            -1: "Down (adj p < 0.05)"
        })
    )
    
    # Plot
    plot = alt.Chart(selected_expr_data).mark_rect().encode(
        x=alt.X(
            "protein_str:N",
            sort=prot_order.index.values,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=f"Proteins for {pathway_id} (different order in each facet)" if x_title else ""
            )
        ),
        y=alt.Y(
            "cancer_type:N",
            sort=cancer_order.values,
            axis=alt.Axis(
                title=f"Pathway {up_or_down} in tumor"
            )
        ),
        color=alt.Color(
            "tumor_up_down:N",
            scale=alt.Scale(
                domain=[
                    "Up (adj p < 0.05)",
                    f"Up (0.05 <= adj p < {max_p})",
                    "No change",
                    f"Down (0.05 <= adj p < {max_p})",
                    "Down (adj p < 0.05)"
                ],
                range=["#bf363a",
                       "#f6bda4",
                       "#f2efee",
                       "#afd3e6",
                       "#1e588a"
                ]
            ),
            legend=alt.Legend(
                title="Expression in tumor"
            )
        ),
    ).properties(
        width=700,
        height=175
    )
    
    return plot

# %%
# Plot
alt.vconcat(
    expr_heatmap(all_expression_data, enrichment_data, neutro_pathway_id, "up", max_p=0.2, x_title=False),
    expr_heatmap(all_expression_data, enrichment_data, neutro_pathway_id, "down", max_p=0.2)
)

# %% [markdown]
# ### B: With same sorting for both

# %%
def expr_heatmap_alt_sort(expr_data, enrich_data, pathway_id, max_p):
    """Make a heatmap with proteins on the X axis, cancer types on the Y 
    axis, and the color reflecting the expression of that protein in that
    cancer type.
    
    Parameters:
    expr_data (pandas.DataFrame): A dataframe with columns "cancer_type", "protein_str", "adj_p", and "simplified_change".
    enrich_data (pandas.DataFrame): A dataframe with columns "cancer_type" and "mean_expr" (i.e. mean expression for the pathway of interest).
    pathway_id (str): The Reactome pathway id for the pathway you want the heatmap for.
    up_or_down (str): Either "up" or "down"; whether to plot cancers where the pathway is up, or where it's down.
    max_p (float): The minimum p value for a protein to be included on the plot. If max_p > 0.05, then proteins with 0.05 <= p < max_p will be marked as marginally significant.
    
    Returns:
    altair.Chart: The heatmap.
    """
    # Filter expression data by p value
    expr_data = expr_data[expr_data["adj_p"] < max_p]
    
    # Get expression data for proteins in the pathway
    pathway_proteins = ut.search_reactome_proteins_in_pathways(pathway_id)
    pathway_expr = expr_data[expr_data["protein_str"].isin(pathway_proteins["member"])]
    
    # Sort proteins by mean expression across all cancer types
    prot_order = pathway_expr.groupby("protein_str")[["simplified_change", "cancer_type"]].\
        agg({
            "simplified_change": np.mean,
            "cancer_type": "count"
        })

    prot_order = prot_order.assign(
            cancer_type=np.copysign(prot_order["cancer_type"], prot_order["simplified_change"])
        ).\
        sort_values(by=["simplified_change", "cancer_type"])

    # Sort cancer types by mean pathway expression
    sel_cancers = enrich_data.\
        loc[enrich_data["pathway_id"] == neutro_pathway_id, ["cancer_type", "mean_expr"]]
        
    sel_cancers = sel_cancers.\
        assign(up_or_down=np.where(sel_cancers["mean_expr"] > 0, "Pathway up in tumor", "Pathway down in tumor")).\
        sort_values(by="mean_expr", ascending=False).\
        loc[:, ["cancer_type", "up_or_down"]]
    
    cancer_order = sel_cancers["cancer_type"].values
    
    pathway_expr = pathway_expr.merge(
        right=sel_cancers,
        how="inner",
        left_on="cancer_type",
        right_on="cancer_type",
        validate="many_to_one"
    )
    
    # Map simplified_change to legend values
    pathway_expr = pathway_expr.assign(
        tumor_up_down=pathway_expr["simplified_change"].replace({
            1: "Up (adj p < 0.05)",
            MSV: f"Up (0.05 <= adj p < {max_p})",
            0: "No change",
            -MSV: f"Down (0.05 <= adj p < {max_p})",
            -1: "Down (adj p < 0.05)"
        })
    )
    
    # Plot
    plot = alt.Chart(pathway_expr).mark_rect().encode(
        x=alt.X(
            "protein_str:N",
            sort=prot_order.index.values,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=f"Proteins for {pathway_id} (same order in both facets)"
            )
        ),
        y=alt.Y(
            "cancer_type:N",
            sort=cancer_order,
            axis=alt.Axis(
                title=""
            )
        ),
        color=alt.Color(
            "tumor_up_down:N",
            scale=alt.Scale(
                domain=[
                    "Up (adj p < 0.05)",
                    f"Up (0.05 <= adj p < {max_p})",
                    "No change",
                    f"Down (0.05 <= adj p < {max_p})",
                    "Down (adj p < 0.05)"
                ],
                range=["#bf363a",
                       "#f6bda4",
                       "#f2efee",
                       "#afd3e6",
                       "#1e588a"
                ]
            ),
            legend=alt.Legend(
                title="Expression in tumor"
            )
        ),
        row=alt.Row(
            "up_or_down:N",
            sort="descending",
            title="",
            header=alt.Header(
                labelFontStyle="bold"
            )
        )
    ).properties(
        width=600,
        height=150
    ).resolve_scale(
        y="independent" # This makes it so each facet (up or down) only has the cancers that are in that category
    )
    
    return plot

# %%
# Plot
expr_heatmap_alt_sort(all_expression_data, enrichment_data, neutro_pathway_id, max_p=0.2)

# %% [markdown]
# ## Figure 3: Pathway overlay for neutrophil degranulation

# %%
def pathway_overlay_wrapper(pathway_id, exp_data, enrich_data, up_or_down):
    
    prots = ut.search_reactome_proteins_in_pathways(pathway_id)
    
    # Categorize the cancer types as the neutrophil degranulation pathway's mean expression being up or down
    if up_or_down == "up":
        comparison = operator.gt
    elif up_or_down == "down":
        comparison = operator.lt
    else:
        raise ValueError(f"Invalid value for up_or_down parameter: '{up_or_down}'")
    
    sel_cancers = enrich_data.\
        loc[(enrich_data["pathway_id"] == neutro_pathway_id) & (comparison(enrich_data["mean_expr"], 0)),
            "cancer_type"]
    
    # Select the desired expression data and average the simplified change across cancer types
    sel_exp = exp_data.\
        loc[
            exp_data["protein_str"].isin(prots["member"]) & 
            exp_data["cancer_type"].isin(sel_cancers),
            ["protein_str", "simplified_change"]
        ].\
        groupby("protein_str").\
        agg(np.mean).\
        rename(columns={"simplified_change": f"{up_or_down}_simp_change"})
    
    img_name = f"{TIME_START}_{pathway_id}_{up_or_down}.png"
    img_path = os.path.join(STEP7_DIR, img_name)
    
    token, _ = ut.reactome_enrichment_analysis(
        analysis_type="ranked", 
        data=sel_exp, 
        sort_by="ENTITIES_FDR", 
        ascending=True,
        include_high_level_diagrams=True, 
        include_interactors=False)
    
    _, img_path = ut.reactome_pathway_overlay(
        analysis_token=token,
        pathway=pathway_id,
        open_browser=False,
        export_path=img_path,
        image_format="png",
        display_col_idx=None,
        diagram_colors="Modern",
        overlay_colors="Standard",
        quality=10
    )

    _, url = ut.reactome_pathway_overlay(
        analysis_token=token,
        pathway=pathway_id,
        open_browser=False,
    )

    return img_path, url

# %%
# Note that we're using expression_data, not all_expression_data; the former has
# only proteins where reject_null

up_image_path, up_url = pathway_overlay_wrapper(neutro_pathway_id, expression_data, enrichment_data, "up")

# %%
IPython.display.HTML(f'<a href={up_url}>{up_url}</a>')

# %%
IPython.display.Image(up_image_path)

# %%
# Note that we're using expression_data, not all_expression_data; the former has
# only proteins where reject_null

down_image_path, down_url = pathway_overlay_wrapper(neutro_pathway_id, expression_data, enrichment_data, "down")

# %%
IPython.display.HTML(f'<a href={down_url}>{down_url}</a>')

# %%
IPython.display.Image(down_image_path)

# %% [markdown]
# ## Figure 4: Distribution of tumor stage in each cancer
# Since neutrophil degranulation is associated with tumor progression, we want to check that it's not just up in cohorts with more high stage tumors, and down in cohorts with more low stage tumors.

# %%
cc = cptac.Ccrcc(no_internet=True)
co = cptac.Colon(no_internet=True)
en = cptac.Endometrial(no_internet=True)
gb = cptac.Gbm(no_internet=True)
hn = cptac.Hnscc(no_internet=True)
ls = cptac.Lscc(no_internet=True)
lu = cptac.Luad(no_internet=True)
ov = cptac.Ovarian(no_internet=True)

# %%
stage_df = pd.DataFrame()

# %%
cc_stage = cc.get_clinical()["tumor_stage_pathological"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="ccrcc")

stage_df = stage_df.append(cc_stage)

# %%
co_stage = co.get_clinical()["Stage"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="colon")

stage_df = stage_df.append(co_stage)

# %%
en_stage = en.get_clinical()["tumor_Stage-Pathological"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="endometrial")

stage_df = stage_df.append(en_stage)

# %%
# GBM: All tumors are stage IV
gb_stage = pd.Series("IV", gb.get_clinical().index).\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="gbm")

gb_stage
stage_df = stage_df.append(gb_stage)

# %%
hn_stage = hn.get_clinical()["patho_staging_curated"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="hnscc")

stage_df = stage_df.append(hn_stage)

# %%
ls_stage = ls.get_clinical()["Stage"]
ls_stage = ls_stage.\
    rename("tumor_stage").\
    where(
        cond=~(ls_stage.dropna().str.endswith("A") | ls_stage.dropna().str.endswith("B")),
        other=ls_stage.str[:-1]).\
    where(
        cond=~(ls_stage.dropna().str.endswith("A 3")),
        other=ls_stage.dropna().str[:-3]
    ).\
    reset_index(drop=False).\
    assign(cancer_type="lscc")

stage_df = stage_df.append(ls_stage)

# %%
lu_stage = lu.get_clinical()["Stage"]
lu_stage = lu_stage.\
    rename("tumor_stage").\
    where(
        cond=~(lu_stage.dropna().str.endswith("A") | lu_stage.dropna().str.endswith("B")),
        other=lu_stage.str[:-1]).\
    replace({
        "1": "I",
        "2": "II",
        "3": "III"}).\
    reset_index(drop=False).\
    assign(cancer_type="luad")

stage_df = stage_df.append(lu_stage)

# %%
ov_stage = ov.get_clinical()["Tumor_Stage_Ovary_FIGO"]
ov_stage = ov_stage.\
    rename("tumor_stage").\
    where(
        cond=~(ov_stage.dropna().str.endswith("A") | 
               ov_stage.dropna().str.endswith("B") | 
               ov_stage.dropna().str.endswith("C")),
        other=ov_stage.str[:-1]).\
    drop(ov_stage[ov_stage == "Not Reported/ Unknown"].index).\
    reset_index(drop=False).\
    assign(cancer_type="ovarian")

stage_df = stage_df.append(ov_stage)

# %%
# Drop NaN samples
stage_df = stage_df.dropna()

# Drop normal samples (to avoid duplicate counts)
stage_df = stage_df[~stage_df["Patient_ID"].str.endswith(".N")]

# %%
# Join in whether neutrophil expression is up or down in tumor
neutro_expr = enrichment_data.loc[
    enrichment_data["pathway_id"] == neutro_pathway_id, 
    ["cancer_type", "name", "pathway_id", "mean_expr"]]

neutro_expr

# %%
stage_df = stage_df.merge(
    right=neutro_expr,
    how="left",
    left_on="cancer_type",
    right_on="cancer_type",
    validate="many_to_one")

# %%
# Make plots
alt.Chart(stage_df).mark_bar().encode(
    x=alt.X(
        "tumor_stage:N",
        axis=alt.Axis(
            labelAngle=0,
            labelFontSize=14,
            title=""
        )
    ),
    y=alt.Y(
        "count():Q",
        axis=alt.Axis(
            title="Count",
            titleFontSize=12
        )
    ),
    color=alt.Color(
        "mean_expr:Q",
        scale=alt.Scale(
            scheme="blueorange",
            domain=[-1, 1]
        ),
        legend=alt.Legend(
            title=["Neutrophil degranulation:", "Mean pathway expression", "in tumor"]
        )
    ),
    column=alt.Column(
        "cancer_type:N",
        title="Tumor stage distributions",
    )
).properties(
    width=65
).configure_header(
    titleFontSize=12
)

# %%
# Ask Sam: Is this idea of "mean pathway expression" 
# really valid? What if in reality, though we can't
# measure it, some proteins' magnitude of expression 
# change is a lot greater, so they should actually
# have greater weight in the mean calculation, and
# thus might alter the overall statistic for the
# pathway?
