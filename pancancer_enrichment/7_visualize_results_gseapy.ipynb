# %% [markdown]
# # Pancancer enrichment analysis step 7: Make figures from GSEApy data

# %% [markdown]
# ## Setup

# %%
import cptac
import cptac.utils as ut
import os
import datetime
import altair as alt
import numpy as np
import pandas as pd
import operator
import IPython.display

# %%
TIME_START = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

STEP1_DIR = "step1_outputs"
STEP1_FILE = "tumor_change_20200529_195104_10000_perm.tsv"
STEP1_FILE_PATH = os.path.join(STEP1_DIR, STEP1_FILE)

STEP5_DIR = "step5_outputs"
STEP5_FILE = "enrichment_gseapy_reactome_20200616_124447.tsv"
STEP5_FILE_PATH = os.path.join(STEP5_DIR, STEP5_FILE)

STEP7_DIR = "step7_outputs"

if not os.path.isdir(STEP7_DIR):
    os.mkdir(STEP7_DIR)
    
MSV = 0.5 # Simplified expression value for marginally significant proteins

# %%
# Altair options
# alt.data_transformers.disable_max_rows()
# alt.data_transformers.enable('json')

# %% [markdown]
# ## Read in data from steps 1, 5, and 6

# %%
all_expression_data = pd.read_csv(STEP1_FILE_PATH, sep="\t", index_col=0)

# Make a column where all increases are +1 and all decreases 
# are -1, because these are ratioed abundances, so we can't 
# compare magnitudes between genes--we can only compare whether 
# there was a change, and whether it was positive or negative
all_expression_data = all_expression_data.assign(simplified_change=np.nan)

# adj p < 0.05 and change > 1 => +1
all_expression_data.loc[
    (all_expression_data["change"] > 0) & (all_expression_data["adj_p"] < 0.05), 
    "simplified_change"
] = 1

# adj p >= 0.05 and change > 1 => +0.5
all_expression_data.loc[(all_expression_data["change"] > 0) & (all_expression_data["adj_p"] >= 0.05),
    "simplified_change"
] = MSV

# change == 0 => 0
all_expression_data.loc[
    all_expression_data["change"] == 0,
    "simplified_change"
] = 0

# adj p >= 0.05 and change < 1 => -0.5
all_expression_data.loc[(all_expression_data["change"] < 0) & (all_expression_data["adj_p"] >= 0.05), 
    "simplified_change"
] = -MSV

# adj p < 0.05 and change < 1 => -1
all_expression_data.loc[
    (all_expression_data["change"] < 0) & (all_expression_data["adj_p"] < 0.05),
    "simplified_change"
] = -1

# Select just the proteins where we chose to reject the null hypothesis of no change
expression_data = all_expression_data[all_expression_data["reject_null"]]

all_expression_data
# Out:
#       cancer_type                       protein    change   P_val     adj_p  \
# 0           ccrcc       ('A1BG', 'NP_570602.2')  0.282928  0.0000  0.000000
# 1           ccrcc       ('A1CF', 'NP_620310.1') -0.551358  0.0000  0.000000
# 2           ccrcc        ('A2M', 'NP_000005.2')  0.595512  0.0000  0.000000
# 3           ccrcc  ('A4GALT', 'NP_001304967.1')  0.479410  0.1735  0.214310
# 4           ccrcc       ('AAAS', 'NP_056480.1')  0.173579  0.0000  0.000000
# 5           ccrcc       ('AACS', 'NP_076417.2') -0.215967  0.0000  0.000000
# 6           ccrcc      ('AADAC', 'NP_001077.2')  0.147423  0.7481  0.784497
# 7           ccrcc   ('AADAT', 'NP_001273612.1') -1.818291  0.0000  0.000000
# 8           ccrcc      ('AAED1', 'NP_714542.1')  0.426052  0.0000  0.000000
# 9           ccrcc      ('AAGAB', 'NP_078942.3') -0.070117  0.0009  0.001554
# 10          ccrcc       ('AAK1', 'NP_055726.3') -0.307917  0.0000  0.000000
# 11          ccrcc       ('AAMP', 'NP_001078.2')  0.328956  0.0000  0.000000
# 12          ccrcc    ('AAR2', 'NP_001258803.1')  0.260477  0.0000  0.000000
# 13          ccrcc       ('AARS', 'NP_001596.2')  0.171212  0.0000  0.000000
# 14          ccrcc      ('AARS2', 'NP_065796.1') -0.084635  0.0102  0.015459
# 15          ccrcc  ('AARSD1', 'NP_001248363.1')  0.217840  0.0000  0.000000
# 16          ccrcc   ('AASDH', 'NP_001273597.1') -0.035299  0.8544  0.877806
# 17          ccrcc   ('AASDHPPT', 'NP_056238.2')  0.025985  0.2636  0.313190
# 18          ccrcc       ('AASS', 'NP_005754.2') -1.614744  0.0000  0.000000
# 19          ccrcc       ('AATF', 'NP_036270.1')  0.388488  0.0000  0.000000
# 20          ccrcc       ('ABAT', 'NP_000654.2') -2.250937  0.0000  0.000000
# 21          ccrcc      ('ABCA1', 'NP_005493.2')  0.558242  0.0000  0.000000
# 22          ccrcc     ('ABCA12', 'NP_056472.2')  0.249142  0.0036  0.005803
# 23          ccrcc      ('ABCA2', 'NP_997698.1') -0.130617  0.0033  0.005344
# 24          ccrcc      ('ABCA3', 'NP_001080.2') -0.169564  0.4012  0.455638
# 25          ccrcc      ('ABCA5', 'NP_061142.2') -0.082137  0.4792  0.533063
# 26          ccrcc      ('ABCA6', 'NP_525023.2') -0.176452  0.3800  0.434335
# 27          ccrcc   ('ABCA8', 'NP_001275914.1') -0.828206  0.0000  0.000000
# 28          ccrcc   ('ABCB1', 'NP_001335874.1') -1.318350  0.0000  0.000000
# 29          ccrcc     ('ABCB10', 'NP_036221.2')  0.159938  0.0009  0.001554
# ...           ...                           ...       ...     ...       ...
# 86229     ovarian    ('ZNF865', 'NP_001182534') -0.400890  0.0064  0.009973
# 86230     ovarian        ('ZNF90', 'NP_009069')  0.360028  0.0000  0.000000
# 86231     ovarian        ('ZNF93', 'NP_112495')  0.352226  0.0000  0.000000
# 86232     ovarian     ('ZNF98', 'NP_001092096')  0.337325  0.0002  0.000368
# 86233     ovarian        ('ZNFX1', 'NP_066363') -0.118389  0.0696  0.092734
# 86234     ovarian       ('ZNHIT1', 'NP_006340')  0.616547  0.0895  0.116891
# 86235     ovarian       ('ZNHIT2', 'NP_055020')  0.160762  0.0619  0.083208
# 86236     ovarian       ('ZNHIT3', 'NP_004764') -0.382495  0.0183  0.026760
# 86237     ovarian       ('ZNHIT6', 'NP_060423')  0.345058  0.0008  0.001390
# 86238     ovarian        ('ZNRF1', 'NP_115644') -0.329103  0.0562  0.076055
# 86239     ovarian        ('ZNRF2', 'NP_667339')  0.240016  0.0311  0.043897
# 86240     ovarian         ('ZPR1', 'NP_003895')  0.229895  0.0048  0.007610
# 86241     ovarian       ('ZRANB2', 'NP_976225')  0.438710  0.0000  0.000000
# 86242     ovarian        ('ZRSR2', 'NP_005080')  0.133788  0.6057  0.654192
# 86243     ovarian   ('ZSCAN18', 'NP_001139014') -0.160106  0.3199  0.372488
# 86244     ovarian       ('ZSCAN2', 'NP_870992')  0.414704  0.0001  0.000188
# 86245     ovarian      ('ZSCAN25', 'NP_660090')  0.065645  0.6050  0.653567
# 86246     ovarian   ('ZSCAN26', 'NP_001018854') -0.427857  0.1220  0.155300
# 86247     ovarian      ('ZSCAN29', 'NP_689668')  0.201903  0.0338  0.047420
# 86248     ovarian   ('ZSCAN30', 'NP_001106205') -0.883458  0.0004  0.000717
# 86249     ovarian      ('ZSCAN31', 'NP_665916')  0.031276  0.8165  0.844845
# 86250     ovarian   ('ZSCAN32', 'NP_001271456') -0.554950  0.0041  0.006555
# 86251     ovarian    ('ZSWIM8', 'NP_001229416') -0.111356  0.1962  0.239748
# 86252     ovarian         ('ZW10', 'NP_004715')  0.272076  0.0000  0.000000
# 86253     ovarian       ('ZWILCH', 'NP_060445')  0.303400  0.0648  0.086793
# 86254     ovarian        ('ZWINT', 'NP_008988')  0.046030  0.8252  0.852436
# 86255     ovarian       ('ZYG11B', 'NP_078922') -0.087644  0.2133  0.258770
# 86256     ovarian       ('ZYX', 'NP_001010972') -0.551746  0.0000  0.000000
# 86257     ovarian        ('ZZEF1', 'NP_055928') -0.256154  0.0001  0.000188
# 86258     ovarian         ('ZZZ3', 'NP_056349') -0.026948  0.8168  0.845115
#
#        reject_null protein_str  simplified_change
# 0             True        A1BG                1.0
# 1             True        A1CF               -1.0
# 2             True         A2M                1.0
# 3            False      A4GALT                0.5
# 4             True        AAAS                1.0
# 5             True        AACS               -1.0
# 6            False       AADAC                0.5
# 7             True       AADAT               -1.0
# 8             True       AAED1                1.0
# 9             True       AAGAB               -1.0
# 10            True        AAK1               -1.0
# 11            True        AAMP                1.0
# 12            True        AAR2                1.0
# 13            True        AARS                1.0
# 14            True       AARS2               -1.0
# 15            True      AARSD1                1.0
# 16           False       AASDH               -0.5
# 17           False    AASDHPPT                0.5
# 18            True        AASS               -1.0
# 19            True        AATF                1.0
# 20            True        ABAT               -1.0
# 21            True       ABCA1                1.0
# 22            True      ABCA12                1.0
# 23            True       ABCA2               -1.0
# 24           False       ABCA3               -0.5
# 25           False       ABCA5               -0.5
# 26           False       ABCA6               -0.5
# 27            True       ABCA8               -1.0
# 28            True       ABCB1               -1.0
# 29            True      ABCB10                1.0
# ...            ...         ...                ...
# 86229         True      ZNF865               -1.0
# 86230         True       ZNF90                1.0
# 86231         True       ZNF93                1.0
# 86232         True       ZNF98                1.0
# 86233        False       ZNFX1               -0.5
# 86234        False      ZNHIT1                0.5
# 86235        False      ZNHIT2                0.5
# 86236         True      ZNHIT3               -1.0
# 86237         True      ZNHIT6                1.0
# 86238        False       ZNRF1               -0.5
# 86239         True       ZNRF2                1.0
# 86240         True        ZPR1                1.0
# 86241         True      ZRANB2                1.0
# 86242        False       ZRSR2                0.5
# 86243        False     ZSCAN18               -0.5
# 86244         True      ZSCAN2                1.0
# 86245        False     ZSCAN25                0.5
# 86246        False     ZSCAN26               -0.5
# 86247         True     ZSCAN29                1.0
# 86248         True     ZSCAN30               -1.0
# 86249        False     ZSCAN31                0.5
# 86250         True     ZSCAN32               -1.0
# 86251        False      ZSWIM8               -0.5
# 86252         True        ZW10                1.0
# 86253        False      ZWILCH                0.5
# 86254        False       ZWINT                0.5
# 86255        False      ZYG11B               -0.5
# 86256         True         ZYX               -1.0
# 86257         True       ZZEF1               -1.0
# 86258        False        ZZZ3               -0.5
#
# [86259 rows x 8 columns]

# %%
enrichment_data = pd.read_csv(STEP5_FILE_PATH, sep="\t")
enrichment_data.sort_values(by=["cancer_type", "fdr"])

# Assign pathway ranks within each cancer type based on FDR
enrichment_data = enrichment_data.\
    assign(cancer_rank_fdr=enrichment_data.groupby("cancer_type")["fdr"].rank()).\
    sort_values(by=["cancer_type", "cancer_rank_fdr"]).\
    reset_index(drop=True)

# Make a table with summary info for all pathways
enrichment_summary = enrichment_data[["Term"]].drop_duplicates(keep="first")

pathway_times_enriched = enrichment_summary["Term"].apply(
    lambda x: enrichment_data[enrichment_data["Term"] == x].shape[0])

avg_rank = enrichment_summary["Term"].apply(
    lambda x: enrichment_data.loc[enrichment_data["Term"] == x, "cancer_rank_fdr"].mean())

enrichment_summary = enrichment_summary.\
    assign(
        pathway_times_enriched=pathway_times_enriched,
        pathway_avg_rank=avg_rank).\
    sort_values(
        by=["pathway_times_enriched", "pathway_avg_rank"],
        ascending=[False, True]).\
    reset_index(drop=True)

# Merge in the original enrichment data
enrichment_data = enrichment_data.\
    merge(
        enrichment_summary,
        how="outer",
        left_on="Term",
        right_on="Term",
        validate="many_to_one"
    ).\
    sort_values(
        by=["pathway_times_enriched", "pathway_avg_rank", "cancer_type"],
        ascending=[False, True, True]
    )

enrichment_data
# Out:
#                                                     Term        es        nes  \
# 1332   Caspase-mediated cleavage of cytoskeletal prot...  0.659181   1.786914
# 1333   Caspase-mediated cleavage of cytoskeletal prot...  0.597757   1.551225
# 1334   Caspase-mediated cleavage of cytoskeletal prot...  0.727443   2.006110
# 1335   Caspase-mediated cleavage of cytoskeletal prot...  0.695016   1.828500
# 1336   Caspase-mediated cleavage of cytoskeletal prot...  0.694543   1.810303
# 1337   Caspase-mediated cleavage of cytoskeletal prot...  0.591907   1.563956
# 1338   Caspase-mediated cleavage of cytoskeletal prot...  0.616007   1.607255
# 1339   Caspase-mediated cleavage of cytoskeletal prot...  0.682615   1.761297
# 2457   Export of Viral Ribonucleoproteins from Nucleu...  0.473014   1.425732
# 2458   Export of Viral Ribonucleoproteins from Nucleu...  0.675153   2.020074
# 2459   Export of Viral Ribonucleoproteins from Nucleu... -0.181221 -61.180345
# 2460   Export of Viral Ribonucleoproteins from Nucleu...  0.546467   1.738775
# 2461   Export of Viral Ribonucleoproteins from Nucleu...  0.640341   1.890259
# 2462   Export of Viral Ribonucleoproteins from Nucleu...  0.630502   1.932164
# 2463   Export of Viral Ribonucleoproteins from Nucleu...  0.495550   1.366437
# 2464   Export of Viral Ribonucleoproteins from Nucleu...  0.601723   1.728516
# 3348   Transport of Ribonucleoproteins into the Host ...  0.464271   1.394918
# 3349   Transport of Ribonucleoproteins into the Host ...  0.663048   1.966647
# 3350   Transport of Ribonucleoproteins into the Host ... -0.209672 -46.039790
# 3351   Transport of Ribonucleoproteins into the Host ...  0.543488   1.729330
# 3352   Transport of Ribonucleoproteins into the Host ...  0.619205   1.817841
# 3353   Transport of Ribonucleoproteins into the Host ...  0.628353   1.938095
# 3354   Transport of Ribonucleoproteins into the Host ...  0.507881   1.399437
# 3355   Transport of Ribonucleoproteins into the Host ...  0.570849   1.626227
# 3828   Rev-mediated nuclear export of HIV RNA Homo sa...  0.490997   1.501488
# 3829   Rev-mediated nuclear export of HIV RNA Homo sa...  0.676975   2.029605
# 3830   Rev-mediated nuclear export of HIV RNA Homo sa... -0.209729 -80.917164
# 3831   Rev-mediated nuclear export of HIV RNA Homo sa...  0.530624   1.686538
# 3832   Rev-mediated nuclear export of HIV RNA Homo sa...  0.624554   1.837580
# 3833   Rev-mediated nuclear export of HIV RNA Homo sa...  0.624618   1.935814
# ...                                                  ...       ...        ...
# 10685  Regulation of gene expression in early pancrea... -0.662771  -2.935209
# 10686  Regulation of gene expression in early pancrea... -0.944581  -2.465158
# 10687  Regulation of gene expression in early pancrea... -0.879205  -2.244890
# 11422  Mineralocorticoid biosynthesis Homo sapiens R-... -0.740946  -2.061590
# 11423  Mineralocorticoid biosynthesis Homo sapiens R-... -0.913559  -2.311834
# 11424  Mineralocorticoid biosynthesis Homo sapiens R-... -0.668519  -1.852790
# 11433  Tandem pore domain potassium channels Homo sap... -0.790723  -2.004048
# 11434  Tandem pore domain potassium channels Homo sap... -0.821968  -7.105993
# 11435  Tandem pore domain potassium channels Homo sap... -0.721958  -1.807533
# 713    Sodium-coupled sulphate, di- and tri-carboxyla...  0.709761   1.984201
# 714    Sodium-coupled sulphate, di- and tri-carboxyla...  0.557393   1.508732
# 11941  Regulation of gene expression in endocrine-com... -0.659565  -3.114336
# 11942  Regulation of gene expression in endocrine-com... -0.527251  -1.400917
# 11903  Hormone ligand-binding receptors Homo sapiens ... -0.913588  -2.502572
# 11904  Hormone ligand-binding receptors Homo sapiens ... -0.940524  -2.602870
# 11929      Serotonin receptors Homo sapiens R-HSA-390666  0.827685   2.121601
# 779    Organic anion transport Homo sapiens R-HSA-561048  0.669826   1.972575
# 11889           Gene Expression Homo sapiens R-HSA-74160  0.496462   1.657967
# 11945  Acetylcholine Binding And Downstream Events Ho...  0.541251   1.493691
# 11946  Activation of Nicotinic Acetylcholine Receptor...  0.541251   1.493691
# 11947  Highly sodium permeable acetylcholine nicotini...  0.541251   1.493691
# 11948  Postsynaptic nicotinic acetylcholine receptors...  0.541251   1.493691
# 11949  Presynaptic nicotinic acetylcholine receptors ...  0.541251   1.493691
# 11930  Muscarinic acetylcholine receptors Homo sapien...  0.655219   1.560824
# 3331   Prostanoid ligand receptors Homo sapiens R-HSA...  0.597199   1.446731
# 11890      Signal Transduction Homo sapiens R-HSA-162582  0.355700   1.171228
# 11943  Tachykinin receptors bind tachykinins Homo sap... -0.511956  -2.201871
# 11446  Vasopressin-like receptors Homo sapiens R-HSA-... -0.735504  -1.947930
# 11902        Relaxin receptors Homo sapiens R-HSA-444821 -0.610836  -1.633440
# 11944  Free fatty acid receptors Homo sapiens R-HSA-4... -0.937212  -2.395241
#
#            pval       fdr  geneset_size  matched_size  \
# 1332   0.002899  0.293321            12            11
# 1333   0.037599  0.334073            12            11
# 1334   0.001480  0.475508            12            12
# 1335   0.003561  0.350661            12            12
# 1336   0.005727  0.203768            12            12
# 1337   0.043042  0.321700            12            12
# 1338   0.019663  0.352172            12            12
# 1339   0.004351  0.277624            12            11
# 2457   0.150104  0.423567            31            31
# 2458   0.004895  0.261147            31            30
# 2459   0.857143  0.422783            31            31
# 2460   0.093633  0.334359            31            31
# 2461   0.019943  0.218480            31            31
# 2462   0.036232  0.270095            31            28
# 2463   0.153097  0.418294            31            19
# 2464   0.028159  0.290971            31            31
# 3348   0.172342  0.430724            30            30
# 3349   0.004196  0.233433            30            29
# 3350   0.484848  0.358429            30            30
# 3351   0.107519  0.334902            30            30
# 3352   0.034875  0.207318            30            30
# 3353   0.044412  0.278157            30            26
# 3354   0.154443  0.395327            30            18
# 3355   0.043210  0.351935            30            30
# 3828   0.117974  0.434138            33            33
# 3829   0.002789  0.264624            33            32
# 3830   0.473684  0.358503            33            33
# 3831   0.102832  0.325096            33            33
# 3832   0.028031  0.205160            33            33
# 3833   0.031002  0.276905            33            30
# ...         ...       ...           ...           ...
# 10685  0.348375  0.880310             8             2
# 10686  0.111402  1.000000             8             1
# 10687  0.233207  0.980348             8             1
# 11422  0.504144  0.963882             6             1
# 11423  0.142313  1.000000             6             1
# 11424  0.605505  0.994968             6             1
# 11433  0.424904  0.965930            12             1
# 11434  0.011940  1.000000            12             3
# 11435  0.580402  0.970487            12             1
# 713    0.126935  0.215671             5             3
# 714    0.876165  0.394875             5             1
# 11941  0.307839  0.981785             5             2
# 11942  0.947791  0.992849             5             1
# 11903  0.180441  0.991788            11             1
# 11904  0.158621  1.000000            11             1
# 11929  0.266250  0.207011            12             1
# 779    0.111326  0.222442             5             5
# 11889  0.000000  0.292849          1631           986
# 11945  0.908587  0.356099            14             1
# 11946  0.908587  0.356099            14             1
# 11947  0.908587  0.356099             7             1
# 11948  0.908587  0.356099            14             1
# 11949  0.908587  0.356099            12             1
# 11930  0.253812  0.392809             5             3
# 3331   0.578947  0.430495             9             2
# 11890  0.004746  0.530811          2465           938
# 11943  0.732743  0.989836             5             2
# 11446  0.539386  0.967403             6             1
# 11902  0.782609  0.980750             8             1
# 11944  0.132468  1.000000             5             1
#
#                                                    genes  \
# 1332   VIM;ADD1;SPTAN1;PLEC;GAS2;CASP3;CASP7;DBNL;CAS...
# 1333   ADD1;MAPT;GSN;VIM;CASP7;SPTAN1;CASP8;PLEC;DBNL...
# 1334   MAPT;CASP8;CASP6;GSN;CASP3;VIM;CASP7;PLEC;ADD1...
# 1335   VIM;SPTAN1;MAPT;ADD1;CASP3;CASP6;CASP7;CASP8;D...
# 1336   SPTAN1;ADD1;VIM;GSN;CASP8;MAPT;CASP7;CASP6;CAS...
# 1337   SPTAN1;ADD1;VIM;CASP3;GSN;MAPT;PLEC;CASP8;CASP...
# 1338   SPTAN1;ADD1;VIM;CASP3;CASP6;PLEC;GSN;MAPT;CASP...
# 1339   ADD1;CASP3;SPTAN1;CASP8;VIM;GSN;MAPT;CASP6;CAS...
# 2457   RAN;NUP43;NUP62;NUP85;XPO1;NUP107;NUP155;NUP54...
# 2458   NUP93;RANBP2;TPR;RAE1;NUP205;NUP98;NUP54;NUP15...
# 2459   HSPA1A;NUP210;NDC1;NUPL2;RAN;NUP50;RAE1;NUP35;...
# 2460   NUP214;NUP93;NUP88;NUP37;NUP153;NUP160;NUP85;T...
# 2461   NUP62;RAN;HSPA1A;NUP88;NUP50;TPR;NUP214;NUP98;...
# 2462   NUP50;NUP93;RANBP2;NUP153;NUP205;NUP98;NUP214;...
# 2463   RANBP2;NUP93;NUP88;TPR;NUP153;NUP205;POM121C;N...
# 2464   XPO1;RAN;AAAS;NUP210;NUP205;RAE1;NUP153;TPR;NU...
# 3348   KPNB1;NUP43;NUP62;NUP85;NUP107;NUP155;NUP54;NU...
# 3349   NUP93;RANBP2;TPR;RAE1;NUP205;NUP98;NUP54;NUP15...
# 3350   NUP210;NDC1;KPNB1;NUPL2;NUP50;RAE1;NUP35;KPNA1...
# 3351   NUP214;NUP93;NUP88;NUP37;NUP153;NUP160;NUP85;T...
# 3352   NUP62;NUP88;NUP50;TPR;NUP214;NUP98;POM121;NUP1...
# 3353   NUP50;NUP93;RANBP2;NUP153;NUP205;NUP98;NUP214;...
# 3354   RANBP2;NUP93;NUP88;TPR;NUP153;NUP205;POM121C;N...
# 3355   AAAS;NUP210;NUP205;RAE1;NUP153;TPR;NUP98;NUP16...
# 3828   RAN;NUP43;RANBP1;NUP62;NUP85;XPO1;RCC1;NUP107;...
# 3829   NUP93;RANBP2;RANGAP1;TPR;RCC1;RAE1;NUP205;NUP9...
# 3830   NUP210;RCC1;NDC1;NUPL2;RAN;RANBP1;RANGAP1;NUP5...
# 3831   NUP214;NUP93;NUP88;NUP37;NUP153;NUP160;NUP85;T...
# 3832   NUP62;RAN;NUP88;NUP50;TPR;NUP214;NUP98;POM121;...
# 3833   RANGAP1;NUP50;NUP93;RANBP2;NUP153;NUP205;NUP98...
# ...                                                  ...
# 10685                                       HNF1B;NKX6-1
# 10686                                              HNF1B
# 10687                                              HNF1B
# 11422                                             HSD3B1
# 11423                                             HSD3B1
# 11424                                             HSD3B2
# 11433                                              KCNK1
# 11434                                  KCNK6;KCNK1;KCNK2
# 11435                                              KCNK1
# 713                              SLC13A3;SLC13A2;SLC13A1
# 714                                              SLC13A5
# 11941                                       NKX2-2;INSM1
# 11942                                             NKX2-2
# 11903                                              GNRH2
# 11904                                               FSHR
# 11929                                              HTR2A
# 779            SLC22A8;SLC22A6;SLC22A12;SLC22A11;SLC22A7
# 11889  DDX21;NUP93;NOP2;SF3B1;PDCD11;NAT10;SNRNP200;M...
# 11945                                              CHRNE
# 11946                                              CHRNE
# 11947                                              CHRNE
# 11948                                              CHRNE
# 11949                                              CHRNE
# 11930                                  CHRM3;CHRM1;CHRM4
# 3331                                        PTGER3;PTGDR
# 11890  NCAM1;LPAR1;PRKAR2B;RGS10;CAV1;GNA11;RANBP2;GN...
# 11943                                          TAC3;TAC1
# 11446                                             AVPR1B
# 11902                                              INSL5
# 11944                                              FFAR2
#
#                                              ledge_genes  cancer_type  \
# 1332                     VIM;ADD1;SPTAN1;PLEC;GAS2;CASP3        ccrcc
# 1333                                       ADD1;MAPT;GSN        colon
# 1334      MAPT;CASP8;CASP6;GSN;CASP3;VIM;CASP7;PLEC;ADD1  endometrial
# 1335                    VIM;SPTAN1;MAPT;ADD1;CASP3;CASP6          gbm
# 1336          SPTAN1;ADD1;VIM;GSN;CASP8;MAPT;CASP7;CASP6        hnscc
# 1337                           SPTAN1;ADD1;VIM;CASP3;GSN         lscc
# 1338                         SPTAN1;ADD1;VIM;CASP3;CASP6         luad
# 1339                ADD1;CASP3;SPTAN1;CASP8;VIM;GSN;MAPT      ovarian
# 2457   RAN;NUP43;NUP62;NUP85;XPO1;NUP107;NUP155;NUP54...        ccrcc
# 2458   NUP93;RANBP2;TPR;RAE1;NUP205;NUP98;NUP54;NUP15...        colon
# 2459   HSPA1A;NUP210;NDC1;NUPL2;RAN;NUP50;RAE1;NUP35;...  endometrial
# 2460   NUP214;NUP93;NUP88;NUP37;NUP153;NUP160;NUP85;T...          gbm
# 2461   NUP62;RAN;HSPA1A;NUP88;NUP50;TPR;NUP214;NUP98;...        hnscc
# 2462   NUP50;NUP93;RANBP2;NUP153;NUP205;NUP98;NUP214;...         lscc
# 2463   RANBP2;NUP93;NUP88;TPR;NUP153;NUP205;POM121C;N...         luad
# 2464   XPO1;RAN;AAAS;NUP210;NUP205;RAE1;NUP153;TPR;NU...      ovarian
# 3348   KPNB1;NUP43;NUP62;NUP85;NUP107;NUP155;NUP54;NU...        ccrcc
# 3349   NUP93;RANBP2;TPR;RAE1;NUP205;NUP98;NUP54;NUP15...        colon
# 3350   NUP210;NDC1;KPNB1;NUPL2;NUP50;RAE1;NUP35;KPNA1...  endometrial
# 3351   NUP214;NUP93;NUP88;NUP37;NUP153;NUP160;NUP85;T...          gbm
# 3352   NUP62;NUP88;NUP50;TPR;NUP214;NUP98;POM121;NUP1...        hnscc
# 3353   NUP50;NUP93;RANBP2;NUP153;NUP205;NUP98;NUP214;...         lscc
# 3354   RANBP2;NUP93;NUP88;TPR;NUP153;NUP205;POM121C;N...         luad
# 3355   AAAS;NUP210;NUP205;RAE1;NUP153;TPR;NUP98;NUP16...      ovarian
# 3828   RAN;NUP43;RANBP1;NUP62;NUP85;XPO1;RCC1;NUP107;...        ccrcc
# 3829   NUP93;RANBP2;RANGAP1;TPR;RCC1;RAE1;NUP205;NUP9...        colon
# 3830   NUP210;RCC1;NDC1;NUPL2;RAN;RANBP1;RANGAP1;NUP5...  endometrial
# 3831   NUP214;NUP93;NUP88;NUP37;NUP153;NUP160;NUP85;T...          gbm
# 3832   NUP62;RAN;NUP88;NUP50;TPR;NUP214;NUP98;POM121;...        hnscc
# 3833   RANGAP1;NUP50;NUP93;RANBP2;NUP153;NUP205;NUP98...         lscc
# ...                                                  ...          ...
# 10685                                       HNF1B;NKX6-1        ccrcc
# 10686                                              HNF1B  endometrial
# 10687                                              HNF1B         luad
# 11422                                             HSD3B1        ccrcc
# 11423                                             HSD3B1        hnscc
# 11424                                             HSD3B2      ovarian
# 11433                                              KCNK1        ccrcc
# 11434                                  KCNK6;KCNK1;KCNK2        hnscc
# 11435                                              KCNK1         luad
# 713                              SLC13A3;SLC13A2;SLC13A1        ccrcc
# 714                                              SLC13A5          gbm
# 11941                                       NKX2-2;INSM1          gbm
# 11942                                             NKX2-2         lscc
# 11903                                              GNRH2        colon
# 11904                                               FSHR        hnscc
# 11929                                              HTR2A          gbm
# 779                    SLC22A8;SLC22A6;SLC22A12;SLC22A11        ccrcc
# 11889  DDX21;NUP93;NOP2;SF3B1;PDCD11;NAT10;SNRNP200;M...        colon
# 11945                                              CHRNE         luad
# 11946                                              CHRNE         luad
# 11947                                              CHRNE         luad
# 11948                                              CHRNE         luad
# 11949                                              CHRNE         luad
# 11930                                  CHRM3;CHRM1;CHRM4          gbm
# 3331                                        PTGER3;PTGDR        ccrcc
# 11890  NCAM1;LPAR1;PRKAR2B;RGS10;CAV1;GNA11;RANBP2;GN...        colon
# 11943                                          TAC3;TAC1          gbm
# 11446                                             AVPR1B        ccrcc
# 11902                                              INSL5        colon
# 11944                                              FFAR2         lscc
#
#        cancer_rank_fdr  pathway_times_enriched  pathway_avg_rank
# 1332             171.0                       8        162.375000
# 1333             304.0                       8        162.375000
# 1334              65.0                       8        162.375000
# 1335             219.0                       8        162.375000
# 1336              31.0                       8        162.375000
# 1337             164.0                       8        162.375000
# 1338             227.0                       8        162.375000
# 1339             118.0                       8        162.375000
# 2457             312.0                       8        181.125000
# 2458              75.0                       8        181.125000
# 2459              14.0                       8        181.125000
# 2460             151.0                       8        181.125000
# 2461             197.0                       8        181.125000
# 2462              76.0                       8        181.125000
# 2463             476.0                       8        181.125000
# 2464             148.0                       8        181.125000
# 3348             425.0                       8        181.625000
# 3349              10.0                       8        181.625000
# 3350               6.0                       8        181.625000
# 3351             153.0                       8        181.625000
# 3352             112.0                       8        181.625000
# 3353             101.0                       8        181.625000
# 3354             436.0                       8        181.625000
# 3355             210.0                       8        181.625000
# 3828             485.0                       8        183.625000
# 3829              76.0                       8        183.625000
# 3830               7.0                       8        183.625000
# 3831             115.0                       8        183.625000
# 3832              73.0                       8        183.625000
# 3833              99.0                       8        183.625000
# ...                ...                     ...               ...
# 10685           1343.0                       3       1409.833333
# 10686           1476.5                       3       1409.833333
# 10687           1410.0                       3       1409.833333
# 11422           1439.0                       3       1424.666667
# 11423           1471.0                       3       1424.666667
# 11424           1364.0                       3       1424.666667
# 11433           1441.0                       3       1430.833333
# 11434           1471.0                       3       1430.833333
# 11435           1380.5                       3       1430.833333
# 713               92.0                       2        242.000000
# 714              392.0                       2        242.000000
# 11941           1347.0                       2       1375.000000
# 11942           1403.0                       2       1375.000000
# 11903           1461.0                       2       1466.000000
# 11904           1471.0                       2       1466.000000
# 11929             57.0                       1         57.000000
# 779              101.0                       1        101.000000
# 11889            179.0                       1        179.000000
# 11945            282.0                       1        282.000000
# 11946            282.0                       1        282.000000
# 11947            282.0                       1        282.000000
# 11948            282.0                       1        282.000000
# 11949            282.0                       1        282.000000
# 11930            374.0                       1        374.000000
# 3331             421.5                       1        421.500000
# 11890            857.0                       1        857.000000
# 11943           1417.0                       1       1417.000000
# 11446           1444.0                       1       1444.000000
# 11902           1445.0                       1       1445.000000
# 11944           1461.0                       1       1461.000000
#
# [11950 rows x 13 columns]

# %% [markdown]
# ## Figure 1: Bubble plot

# %%
# Select top 10 for our plot
top_ten = enrichment_data["Term"].unique()[:10]
sel_enrich = enrichment_data[enrichment_data["Term"].isin(top_ten)]

# %%
# Calculate the mean expression for each pathway in each cancer type
mean_exprs = []

for idx in sel_enrich.index:
    genes = sel_enrich.loc[idx, "genes"].split(";")
    cancer_type = sel_enrich.loc[idx, "cancer_type"]
    
    genes_expr = expression_data.loc[
        expression_data["protein_str"].isin(genes),
        "simplified_change"
    ].mean()
    
    mean_exprs.append(genes_expr)
    
sel_enrich = sel_enrich.assign(mean_expr=mean_exprs)

# %%
sel_enrich = sel_enrich.assign(
    rank_size=1 / sel_enrich["cancer_rank_fdr"],
    avg_rank_size=1 / sel_enrich["pathway_avg_rank"])

individual = alt.Chart(sel_enrich).mark_circle().encode(
    x=alt.X(
        "Term:N",
        sort=sel_enrich["Term"].values,
        axis=alt.Axis(
            labelAngle=-30,
            labelFontSize=12,
            labelLimit=500,
            title="",
            titleFontSize=12
        )
    ),
    y=alt.Y(
        "cancer_type:N",
        axis=alt.Axis(
            title="Cancer type",
            titleFontSize=12
        ),
    ),
    size=alt.Size(
        "rank_size:Q",
        legend=None
    ),
    color=alt.Color(
        "mean_expr:Q",
        scale=alt.Scale(
            scheme="blueorange",
            domain=[-1, 1]
        ),
        legend=alt.Legend(
            title="Pathway tumor expression"
        )
    )
).properties(
    width=400,
    height=300
)

aggregate = alt.Chart(sel_enrich).mark_circle().encode(
    x=alt.X(
        "pathway_avg_rank:N",
        sort=sel_enrich["pathway_avg_rank"].values,
        axis=alt.Axis(
            labelAngle=-30,
            labelFontSize=12,
            labelLimit=500,
            title="Overall rank of pathway",
            titleFontSize=12
        )
    ),
    size=alt.Size(
        "avg_rank_size:Q",
        legend=None
    ),
).properties(
    width=400
)

alt.vconcat(aggregate, individual).configure_axis(
    grid=True
)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Figure 2: Expression of proteins in the neutrophil degranulation pathway

# %%
# Get the ID the top expessed pathway
neutro_pathway_ids = enrichment_data.\
    loc[enrichment_data["name"] == "Neutrophil degranulation", "pathway_id"].\
    unique()

if len(neutro_pathway_ids) != 1:
    raise ValueError("Multiple pathways found.")
    
neutro_pathway_id = neutro_pathway_ids[0]

# %% [markdown]
# ### A: With proteins in different orders for the up and down categories

# %%
def expr_heatmap(expr_data, enrich_data, pathway_id, up_or_down, max_p, x_title=True):
    """Make a heatmap with proteins on the X axis, cancer types on the Y 
    axis, and the color reflecting the expression of that protein in that
    cancer type.
    
    Parameters:
    expr_data (pandas.DataFrame): A dataframe with columns "cancer_type", "protein_str", "adj_p", and "simplified_change".
    enrich_data (pandas.DataFrame): A dataframe with columns "cancer_type" and "mean_expr" (i.e. mean expression for the pathway of interest).
    pathway_id (str): The Reactome pathway id for the pathway you want the heatmap for.
    up_or_down (str): Either "up" or "down"; whether to plot cancers where the pathway is up, or where it's down.
    max_p (float): The minimum p value for a protein to be included on the plot. If max_p > 0.05, then proteins with 0.05 <= p < max_p will be marked as marginally significant.
    x_title (bool): Whether to include an x axis title.
    
    Returns:
    altair.Chart: The heatmap.
    """
    # Filter expression data by p value
    expr_data = expr_data[expr_data["adj_p"] < max_p]
    
    # Get expression data for proteins in the pathway
    pathway_proteins = ut.search_reactome_proteins_in_pathways(pathway_id)
    pathway_expr = expr_data[expr_data["protein_str"].isin(pathway_proteins["member"])]
    
    # Categorize the cancer types as the neutrophil degranulation pathway's mean expression being up or down
    if up_or_down == "up":
        comparison = operator.gt
    elif up_or_down == "down":
        comparison = operator.lt
    else:
        raise ValueError(f"Invalid value for up_or_down parameter: '{up_or_down}'")
    
    sel_cancers = enrich_data.\
        loc[(enrich_data["pathway_id"] == neutro_pathway_id) & (comparison(enrich_data["mean_expr"], 0)),
           ["cancer_type", "mean_expr"]]

    # Select data for the specified cancer types
    selected_expr_data = pathway_expr[pathway_expr["cancer_type"].isin(sel_cancers["cancer_type"])]

    # Sort proteins by mean expression across selected cancer types
    prot_order = selected_expr_data.groupby("protein_str")[["simplified_change", "cancer_type"]].\
        agg({
            "simplified_change": np.mean,
            "cancer_type": "count"
        })

    prot_order = prot_order.assign(
            cancer_type=np.copysign(prot_order["cancer_type"], prot_order["simplified_change"])
        ).\
        sort_values(by=["simplified_change", "cancer_type"])

    # Sort cancer types by mean pathway expression
    cancer_order = sel_cancers.\
        sort_values(by="mean_expr", ascending=False).\
        loc[:, "cancer_type"]
    
    # Map simplified_change to legend values
    selected_expr_data = selected_expr_data.assign(
        tumor_up_down=selected_expr_data["simplified_change"].replace({
            1: "Up (adj p < 0.05)",
            MSV: f"Up (0.05 <= adj p < {max_p})",
            0: "No change",
            -MSV: f"Down (0.05 <= adj p < {max_p})",
            -1: "Down (adj p < 0.05)"
        })
    )
    
    # Plot
    plot = alt.Chart(selected_expr_data).mark_rect().encode(
        x=alt.X(
            "protein_str:N",
            sort=prot_order.index.values,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=f"Proteins for {pathway_id} (different order in each facet)" if x_title else ""
            )
        ),
        y=alt.Y(
            "cancer_type:N",
            sort=cancer_order.values,
            axis=alt.Axis(
                title=f"Pathway {up_or_down} in tumor"
            )
        ),
        color=alt.Color(
            "tumor_up_down:N",
            scale=alt.Scale(
                domain=[
                    "Up (adj p < 0.05)",
                    f"Up (0.05 <= adj p < {max_p})",
                    "No change",
                    f"Down (0.05 <= adj p < {max_p})",
                    "Down (adj p < 0.05)"
                ],
                range=["#bf363a",
                       "#f6bda4",
                       "#f2efee",
                       "#afd3e6",
                       "#1e588a"
                ]
            ),
            legend=alt.Legend(
                title="Expression in tumor"
            )
        ),
    ).properties(
        width=700,
        height=175
    )
    
    return plot

# %%
# Plot
alt.vconcat(
    expr_heatmap(all_expression_data, enrichment_data, neutro_pathway_id, "up", max_p=0.2, x_title=False),
    expr_heatmap(all_expression_data, enrichment_data, neutro_pathway_id, "down", max_p=0.2)
)

# %% [markdown]
# ### B: With same sorting for both

# %%
def expr_heatmap_alt_sort(expr_data, enrich_data, pathway_id, max_p):
    """Make a heatmap with proteins on the X axis, cancer types on the Y 
    axis, and the color reflecting the expression of that protein in that
    cancer type.
    
    Parameters:
    expr_data (pandas.DataFrame): A dataframe with columns "cancer_type", "protein_str", "adj_p", and "simplified_change".
    enrich_data (pandas.DataFrame): A dataframe with columns "cancer_type" and "mean_expr" (i.e. mean expression for the pathway of interest).
    pathway_id (str): The Reactome pathway id for the pathway you want the heatmap for.
    up_or_down (str): Either "up" or "down"; whether to plot cancers where the pathway is up, or where it's down.
    max_p (float): The minimum p value for a protein to be included on the plot. If max_p > 0.05, then proteins with 0.05 <= p < max_p will be marked as marginally significant.
    
    Returns:
    altair.Chart: The heatmap.
    """
    # Filter expression data by p value
    expr_data = expr_data[expr_data["adj_p"] < max_p]
    
    # Get expression data for proteins in the pathway
    pathway_proteins = ut.search_reactome_proteins_in_pathways(pathway_id)
    pathway_expr = expr_data[expr_data["protein_str"].isin(pathway_proteins["member"])]
    
    # Sort proteins by mean expression across all cancer types
    prot_order = pathway_expr.groupby("protein_str")[["simplified_change", "cancer_type"]].\
        agg({
            "simplified_change": np.mean,
            "cancer_type": "count"
        })

    prot_order = prot_order.assign(
            cancer_type=np.copysign(prot_order["cancer_type"], prot_order["simplified_change"])
        ).\
        sort_values(by=["simplified_change", "cancer_type"])

    # Sort cancer types by mean pathway expression
    sel_cancers = enrich_data.\
        loc[enrich_data["pathway_id"] == neutro_pathway_id, ["cancer_type", "mean_expr"]]
        
    sel_cancers = sel_cancers.\
        assign(up_or_down=np.where(sel_cancers["mean_expr"] > 0, "Pathway up in tumor", "Pathway down in tumor")).\
        sort_values(by="mean_expr", ascending=False).\
        loc[:, ["cancer_type", "up_or_down"]]
    
    cancer_order = sel_cancers["cancer_type"].values
    
    pathway_expr = pathway_expr.merge(
        right=sel_cancers,
        how="inner",
        left_on="cancer_type",
        right_on="cancer_type",
        validate="many_to_one"
    )
    
    # Map simplified_change to legend values
    pathway_expr = pathway_expr.assign(
        tumor_up_down=pathway_expr["simplified_change"].replace({
            1: "Up (adj p < 0.05)",
            MSV: f"Up (0.05 <= adj p < {max_p})",
            0: "No change",
            -MSV: f"Down (0.05 <= adj p < {max_p})",
            -1: "Down (adj p < 0.05)"
        })
    )
    
    # Plot
    plot = alt.Chart(pathway_expr).mark_rect().encode(
        x=alt.X(
            "protein_str:N",
            sort=prot_order.index.values,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=f"Proteins for {pathway_id} (same order in both facets)"
            )
        ),
        y=alt.Y(
            "cancer_type:N",
            sort=cancer_order,
            axis=alt.Axis(
                title=""
            )
        ),
        color=alt.Color(
            "tumor_up_down:N",
            scale=alt.Scale(
                domain=[
                    "Up (adj p < 0.05)",
                    f"Up (0.05 <= adj p < {max_p})",
                    "No change",
                    f"Down (0.05 <= adj p < {max_p})",
                    "Down (adj p < 0.05)"
                ],
                range=["#bf363a",
                       "#f6bda4",
                       "#f2efee",
                       "#afd3e6",
                       "#1e588a"
                ]
            ),
            legend=alt.Legend(
                title="Expression in tumor"
            )
        ),
        row=alt.Row(
            "up_or_down:N",
            sort="descending",
            title="",
            header=alt.Header(
                labelFontStyle="bold"
            )
        )
    ).properties(
        width=600,
        height=150
    ).resolve_scale(
        y="independent" # This makes it so each facet (up or down) only has the cancers that are in that category
    )
    
    return plot

# %%
# Plot
expr_heatmap_alt_sort(all_expression_data, enrichment_data, neutro_pathway_id, max_p=0.2)

# %% [markdown]
# ## Figure 3: Pathway overlay for neutrophil degranulation

# %%
def pathway_overlay_wrapper(pathway_id, exp_data, enrich_data, up_or_down):
    
    prots = ut.search_reactome_proteins_in_pathways(pathway_id)
    
    # Categorize the cancer types as the neutrophil degranulation pathway's mean expression being up or down
    if up_or_down == "up":
        comparison = operator.gt
    elif up_or_down == "down":
        comparison = operator.lt
    else:
        raise ValueError(f"Invalid value for up_or_down parameter: '{up_or_down}'")
    
    sel_cancers = enrich_data.\
        loc[(enrich_data["pathway_id"] == neutro_pathway_id) & (comparison(enrich_data["mean_expr"], 0)),
            "cancer_type"]
    
    # Select the desired expression data and average the simplified change across cancer types
    sel_exp = exp_data.\
        loc[
            exp_data["protein_str"].isin(prots["member"]) & 
            exp_data["cancer_type"].isin(sel_cancers),
            ["protein_str", "simplified_change"]
        ].\
        groupby("protein_str").\
        agg(np.mean).\
        rename(columns={"simplified_change": f"{up_or_down}_simp_change"})
    
    img_name = f"{TIME_START}_{pathway_id}_{up_or_down}.png"
    img_path = os.path.join(STEP7_DIR, img_name)
    
    token, _ = ut.reactome_enrichment_analysis(
        analysis_type="ranked", 
        data=sel_exp, 
        sort_by="ENTITIES_FDR", 
        ascending=True,
        include_high_level_diagrams=True, 
        include_interactors=False)
    
    _, img_path = ut.reactome_pathway_overlay(
        analysis_token=token,
        pathway=pathway_id,
        open_browser=False,
        export_path=img_path,
        image_format="png",
        display_col_idx=None,
        diagram_colors="Modern",
        overlay_colors="Standard",
        quality=10
    )

    _, url = ut.reactome_pathway_overlay(
        analysis_token=token,
        pathway=pathway_id,
        open_browser=False,
    )

    return img_path, url

# %%
# Note that we're using expression_data, not all_expression_data; the former has
# only proteins where reject_null

up_image_path, up_url = pathway_overlay_wrapper(neutro_pathway_id, expression_data, enrichment_data, "up")

# %%
IPython.display.HTML(f'<a href={up_url}>{up_url}</a>')

# %%
IPython.display.Image(up_image_path)

# %%
# Note that we're using expression_data, not all_expression_data; the former has
# only proteins where reject_null

down_image_path, down_url = pathway_overlay_wrapper(neutro_pathway_id, expression_data, enrichment_data, "down")

# %%
IPython.display.HTML(f'<a href={down_url}>{down_url}</a>')

# %%
IPython.display.Image(down_image_path)

# %% [markdown]
# ## Figure 4: Distribution of tumor stage in each cancer
# Since neutrophil degranulation is associated with tumor progression, we want to check that it's not just up in cohorts with more high stage tumors, and down in cohorts with more low stage tumors.

# %%
cc = cptac.Ccrcc(no_internet=True)
co = cptac.Colon(no_internet=True)
en = cptac.Endometrial(no_internet=True)
gb = cptac.Gbm(no_internet=True)
hn = cptac.Hnscc(no_internet=True)
ls = cptac.Lscc(no_internet=True)
lu = cptac.Luad(no_internet=True)
ov = cptac.Ovarian(no_internet=True)

# %%
stage_df = pd.DataFrame()

# %%
cc_stage = cc.get_clinical()["tumor_stage_pathological"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="ccrcc")

stage_df = stage_df.append(cc_stage)

# %%
co_stage = co.get_clinical()["Stage"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="colon")

stage_df = stage_df.append(co_stage)

# %%
en_stage = en.get_clinical()["tumor_Stage-Pathological"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="endometrial")

stage_df = stage_df.append(en_stage)

# %%
# GBM: All tumors are stage IV
gb_stage = pd.Series("IV", gb.get_clinical().index).\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="gbm")

gb_stage
stage_df = stage_df.append(gb_stage)

# %%
hn_stage = hn.get_clinical()["patho_staging_curated"].\
    dropna().\
    str.rsplit(" ", n=1, expand=True)[1].\
    rename("tumor_stage").\
    reset_index(drop=False).\
    assign(cancer_type="hnscc")

stage_df = stage_df.append(hn_stage)

# %%
ls_stage = ls.get_clinical()["Stage"]
ls_stage = ls_stage.\
    rename("tumor_stage").\
    where(
        cond=~(ls_stage.dropna().str.endswith("A") | ls_stage.dropna().str.endswith("B")),
        other=ls_stage.str[:-1]).\
    where(
        cond=~(ls_stage.dropna().str.endswith("A 3")),
        other=ls_stage.dropna().str[:-3]
    ).\
    reset_index(drop=False).\
    assign(cancer_type="lscc")

stage_df = stage_df.append(ls_stage)

# %%
lu_stage = lu.get_clinical()["Stage"]
lu_stage = lu_stage.\
    rename("tumor_stage").\
    where(
        cond=~(lu_stage.dropna().str.endswith("A") | lu_stage.dropna().str.endswith("B")),
        other=lu_stage.str[:-1]).\
    replace({
        "1": "I",
        "2": "II",
        "3": "III"}).\
    reset_index(drop=False).\
    assign(cancer_type="luad")

stage_df = stage_df.append(lu_stage)

# %%
ov_stage = ov.get_clinical()["Tumor_Stage_Ovary_FIGO"]
ov_stage = ov_stage.\
    rename("tumor_stage").\
    where(
        cond=~(ov_stage.dropna().str.endswith("A") | 
               ov_stage.dropna().str.endswith("B") | 
               ov_stage.dropna().str.endswith("C")),
        other=ov_stage.str[:-1]).\
    drop(ov_stage[ov_stage == "Not Reported/ Unknown"].index).\
    reset_index(drop=False).\
    assign(cancer_type="ovarian")

stage_df = stage_df.append(ov_stage)

# %%
# Drop NaN samples
stage_df = stage_df.dropna()

# Drop normal samples (to avoid duplicate counts)
stage_df = stage_df[~stage_df["Patient_ID"].str.endswith(".N")]

# %%
# Join in whether neutrophil expression is up or down in tumor
neutro_expr = enrichment_data.loc[
    enrichment_data["pathway_id"] == neutro_pathway_id, 
    ["cancer_type", "name", "pathway_id", "mean_expr"]]

neutro_expr

# %%
stage_df = stage_df.merge(
    right=neutro_expr,
    how="left",
    left_on="cancer_type",
    right_on="cancer_type",
    validate="many_to_one")

# %%
# Make plots
alt.Chart(stage_df).mark_bar().encode(
    x=alt.X(
        "tumor_stage:N",
        axis=alt.Axis(
            labelAngle=0,
            labelFontSize=14,
            title=""
        )
    ),
    y=alt.Y(
        "count():Q",
        axis=alt.Axis(
            title="Count",
            titleFontSize=12
        )
    ),
    color=alt.Color(
        "mean_expr:Q",
        scale=alt.Scale(
            scheme="blueorange",
            domain=[-1, 1]
        ),
        legend=alt.Legend(
            title=["Neutrophil degranulation:", "Mean pathway expression", "in tumor"]
        )
    ),
    column=alt.Column(
        "cancer_type:N",
        title="Tumor stage distributions",
    )
).properties(
    width=65
).configure_header(
    titleFontSize=12
)

# %%
# Ask Sam: Is this idea of "mean pathway expression" 
# really valid? What if in reality, though we can't
# measure it, some proteins' magnitude of expression 
# change is a lot greater, so they should actually
# have greater weight in the mean calculation, and
# thus might alter the overall statistic for the
# pathway?
