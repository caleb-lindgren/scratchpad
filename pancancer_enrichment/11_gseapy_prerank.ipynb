# %% [markdown]
# # Pancancer enrichment analysis step 11: Try GSEApy PreRank, make the job preemptable

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
import datetime
import gseapy as gp
import statsmodels.stats.multitest as sm

# %%
TIME_START = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
NUM_PERMUTATIONS = 10000

STEP1_DIR = "step1_outputs"
STEP1_FILE = "tumor_change_20200529_195104_10000_perm.tsv"
STEP1_FILE_PATH = os.path.join(STEP1_DIR, STEP1_FILE)

STEP11_DIR = "step11_outputs"

# Create log dir and file
LOG_DIR = "step11_checkpoints"
LOG_FILE = f"{TIME_START}_prerank.log"
LOG_FILE_PATH = os.path.join(LOG_DIR, LOG_FILE)

if not os.path.isdir(LOG_DIR):
    os.mkdir(LOG_DIR)
    
with open(LOG_FILE_PATH, 'w') as fp: 
    fp.write(f"{TIME_START}\n")
    fp.write(f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Started step 9 with {NUM_PERMUTATIONS} permutations.\n")

GSEAPY_DIR_PATH = os.path.join(STEP11_DIR, "gseapy")

if not os.path.isdir(STEP11_DIR):
    os.mkdir(STEP11_DIR)

# %% [markdown]
# ## Prepare data

# %%
# Read in the file from step 1
data = pd.read_csv(STEP1_FILE_PATH, sep='\t', index_col=0)
data = data[["cancer_type", "protein_str", "P_val"]]

# %%
# Replace zeros with 0.00001, then adjust the p values
data["P_val"] = data["P_val"].replace(to_replace=0, value=0.00001)

reject_null, adj_p, alpha_sidak, alpha_bonf = sm.multipletests(
    pvals=data["P_val"],
    alpha=0.05,
    method="fdr_bh")

data = data.\
    assign(adj_p=adj_p).\
    drop(columns="P_val")

data = data.\
    groupby(["cancer_type", "protein_str"]).\
    mean().\
    reset_index()

# %%
data
# Out:
#       cancer_type protein_str     adj_p
# 0           ccrcc        A1BG  0.000020
# 1           ccrcc        A1CF  0.000020
# 2           ccrcc         A2M  0.000020
# 3           ccrcc      A4GALT  0.214310
# 4           ccrcc        AAAS  0.000020
# 5           ccrcc        AACS  0.000020
# 6           ccrcc       AADAC  0.784497
# 7           ccrcc       AADAT  0.000020
# 8           ccrcc       AAED1  0.000020
# 9           ccrcc       AAGAB  0.001554
# 10          ccrcc        AAK1  0.000020
# 11          ccrcc        AAMP  0.000020
# 12          ccrcc        AAR2  0.000020
# 13          ccrcc        AARS  0.000020
# 14          ccrcc       AARS2  0.015459
# 15          ccrcc      AARSD1  0.000020
# 16          ccrcc       AASDH  0.877806
# 17          ccrcc    AASDHPPT  0.313190
# 18          ccrcc        AASS  0.000020
# 19          ccrcc        AATF  0.000020
# 20          ccrcc        ABAT  0.000020
# 21          ccrcc       ABCA1  0.000020
# 22          ccrcc      ABCA12  0.005803
# 23          ccrcc       ABCA2  0.005344
# 24          ccrcc       ABCA3  0.455638
# 25          ccrcc       ABCA5  0.533063
# 26          ccrcc       ABCA6  0.434335
# 27          ccrcc       ABCA8  0.000020
# 28          ccrcc       ABCB1  0.000020
# 29          ccrcc      ABCB10  0.001554
# ...           ...         ...       ...
# 84340     ovarian      ZNF865  0.009973
# 84341     ovarian       ZNF90  0.000020
# 84342     ovarian       ZNF93  0.000020
# 84343     ovarian       ZNF98  0.000368
# 84344     ovarian       ZNFX1  0.092734
# 84345     ovarian      ZNHIT1  0.116891
# 84346     ovarian      ZNHIT2  0.083208
# 84347     ovarian      ZNHIT3  0.026760
# 84348     ovarian      ZNHIT6  0.001390
# 84349     ovarian       ZNRF1  0.076055
# 84350     ovarian       ZNRF2  0.043897
# 84351     ovarian        ZPR1  0.007610
# 84352     ovarian      ZRANB2  0.000020
# 84353     ovarian       ZRSR2  0.654192
# 84354     ovarian     ZSCAN18  0.372488
# 84355     ovarian      ZSCAN2  0.000188
# 84356     ovarian     ZSCAN25  0.653567
# 84357     ovarian     ZSCAN26  0.155300
# 84358     ovarian     ZSCAN29  0.047420
# 84359     ovarian     ZSCAN30  0.000717
# 84360     ovarian     ZSCAN31  0.844845
# 84361     ovarian     ZSCAN32  0.006555
# 84362     ovarian      ZSWIM8  0.239748
# 84363     ovarian        ZW10  0.000020
# 84364     ovarian      ZWILCH  0.086793
# 84365     ovarian       ZWINT  0.852436
# 84366     ovarian      ZYG11B  0.258770
# 84367     ovarian         ZYX  0.000020
# 84368     ovarian       ZZEF1  0.000188
# 84369     ovarian        ZZZ3  0.845115
#
# [84370 rows x 3 columns]

# %% [markdown]
# ## Run GSEApy PreRank analysis

# %%
def gseapy_prerank_reactome(ranks, asc, wst):
    
    with open(LOG_FILE_PATH, 'a') as fp: 
        fp.write(f"\n{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Started asc={asc} wst={wst}.\n")
    
    output_file = f"enrichment_gseapy_prerank_{TIME_START}_{NUM_PERMUTATIONS}_perms_asc_{asc}_wst_{wst}.tsv"
    output_path = os.path.join(STEP11_DIR, output_file)
    
    # For each cancer, find enriched pathways.
    all_enrichments = pd.DataFrame()

    for cancer_type in ranks["cancer_type"].unique():

        prot = ranks.loc[
            ranks["cancer_type"] == cancer_type,
            ["protein_str", "adj_p"]
        ]
        
        pre_res = gp.prerank(
            rnk=prot,
            gene_sets="gene_set_libraries/Reactome_2020.gmt",
            outdir=GSEAPY_DIR_PATH,
            permutation_num=NUM_PERMUTATIONS,
            min_size=1,
            max_size=500, 
            weighted_score_type=wst,
            ascending=asc,
            no_plot=True,
            processes=1,
            seed=0)

        cancer_enriched = pre_res.res2d.assign(cancer_type=cancer_type)
        all_enrichments = all_enrichments.append(cancer_enriched)

        # Log that we finished this cancer type
        with open(LOG_FILE_PATH, 'a') as fp: 
            fp.write(f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Finished {cancer_type} data.\n")
            
    # Record the results
    all_enrichments.to_csv(output_path, sep="\t")
            
    with open(LOG_FILE_PATH, 'a') as fp: 
        fp.write(f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Finished asc={asc} wst={wst}.\n")

# %%
gseapy_prerank_reactome(data, asc=True, wst=1)
