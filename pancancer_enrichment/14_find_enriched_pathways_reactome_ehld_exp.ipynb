# %% [markdown]
# # Repeating Reactome analysis, experimenting with including EHLD (Enhanced High Level Diagram) pathways

# %% [markdown]
# ## Setup

# %%
import cptac
import cptac.utils as ut
import pandas as pd
import numpy as np
import os
import datetime

# %%
TIME_START = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')

STEP01_DIR = "step01_outputs"
STEP01_FILE = "tumor_change_20200529_195104_10000_perm.tsv"
STEP01_FILE_PATH = os.path.join(STEP01_DIR, STEP01_FILE)

STEP14_DIR = "step14_outputs"
STEP14_FILE = f"enrichment_reactome_ehld_{TIME_START}_from_{STEP01_FILE.rsplit('.', maxsplit=1)[0]}.tsv"
STEP14_FILE_PATH = os.path.join(STEP14_DIR, STEP14_FILE)

if not os.path.isdir(STEP14_DIR):
    os.mkdir(STEP14_DIR)

# %% [markdown]
# ## Prepare data

# %%
# Read in the file from step 1
data = pd.read_csv(STEP01_FILE_PATH, sep='\t', index_col=0)

# The ranked enrichment analysis service wants ranking scores
# where "bigger is better", such as expression values or
# t scores. We are ranking by adjusted p-values, where smaller
# is better. So, we'll create a column of (1 - adj_p) to use
# for ranking.
data = data.assign(one_minus_adj_p=1 - data["adj_p"])

# Make a column where all increases are +1 and all decreases 
# are -1, because these are ratioed abundances, so we can't 
# compare magnitudes between genes--we can only compare whether 
# there was a change, and whether it was positive or negative
data = data.assign(simplified_change=data["change"])

data.loc[data["change"] > 0, "simplified_change"] = 1
data.loc[data["change"] < 0, "simplified_change"] = -1
data.loc[data["change"] == 0, "simplified_change"] = 0

# %%
data.head()
# Out:
#   cancer_type                       protein    change   P_val    adj_p  \
# 0       ccrcc       ('A1BG', 'NP_570602.2')  0.282928  0.0000  0.00000
# 1       ccrcc       ('A1CF', 'NP_620310.1') -0.551358  0.0000  0.00000
# 2       ccrcc        ('A2M', 'NP_000005.2')  0.595512  0.0000  0.00000
# 3       ccrcc  ('A4GALT', 'NP_001304967.1')  0.479410  0.1735  0.21431
# 4       ccrcc       ('AAAS', 'NP_056480.1')  0.173579  0.0000  0.00000
#
#    reject_null protein_str  one_minus_adj_p  simplified_change
# 0         True        A1BG          1.00000                1.0
# 1         True        A1CF          1.00000               -1.0
# 2         True         A2M          1.00000                1.0
# 3        False      A4GALT          0.78569                1.0
# 4         True        AAAS          1.00000                1.0

# %% [markdown]
# ## Run enrichment analysis

# %%
# For each cancer, find enriched pathways based on p value for differential expression   
all_enrichments = pd.DataFrame()

for cancer_type in data["cancer_type"].unique():
    
    ranked_data = data.loc[data["cancer_type"] == cancer_type, ["protein_str", "one_minus_adj_p"]].\
        set_index("protein_str").\
        rename(columns={"one_minus_adj_p": f"{cancer_type}_one_minus_adj_p"})

    unneeded_token, cancer_enriched = ut.reactome_enrichment_analysis(
        analysis_type="ranked", 
        data=ranked_data, 
        sort_by="ENTITIES_FDR", 
        ascending=True,
        include_high_level_diagrams=True, 
        include_interactors=False)
    
    # Record the cancer type and rename the pathway id column
    cancer_enriched = cancer_enriched.\
        assign(cancer_type=cancer_type).\
        rename(columns={"stId": "pathway_id"})
    
    # Append to the overall dataframe
    all_enrichments = all_enrichments.append(cancer_enriched)

# %%
# Drop columns we don't need
all_enrichments = all_enrichments.drop(columns=["entities_ratio", "entities_found", "entities_total"])

# %%
# Assign pathway ranks within each cancer type based on p value
# We use p value instead of FDR because they will both put the pathways
# in the same order, but the p values are more precise for ranking--some
# pathways that have the same FDR have different p values, so we get
# more specific ranks from the p values.

all_enrichments = all_enrichments.\
    assign(cancer_rank_pval=all_enrichments.groupby("cancer_type")["entities_pValue"].rank()).\
    sort_values(by=["cancer_type", "cancer_rank_pval"]).\
    reset_index(drop=True)

# %% [markdown]
# ## Summarize enrichment results from all cancers

# %%
enrichment_summary = all_enrichments[["pathway_id", "name"]].drop_duplicates(keep="first")

pathway_times_enriched = enrichment_summary["pathway_id"].apply(
    lambda x: all_enrichments[all_enrichments["pathway_id"] == x].shape[0])

avg_rank = enrichment_summary["pathway_id"].apply(
    lambda x: all_enrichments.loc[all_enrichments["pathway_id"] == x, "cancer_rank_pval"].mean())

enrichment_summary = enrichment_summary.\
    assign(
        pathway_times_enriched=pathway_times_enriched,
        pathway_avg_rank=avg_rank).\
    sort_values(
        by=["pathway_times_enriched", "pathway_avg_rank"],
        ascending=[False, True]).\
    reset_index(drop=True)

# %%
enrichment_summary
# Out:
#          pathway_id                                               name  \
# 0     R-HSA-6798695                           Neutrophil degranulation
# 1     R-HSA-6791226  Major pathway of rRNA processing in the nucleo...
# 2     R-HSA-8868773         rRNA processing in the nucleus and cytosol
# 3     R-HSA-1236977                         Endosomal/Vacuolar pathway
# 4       R-HSA-72689           Formation of a pool of free 40S subunits
# 5     R-HSA-1799339  SRP-dependent cotranslational protein targetin...
# 6      R-HSA-975956  Nonsense Mediated Decay (NMD) independent of t...
# 7       R-HSA-72706  GTP hydrolysis and joining of the 60S ribosoma...
# 8     R-HSA-5419276              Mitochondrial translation termination
# 9     R-HSA-5389840               Mitochondrial translation elongation
# 10    R-HSA-9609507                               Protein localization
# 11     R-HSA-156827  L13a-mediated translational silencing of Cerul...
# 12     R-HSA-927802                      Nonsense-Mediated Decay (NMD)
# 13     R-HSA-975957  Nonsense Mediated Decay (NMD) enhanced by the ...
# 14      R-HSA-72163                      mRNA Splicing - Major Pathway
# 15    R-HSA-5368287                          Mitochondrial translation
# 16      R-HSA-72613                  Eukaryotic Translation Initiation
# 17      R-HSA-72737               Cap-dependent Translation Initiation
# 18    R-HSA-5368286               Mitochondrial translation initiation
# 19     R-HSA-156902                           Peptide chain elongation
# 20     R-HSA-983170  Antigen Presentation: Folding, assembly and pe...
# 21     R-HSA-156842                  Eukaryotic Translation Elongation
# 22      R-HSA-72649           Translation initiation complex formation
# 23      R-HSA-72172                                      mRNA Splicing
# 24      R-HSA-72695  Formation of the ternary complex, and subseque...
# 25      R-HSA-72187                             mRNA 3'-end processing
# 26    R-HSA-6799198                               Complex I biogenesis
# 27    R-HSA-9007101                      Rab regulation of trafficking
# 28    R-HSA-1268020                       Mitochondrial protein import
# 29    R-HSA-8950505  Gene and protein expression by JAK-STAT signal...
# ...             ...                                                ...
# 2320  R-HSA-5619085  Defective SLC26A3 causes congenital secretory ...
# 2321  R-HSA-5619087    Defective SLC12A3 causes Gitelman syndrome (GS)
# 2322  R-HSA-3274531            Glycogen storage disease type Ia (G6PC)
# 2323  R-HSA-5658208   Defective SLC5A2 causes renal glucosuria (GLYS1)
# 2324  R-HSA-5619071  Defective SLC22A12 causes renal hypouricemia 1...
# 2325  R-HSA-5619099  Defective AVP does not bind AVPR1A,B and cause...
# 2326  R-HSA-5619040  Defective SLC34A1 causes hypophosphatemic neph...
# 2327   R-HSA-432030  Transport of glycerol from adipocytes to the l...
# 2328   R-HSA-380095              Tachykinin receptors bind tachykinins
# 2329  R-HSA-1307965                 betaKlotho-mediated ligand binding
# 2330  R-HSA-5619113          Defective SLC3A1 causes cystinuria (CSNU)
# 2331  R-HSA-5660883          Defective SLC7A9 causes cystinuria (CSNU)
# 2332   R-HSA-888568                                     GABA synthesis
# 2333  R-HSA-1839128                   FGFR4 mutant receptor activation
# 2334  R-HSA-5579002         Defective UGT1A1 causes hyperbilirubinemia
# 2335  R-HSA-5619041  Defective SLC36A2 causes iminoglycinuria (IG) ...
# 2336  R-HSA-5619098  Defective SLC2A2 causes Fanconi-Bickel syndrom...
# 2337  R-HSA-5619104  Defective SLC12A1 causes Bartter syndrome 1 (BS1)
# 2338  R-HSA-1299503              TWIK related potassium channel (TREK)
# 2339  R-HSA-5619089    Defective SLC6A5 causes hyperekplexia 3 (HKPX3)
# 2340   R-HSA-451307       Activation of Na-permeable kainate receptors
# 2341  R-HSA-1296053                             Classical Kir channels
# 2342  R-HSA-2160456                                    Phenylketonuria
# 2343   R-HSA-388479                         Vasopressin-like receptors
# 2344  R-HSA-5579028  Defective CYP17A1 causes Adrenal hyperplasia 5...
# 2345   R-HSA-350864             Regulation of thyroid hormone activity
# 2346  R-HSA-5659735    Defective SLC6A19 causes Hartnup disorder (HND)
# 2347  R-HSA-5619044    Defective SLC6A19 causes Hartnup disorder (HND)
# 2348  R-HSA-5662702                               Melanin biosynthesis
# 2349   R-HSA-444209                          Free fatty acid receptors
#
#       pathway_times_enriched  pathway_avg_rank
# 0                          8            1.0000
# 1                          8            3.0000
# 2                          8            7.7500
# 3                          8           12.7500
# 4                          8           14.2500
# 5                          8           18.1250
# 6                          8           19.3750
# 7                          8           19.6250
# 8                          8           25.1250
# 9                          8           26.3125
# 10                         8           28.7500
# 11                         8           29.5000
# 12                         8           31.3750
# 13                         8           31.3750
# 14                         8           35.1250
# 15                         8           38.1250
# 16                         8           42.6250
# 17                         8           42.6250
# 18                         8           47.0000
# 19                         8           47.1250
# 20                         8           48.5000
# 21                         8           51.2500
# 22                         8           52.3125
# 23                         8           55.1250
# 24                         8           56.1250
# 25                         8           56.8750
# 26                         8           58.0000
# 27                         8           69.2500
# 28                         8           79.1250
# 29                         8           82.9375
# ...                      ...               ...
# 2320                       1         1133.0000
# 2321                       1         1161.5000
# 2322                       1         1161.5000
# 2323                       1         1161.5000
# 2324                       1         1161.5000
# 2325                       1         1161.5000
# 2326                       1         1161.5000
# 2327                       1         1161.5000
# 2328                       1         1219.0000
# 2329                       1         1331.5000
# 2330                       1         1331.5000
# 2331                       1         1331.5000
# 2332                       1         1343.5000
# 2333                       1         1372.5000
# 2334                       1         1372.5000
# 2335                       1         1372.5000
# 2336                       1         1372.5000
# 2337                       1         1372.5000
# 2338                       1         1400.5000
# 2339                       1         1400.5000
# 2340                       1         1517.0000
# 2341                       1         1517.0000
# 2342                       1         1520.0000
# 2343                       1         1633.5000
# 2344                       1         1719.0000
# 2345                       1         1857.0000
# 2346                       1         2045.5000
# 2347                       1         2045.5000
# 2348                       1         2114.0000
# 2349                       1         2166.0000
#
# [2350 rows x 4 columns]

# %% [markdown]
# ## Visualize pathways with expression change

# %%
# Submit the differential expression data for each cancer type to the analysis service, and get the tokens
# The data we'd submitted previously were the p values for the differential expression, but that's not what
# we want to visualize; we want to see whether the expression was up or down.
diff_expr_tokens = {}

for cancer_type in data["cancer_type"].unique():

    # Select data for that cancer type
    # Exclude samples where not reject_null
    omics = data.loc[(data["cancer_type"] == cancer_type) & data["reject_null"], 
                     ["protein_str", "simplified_change"]].\
        set_index("protein_str").\
        rename(columns={"simplified_change": f"{cancer_type}_simp_change"})

    analysis_token, unneeded_df = ut.reactome_enrichment_analysis(
        analysis_type="ranked", 
        data=omics, 
        sort_by="ENTITIES_FDR", 
        ascending=True,
        include_high_level_diagrams=True, 
        include_interactors=False)
    
    diff_expr_tokens[cancer_type] = analysis_token

# %%
# Select pathways to get URLs for
to_viz = enrichment_summary.iloc[0:10, :]

# Get URLs
id_list = []
cancer_type_list = []
expr_list = []
url_list = []

for idx in to_viz.index:
    pathway_id = to_viz.loc[idx, "pathway_id"]
    
    for cancer_type in data["cancer_type"].unique():
         
        # Get the URL
        expr_vals, url = ut.reactome_pathway_overlay(
            pathway=pathway_id,
            analysis_token=diff_expr_tokens[cancer_type],
            open_browser=False)
        
        id_list.append(pathway_id)
        cancer_type_list.append(cancer_type)
        expr_list.append(expr_vals[0])
        url_list.append(url)

# %%
# Put all the urls in a dataframe
urls_df = pd.DataFrame({
        "pathway_id": id_list,
        "cancer_type": cancer_type_list,
        "mean_expr": expr_list,
        "url": url_list})

# Join in the enrichment summary table
urls_df = urls_df.merge(
    enrichment_summary,
    how="left",
    left_on="pathway_id",
    right_on="pathway_id",
    validate="many_to_one")

# Join in the original enrichment data for each pathway and cancer type
urls_df = urls_df.merge(
    all_enrichments,
    how="left",
    left_on=["pathway_id", "name", "cancer_type"],
    right_on=["pathway_id", "name", "cancer_type"],
    validate="one_to_one")

# %%
# Print the dataframe in such a way that the links are clickable
urls_df.style.format('<a href="{0}">{0}</a>', subset="url")
# Out:
# <style  type="text/css" >
# </style><table id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >pathway_id</th>        <th class="col_heading level0 col1" >cancer_type</th>        <th class="col_heading level0 col2" >mean_expr</th>        <th class="col_heading level0 col3" >url</th>        <th class="col_heading level0 col4" >name</th>        <th class="col_heading level0 col5" >pathway_times_enriched</th>        <th class="col_heading level0 col6" >pathway_avg_rank</th>        <th class="col_heading level0 col7" >entities_pValue</th>        <th class="col_heading level0 col8" >entities_fdr</th>        <th class="col_heading level0 col9" >cancer_rank_pval</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col0" class="data row0 col0" >R-HSA-6798695</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col1" class="data row0 col1" >ccrcc</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col2" class="data row0 col2" >0.268930</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col3" class="data row0 col3" ><a href="https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxMzdfNjE5Ng%3D%3D">https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxMzdfNjE5Ng%3D%3D</a></td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col4" class="data row0 col4" >Neutrophil degranulation</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col5" class="data row0 col5" >8</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col6" class="data row0 col6" >1.000000</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col7" class="data row0 col7" >0.013310</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col8" class="data row0 col8" >0.910882</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow0_col9" class="data row0 col9" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col0" class="data row1 col0" >R-HSA-6798695</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col1" class="data row1 col1" >colon</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col2" class="data row1 col2" >-0.097179</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col3" class="data row1 col3" ><a href="https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNDFfNjE5Nw%3D%3D">https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNDFfNjE5Nw%3D%3D</a></td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col4" class="data row1 col4" >Neutrophil degranulation</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col5" class="data row1 col5" >8</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col6" class="data row1 col6" >1.000000</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col7" class="data row1 col7" >0.000000</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col8" class="data row1 col8" >0.000000</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow1_col9" class="data row1 col9" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col0" class="data row2 col0" >R-HSA-6798695</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col1" class="data row2 col1" >endometrial</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col2" class="data row2 col2" >0.302752</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col3" class="data row2 col3" ><a href="https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNDVfNjE5OA%3D%3D">https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNDVfNjE5OA%3D%3D</a></td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col4" class="data row2 col4" >Neutrophil degranulation</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col5" class="data row2 col5" >8</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col6" class="data row2 col6" >1.000000</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col7" class="data row2 col7" >0.004040</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col8" class="data row2 col8" >0.887282</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow2_col9" class="data row2 col9" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col0" class="data row3 col0" >R-HSA-6798695</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col1" class="data row3 col1" >gbm</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col2" class="data row3 col2" >0.236467</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col3" class="data row3 col3" ><a href="https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNDlfNjE5OQ%3D%3D">https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNDlfNjE5OQ%3D%3D</a></td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col4" class="data row3 col4" >Neutrophil degranulation</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col5" class="data row3 col5" >8</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col6" class="data row3 col6" >1.000000</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col7" class="data row3 col7" >0.006271</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col8" class="data row3 col8" >0.865223</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow3_col9" class="data row3 col9" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow4_col0" class="data row4 col0" >R-HSA-6798695</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow4_col1" class="data row4 col1" >hnscc</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow4_col2" class="data row4 col2" >0.162534</td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow4_col3" class="data row4 col3" ><a href="https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNTNfNjIwMA%3D%3D">https://reactome.org/PathwayBrowser/#/R-HSA-6798695&DTAB=AN&ANALYSIS=MjAyMDA2MjQyMDMxNTNfNjIwMA%3D%3D</a></td>
#                         <td id="T_117c217c_b65f_11ea_a686_8bc56a3e8b6crow4_col4" class="data row4 col4" >Neut

# %%
# Save the results
urls_df.to_csv(STEP14_FILE_PATH, sep='\t')
