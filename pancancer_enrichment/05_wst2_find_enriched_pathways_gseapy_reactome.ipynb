# %% [markdown]
# # Pancancer enrichment analysis step 5: Find enriched pathways using GSEApy with Reactome data

# %% [markdown]
# ## Setup

# %%
import cptac
import cptac.utils as ut
import pandas as pd
import numpy as np
import gseapy as gp
import os
import datetime
import glob

# %%
TIME_START = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
NUM_PERMUTATIONS = 10000

STEP04_DIR = "step04_outputs"
STEP05_DIR = "step05_outputs"

# Create log dir and file
LOG_DIR = "step05_checkpoints"
LOG_FILE = f"{TIME_START}_{NUM_PERMUTATIONS}_perms_wst2.log"
LOG_FILE_PATH = os.path.join(LOG_DIR, LOG_FILE)

if not os.path.isdir(LOG_DIR):
    os.mkdir(LOG_DIR)
    
with open(LOG_FILE_PATH, 'w') as fp: 
    fp.write(f"{TIME_START}\n")
    fp.write(f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Started step 5 with {NUM_PERMUTATIONS} permutations.\n")

GSEAPY_DIR_PATH = os.path.join(STEP05_DIR, "gseapy")

if not os.path.isdir(STEP05_DIR):
    os.mkdir(STEP05_DIR)

# %% [markdown]
# ## Prepare data

# %%
# Read in the files from step 4
step04_files = glob.glob(f"{STEP04_DIR}{os.sep}*")
prot_dict = {}
for file in step04_files:
    name = file.split(os.sep)[1].split("_")[0]
    prot_dict[name] = pd.read_csv(file, sep='\t')

# %%
prot_dict.keys()
# Out:
# dict_keys(['hnscc', 'lscc', 'colon', 'endometrial', 'luad', 'ccrcc', 'gbm', 'ovarian'])

# %% [markdown]
# ## Run enrichment analysis

# %%
def gseapy_enrich_reactome(method, proteomics_dictionary):
    
    with open(LOG_FILE_PATH, 'a') as fp: 
        fp.write(f"\n{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Started {method} method.\n")
    
    output_file = f"enrichment_gseapy_reactome_{TIME_START}_{NUM_PERMUTATIONS}_perms_wst2_{method}.tsv"
    output_path = os.path.join(STEP05_DIR, output_file)
    
    # For each cancer, find enriched pathways.
    all_enrichments = pd.DataFrame()

    for cancer_type in proteomics_dictionary.keys():

        prot = proteomics_dictionary[cancer_type]
        samples = prot.columns[~prot.columns.isin(["NAME"])]
        cls_list = np.where(samples.str.endswith(".N"), "Normal", "Tumor").tolist()

        gs_res = gp.gsea(
            data=prot,
            gene_sets="gene_set_libraries/Reactome_2020.gmt",
            cls=cls_list,
            permutation_type="phenotype",
            permutation_num=NUM_PERMUTATIONS,
            min_size=1,
            max_size=500, 
            outdir=GSEAPY_DIR_PATH,
            no_plot=True,
            method=method,
            processes=1,
            seed=0,
            weighted_score_type=2,
            ascending=False)

        cancer_enriched = gs_res.res2d.assign(cancer_type=cancer_type)
        all_enrichments = all_enrichments.append(cancer_enriched)
        all_enrichments.to_csv(output_path, sep="\t")

        # Log that we finished this cancer type
        with open(LOG_FILE_PATH, 'a') as fp: 
            fp.write(f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Finished {cancer_type} data.\n")
            
    with open(LOG_FILE_PATH, 'a') as fp: 
        fp.write(f"\n{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')} - Finished {method} method.\n")

# %%
gseapy_enrich_reactome("abs_signal_to_noise", prot_dict)
gseapy_enrich_reactome("signal_to_noise", prot_dict)
gseapy_enrich_reactome("t_test", prot_dict)
gseapy_enrich_reactome("ratio_of_classes", prot_dict)
gseapy_enrich_reactome("diff_of_classes", prot_dict)
gseapy_enrich_reactome("log2_ratio_of_classes", prot_dict)
# Out:
# 2020-06-18 10:45:13,510 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 11:20:23,004 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 11:50:32,115 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 12:06:08,654 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 12:33:57,006 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 12:59:18,518 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 13:29:29,890 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 13:48:27,193 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 14:04:01,666 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 14:23:44,254 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 14:41:35,750 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 14:53:42,763 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 15:10:56,476 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 15:27:33,503 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 15:46:34,888 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 16:04:12,340 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 16:19:46,631 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 16:39:28,729 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 16:57:20,820 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 17:09:27,715 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 17:26:36,649 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 17:43:14,063 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 18:02:17,382 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 18:19:56,894 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 18:35:33,228 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 18:55:18,233 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 19:13:11,448 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 19:25:19,880 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 19:42:30,617 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 19:59:08,457 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 20:18:12,561 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 20:35:52,491 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 20:51:28,291 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 21:11:11,009 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 21:29:03,172 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 21:41:10,557 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 21:58:20,371 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 22:14:57,279 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 22:34:02,340 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 22:51:41,630 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 23:07:17,019 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 23:27:02,699 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 23:44:52,535 Warning: Input data contains NA, filled NA with 0
# 2020-06-18 23:56:58,047 Warning: Input data contains NA, filled NA with 0
# 2020-06-19 00:14:02,537 Warning: Input data contains NA, filled NA with 0
# 2020-06-19 00:30:38,496 Warning: Input data contains NA, filled NA with 0
# 2020-06-19 00:49:42,484 Warning: Input data contains NA, filled NA with 0
# 2020-06-19 01:07:16,490 Warning: Input data contains NA, filled NA with 0
